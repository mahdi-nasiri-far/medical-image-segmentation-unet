# %% [markdown]
# <div style="border-left: 5px solid green; padding: 10px; background-color:rgb(224, 247, 206);">
#     <b>⚡️ Information:</b>
#     Yihan's customized unet experiment
# </div>

# %% [markdown]
# ### Step 0 - Set & Check available memory

# %%
import tensorflow as tf
MEMORY_SIZE = 18
memory_limit = MEMORY_SIZE * 1024

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]  # Set limit to 15GB
        )
        print(f"Limited GPU memory usage to {MEMORY_SIZE}GB")
    except RuntimeError as e:
        print(e)
# Out:
# Limited GPU memory usage to 18GB

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for i, gpu in enumerate(gpus):
        device_name = f"GPU:{i}"  # Properly format the device name
        details = tf.config.experimental.get_memory_info(device_name)
        print(f"GPU: {device_name}")
        print(f"Current Memory Usage: {details['current']} bytes")
        print(f"Peak Memory Usage: {details['peak']} bytes")
else:
    print("No GPU devices found.")

for gpu in gpus:
    print(f"Memory growth for {gpu}: {tf.config.experimental.get_memory_growth(gpu)}")
# Out:
# GPU: GPU:0
# Current Memory Usage: 601001728 bytes
# Peak Memory Usage: 4785219072 bytes
# Memory growth for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): None

# %% [markdown]
# ### Step 1 - Set up environment

# %%
import nibabel as nib
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from skimage.transform import rotate
from skimage.util import montage
import os
from sklearn.model_selection import train_test_split
import keras
import cv2
import tensorflow
import random
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import numpy as np
from keras.callbacks import CSVLogger
import keras.backend as K
import zipfile
import pandas as pd

# %% [markdown]
# #### paths, VOLUME_*, IMG_SIZE, N_CHANNELS

# %%
# Specify a sample path (here we will take the first patient of the Training dataset)
brats_index = 'BraTS-GLI-00077-000'
brats_sample_path = f'../brain_tumor_seg/data/raw_data/GLI_train/{brats_index}/{brats_index}-'

# Specify the root data path of training data
# data_path_GLI_train_dir = f'../brain_tumor_seg/data/raw_data/GLI_train'
data_path_GLI_train_dir = f'/home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train'


# Define selected slices range
VOLUME_START_AT = 40 
VOLUME_SLICES_PLUS = 76 
TUMOR_RATIO_LOWER_BOUND = 0.2
TUMOR_RATIO_UPPER_BOUND = 0.25

# For DataGenerator
IMG_SIZE = 256
N_CHANNELS = 2

# %% [markdown]
# ### Not a Step - Explore data

# %%
# Load the 4 MRI modalities and the segmentation located in the patient's path using the nibabel library
t1_img_sample=nib.load(brats_sample_path + 't1n.nii.gz')
t1ce_img_sample=nib.load(brats_sample_path + 't1c.nii.gz')
t2_img_sample=nib.load(brats_sample_path + 't2w.nii.gz')
flair_img_sample=nib.load(brats_sample_path + 't2f.nii.gz')
seg_img_sample=nib.load(brats_sample_path + 'seg.nii.gz')

# Get the image data
t1_data_sample = t1_img_sample.get_fdata()
t1ce_data_sample = t1ce_img_sample.get_fdata()
t2_data_sample = t2_img_sample.get_fdata()
flair_data_sample = flair_img_sample.get_fdata()
seg_data_sample = seg_img_sample.get_fdata()

# Plot the 100th slice of the 4 RMI modalities and the segmentation
slice_nb = 100

fig, axs = plt.subplots(1, 5, figsize=(20,20))
axs[0].imshow(t1_data_sample[:,:,slice_nb], cmap="gray")
axs[0].set_title('T1')
axs[1].imshow(t1ce_data_sample[:,:,slice_nb], cmap="gray")
axs[1].set_title('T1CE')
axs[2].imshow(t2_data_sample[:,:,slice_nb], cmap="gray")
axs[2].set_title('T2')
axs[3].imshow(flair_data_sample[:,:,slice_nb], cmap="gray")
axs[3].set_title('FLAIR')
axs[4].imshow(seg_data_sample[:,:,slice_nb], cmap="gray")
axs[4].set_title('Segmentation')
plt.savefig(f'./plt/seg_classes_{brats_index}.png', dpi=300)
plt.show()

# %%
# Plot a RMI modality through all planes
slice_nb = 100

fig, axs2 = plt.subplots(1, 3, figsize=(10,10))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
axs2[0].imshow(rotate(t1_data_sample[slice_nb,:,:], 90, resize=True), cmap="gray")
axs2[0].set_title('T1 - Sagittal View')

axs2[1].imshow(rotate(t1_data_sample[:,slice_nb,:], 90, resize=True), cmap="gray")
axs2[1].set_title('T1 - Coronal View')

axs2[2].imshow(t1_data_sample[:,:,slice_nb], cmap="gray")
axs2[2].set_title('T1 - Axial View')

plt.show()

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data_sample[:,:,:]), 90, resize=True), cmap ='gray')

# montage allows us to concatenate multiple images of the same size horizontally and vertically

# %%
# Display all slices of a segmentation
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(seg_data_sample[:,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data_sample[60:135,:,:]), 90, resize=True), cmap ='gray')

# %%
# Plot a segmantation
some_seg_img = nib.load(f'{brats_sample_path}seg.nii.gz').get_fdata()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

plt.imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
plt.title(brats_index)
plt.colorbar()

# %%
seg_samples = [os.path.join(data_path_GLI_train_dir, sample, f"{sample}-seg.nii.gz") for sample in os.listdir(data_path_GLI_train_dir) if not sample.endswith('.csv')]

saved_values = []
max_nb_values = 0
for sample in seg_samples:
    seg_img_sample = nib.load(sample).get_fdata()
    unique_values = np.unique(seg_img_sample)
    nb_unique_values = len(np.unique(seg_img_sample))
    
    if nb_unique_values > max_nb_values:
        max_nb_values = nb_unique_values
        saved_values = unique_values

print(f"Maximum number of values in all segmentation images: {max_nb_values}")
print(f"Values: {saved_values}")

# %%
# Deletion of class 0
seg_0 = some_seg_img.astype(float).copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = some_seg_img.astype(float).copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = some_seg_img.astype(float).copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_3 = some_seg_img.astype(float).copy()
seg_3[seg_3 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 3']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, axs3 = plt.subplots(1, 5, figsize=(15, 15))

axs3[0].imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
axs3[0].set_title('Original Segmentation')
axs3[0].legend(handles=legend, loc='upper right')

axs3[1].imshow(seg_0[100,:,:], cmap=cmap, norm=norm)
axs3[1].set_title('[Not Tumor] class 0')

axs3[2].imshow(seg_1[100,:,:], cmap=cmap, norm=norm)
axs3[2].set_title('[NCR] class 1')

axs3[3].imshow(seg_2[100,:,:], cmap=cmap, norm=norm)
axs3[3].set_title('[ED] class 2')

axs3[4].imshow(seg_3[100,:,:], cmap=cmap, norm=norm)
axs3[4].set_title('[ET] class 3')

# Save the figure to a file
plt.savefig('segmentation_classes.png', dpi=300)  # Saves the image as 'segmentation_classes.png'

plt.show()

# %%
values, counts = np.unique(some_seg_img, return_counts=True)
print(f'distribution of 4 classes: {counts}')

# %%
# Modality shape
print(f'modality shape: {t1_data_sample.shape}')

# Segmentation shape
print(f'segmentation shape: {seg_data_sample.shape}')

# %% [markdown]
# ### Step 2 - Load images and parameters

# %%
# Retrieve all samples from path with listdir(). This method lists of all files + directories in the specified directory.
all_datas = os.listdir(data_path_GLI_train_dir)
print("Number of samples:", len(all_datas))
# Out:
# Number of samples: 1251

# %%
# Split the dataset into train and validation sets
datas_train, datas_val = train_test_split(all_datas, test_size=0.2, random_state=42)

# Split the train set into the real train set and in a test set 
datas_train, datas_test = train_test_split(datas_train, test_size=0.15, random_state=42)

# Print data distribution (Train: 68%, Test: 12%, Val: 20%)
print(f"Train length: {len(datas_train)}")
print(f"Validation length: {len(datas_val)}")
print(f"Test length: {len(datas_test)}")
# Out:
# Train length: 850
# Validation length: 251
# Test length: 150

# %%
pip show keras tensorflow # type: ignore
# Out:
# Name: keras
# Version: 2.7.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /home/cbel/Desktop/YIHAN/venv/lib/python3.8/site-packages
# Requires:
# Required-by: tensorflow
# ---
# Name: tensorflow
# Version: 2.7.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /home/cbel/Desktop/YIHAN/venv/lib/python3.8/site-packages
# Requires: astunparse, termcolor, protobuf, numpy, gast, grpcio, wheel, h5py, keras-preprocessing, google-pasta, six, tensorflow-io-gcs-filesystem, tensorflow-estimator, libclang, tensorboard, wrapt, typing-extensions, keras, opt-einsum, flatbuffers, absl-py
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print("===============================")
print(f'tensorflow version: {tf.__version__}')  # Should print 2.7.0
print(f'is built with CUDA: {tf.test.is_built_with_cuda()}')  # Should return True
print(f'GPU details: {tf.config.list_physical_devices("GPU")}')  # Should show GPU details

# Check if TensorFlow can detect a GPU
if tf.config.list_physical_devices('GPU'):
    print("GPU is available.")
else:
    print("GPU is not available.")

print("===============================")
# Out:
# ===============================
# tensorflow version: 2.7.0
# is built with CUDA: True
# GPU details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU is available.
# ===============================

# %% [markdown]
# ### Skip if no need - combine existing pkl

# %%
import pickle
import csv

DATA_1_DIR = 'processed_data_0.05_0.1'
DATA_2_DIR = 'processed_data_0.1_0.25'
COMBINED_DATA_DIR = 'processed_data_0.05_0.25'
SET = 'test'


with open(f'./data/{DATA_1_DIR}/processed_{SET}_data.pkl', 'rb') as f:
    data1 = pickle.load(f)
with open(f'./data/{DATA_2_DIR}/processed_{SET}_data.pkl', 'rb') as f:
    data2 = pickle.load(f)
combined_data = data1.copy()
combined_data.update(data2)
with open(f'./data/{COMBINED_DATA_DIR}/processed_{SET}_data.pkl', 'wb') as f:
    pickle.dump(combined_data, f)


with open(f'./data/{DATA_1_DIR}/{SET}_data_info.csv', 'r') as csv1, open(f'./data/{DATA_2_DIR}/{SET}_data_info.csv', 'r') as csv2:
    reader1 = csv.reader(csv1)
    reader2 = csv.reader(csv2)

    with open(f'./data/{COMBINED_DATA_DIR}/{SET}_data_info.csv', 'w', newline='') as csv_out:
        writer = csv.writer(csv_out)
        for row in reader1:
            writer.writerow(row)
        next(reader2)
        for row in reader2:
            writer.writerow(row)

# %% [markdown]
# ### Step * Crop Nii files

# %% [markdown]
# #### Step * - 1: Set up params & crop method

# %%
import pickle
import os
import nibabel as nib
import cv2
import numpy as np
import csv

total_slices_dict = {
    "train": 0,
    "val": 0,
    "test": 0
}

def preprocess_and_save(data_list, save_path, log_path, tumor_ratio_lower_bound, tumor_ratio_upper_bound):
    processed_data = {'X': [], 'y': []}
    slice_info = {}  # Dictionary to store slice information for each NIfTI

    with open(log_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['NIfTI ID', 'Slice Index', 'Tumor Ratio', 'Brain Area'])

        total_slices = 0

        for i in data_list:
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()

            slice_info[i] = []  # Initialize list for each NIfTI

            for j in range(VOLUME_SLICES_PLUS):
                slice_seg = seg[:, :, j + VOLUME_START_AT]
                slice_flair = flair[:, :, j + VOLUME_START_AT]
                tumor_area = np.sum(slice_seg > 0)
                brain_area = np.sum(slice_flair > 0)  # Use non-zero pixels in FLAIR as brain area

                # Avoid division by zero
                if brain_area == 0:
                    continue

                tumor_percentage = tumor_area / brain_area

                if tumor_ratio_lower_bound < tumor_percentage <= tumor_ratio_upper_bound:
                    X_slice = np.zeros((IMG_SIZE, IMG_SIZE, N_CHANNELS))
                    X_slice[:, :, 0] = cv2.resize(slice_flair, (IMG_SIZE, IMG_SIZE))
                    X_slice[:, :, 1] = cv2.resize(t1ce[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                    processed_data['X'].append(X_slice)
                    processed_data['y'].append(slice_seg)
                    slice_info[i].append(j + VOLUME_START_AT)  # Record the slice index

                    # Write slice information to CSV file
                    csv_writer.writerow([i, j + VOLUME_START_AT, round(tumor_percentage, 4), brain_area])
                    total_slices += 1

        total_slices_dict[log_path.split('/')[-1].split('_')[0]] = total_slices

    # Save the processed data
    with open(save_path, 'wb') as f:
        pickle.dump(processed_data, f)

def count_rows_in_csv(file_path):
    with open(file_path, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader, None)
        row_count = sum(1 for row in reader)
    return row_count

# %%
import csv
import os

def append_to_csv(file_path, data, header=None):
    file_exists = os.path.isfile(file_path)

    with open(file_path, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        if header and not file_exists:
            writer.writerow(header)
        writer.writerows(data)

# %% [markdown]
# #### Step * - 2: Crop

# %%
from datetime import datetime
import gc

processed_data_dir_root = f'./data/dimension_{IMG_SIZE}/processed_data_{TUMOR_RATIO_LOWER_BOUND}_{TUMOR_RATIO_UPPER_BOUND}'
processed_data_lists_csv = f'./data/dimension_{IMG_SIZE}/processed_data_lists.csv'
processed_data_lists_header = ['tumor_ratio_lower_bound', 'tumor_ratio_upper_bound', 'train_slices', 'val_slices', 'test_slices', 'generated_timestamp']

print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')

if not os.path.exists(processed_data_dir_root):
    os.makedirs(processed_data_dir_root)
    print("dir processed_data created.")

    preprocess_and_save(datas_train, f'{processed_data_dir_root}/processed_train_data.pkl', f'{processed_data_dir_root}/train_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()
    preprocess_and_save(datas_val, f'{processed_data_dir_root}/processed_val_data.pkl', f'{processed_data_dir_root}/val_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()
    preprocess_and_save(datas_test, f'{processed_data_dir_root}/processed_test_data.pkl', f'{processed_data_dir_root}/test_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()

    processed_data_lists_data = [
        [TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND, total_slices_dict["train"], total_slices_dict["val"], total_slices_dict["test"], datetime.now().strftime("%b-%d_%H-%M-%S")]
    ]
    append_to_csv(processed_data_lists_csv, processed_data_lists_data, processed_data_lists_header)

else:
    print(f'dir processed_data existed at {processed_data_dir_root}.')

# set the data info to params
TRAIN_PKL = f'{processed_data_dir_root}/processed_train_data.pkl'
VAL_PKL = f'{processed_data_dir_root}/processed_val_data.pkl'
TEST_PKL = f'{processed_data_dir_root}/processed_test_data.pkl'
TRAIN_PKL_CSV = f'{processed_data_dir_root}/train_data_info.csv'
VAL_PKL_CSV = f'{processed_data_dir_root}/val_data_info.csv'
TEST_PKL_CSV = f'{processed_data_dir_root}/test_data_info.csv'
total_slices_dict.update({
    "train": count_rows_in_csv(TRAIN_PKL_CSV),
    "val": count_rows_in_csv(VAL_PKL_CSV),
    "test": count_rows_in_csv(TEST_PKL_CSV)
})

print(f'train: {total_slices_dict["train"]} slices')
print(f'val: {total_slices_dict["val"]} slices')
print(f'test: {total_slices_dict["test"]} slices')
# Out:
# tumor ratio: 0.2 ~ 0.25
# dir processed_data existed at ./data/dimension_256/processed_data_0.2_0.25.
# train: 3615 slices
# val: 1092 slices
# test: 551 slices

# %% [markdown]
# ### Step 3 - Set up training compoenents

# %% [markdown]
# **When generating `DataGenerator`**:
# - We use a data generator to be able to process and send our data to our neural network (since all our images cannot be stored in memory at once).
# - For each epoch (single pass of the entire training dataset through a neural network), the model will receive 250 samples (those contained in our training dataset).
# - For each sample, the model will have to analyze 150 slices (since there are two modalities, and 75(VOLUME_SLICES) selected slices for both of them), received in a (128, 128) shape, as an X array of a (128, 128, 75, 2) shape. This array will be provided with the ground truth segmentation of the patient, which will be One-Hot encoded and will then have a (75, 128, 128, 4) shape.

# %% [markdown]
# #### 3 - 1: DataGenerator

# %% [markdown]
# ##### 3-1-1 DataGenerator_UnetV1

# %%
from tensorflow.keras import layers, models

# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net

class DataGenerator_UnetV1(keras.utils.all_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = N_CHANNELS, shuffle=True):
        print('------ usging Data Generator V1 ------')
        'Initialization'
        self.dim = dim # Resized image dimensions (128 x 128)
        self.batch_size = batch_size #  Number of images to load each time
        self.list_IDs = list_IDs # Patients IDs
        self.n_channels = n_channels # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle # Indicates if data is shuffled for each epoch
        self.on_epoch_end() # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):
            
            # Get path of each RMI modality and the segmentation
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            #t1_path = sample_path + '_t1.nii.gz'
            #t2_path = sample_path + '_t2.nii.gz'
            
            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()
        
            for j in range(VOLUME_SLICES_PLUS):
                 X[j +VOLUME_SLICES_PLUS*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                 X[j +VOLUME_SLICES_PLUS*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES_PLUS*c] = seg[:,:,j+VOLUME_START_AT]
                    
        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %% [markdown]
# ##### 3-1-2 DataGenerator_UnetV2

# %%
from tensorflow.keras import layers, models

# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net

class DataGenerator_UnetV2(keras.utils.all_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = N_CHANNELS, shuffle=True):
        print('------ usging Data Generator V2 ------')
        'Initialization'
        self.dim = dim # Resized image dimensions (128 x 128)
        self.batch_size = batch_size #  Number of images to load each time
        self.list_IDs = list_IDs # Patients IDs
        self.n_channels = n_channels # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle # Indicates if data is shuffled for each epoch
        self.on_epoch_end() # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):
            
            # Get path of each RMI modality and the segmentation
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            #t1_path = sample_path + '_t1.nii.gz'
            #t2_path = sample_path + '_t2.nii.gz'
            
            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()
        
            for j in range(VOLUME_SLICES_PLUS):
                 X[j +VOLUME_SLICES_PLUS*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES_PLUS*c] = seg[:,:,j+VOLUME_START_AT]
                    
        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %% [markdown]
# ##### 3-1-3 DataGenerator_UnetV3_count_image_ratio

# %%
from tensorflow.keras import layers, models

class DataGenerator_UnetV3_count_image_ratio(keras.utils.all_utils.Sequence):
    def __init__(self, data_path, batch_size=1, shuffle=True):
        print('------ usging Data Generator V3: use crop NIIs ------')
        with open(data_path, 'rb') as f:
            self.data = pickle.load(f)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.data['X']))
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.data['X']) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        X_batch = [self.data['X'][k] for k in indexes]
        y_batch = [self.data['y'][k] for k in indexes]

        y_batch = np.array(y_batch)
        y_batch[y_batch == 4] = 3
        mask = tensorflow.one_hot(y_batch, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))

        return np.array(X_batch) / np.max(X_batch), Y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# #### 3 -2: U-Net model

# %% [markdown]
# ##### 3-2-1 U-Net v1

# %%
# U-Net implementation for BraTS 2019 by Naomi Fridman, https://naomi-fridman.medium.com/multi-class-image-segmentation-a5cc671e647a
def unet_v1(inputs, ker_init, dropout, kernel_size=3):
    print('****** using U-Net V1 ******')
    conv1 = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)
    
    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    
    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    conv10 = Conv2D(4, 1, activation = 'softmax')(conv)
    
    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# ##### 3-2-2: U-Net V2

# %%
def unet_v2(inputs, ker_init, dropout=0.5, kernel_size=3):
    print('****** using U-Net V2 ******')
    conv1 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool3)
    conv4 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv4)
    drop4 = Dropout(dropout)(conv4)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
    conv5 = Conv2D(1024, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(1024, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge6)
    conv6 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    conv9 = Conv2D(2, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    conv10 = Conv2D(4, 1, activation = 'sigmoid')(conv9)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# #### 3 - 3: Loss Functions

# %%
def categorical_dice_loss(y_true, y_pred, smooth=1e-6):
    intersection = K.sum(y_true * y_pred, axis=[0,1,2])
    union = K.sum(y_true, axis=[0,1,2]) + K.sum(y_pred, axis=[0,1,2])
    dice_loss = 1 - K.mean((2. * intersection + smooth) / (union + smooth))
    return dice_loss

def focal_loss(alpha=0.25, gamma=2.0):
    def loss(y_true, y_pred):
        ce = tf.keras.losses.CategoricalCrossentropy()(y_true, y_pred)
        pt = tf.exp(-ce)  # 計算 p_t
        focal_loss = alpha * (1 - pt) ** gamma * ce
        return focal_loss
    return loss

def focal_dice_loss(y_true, y_pred):
    return focal_loss()(y_true, y_pred) + categorical_dice_loss(y_true, y_pred)

# %% [markdown]
# #### 3 - 4: Metrics

# %%
# Compute metric between the predicted segmentation and the ground truth
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

########################### my customized metrics ###########################

def sensibility(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Calculate the sensibility
    sensibility = 1 - (false_positives / (true_positives + possible_positives + K.epsilon()))
    # Check for NaN or Inf values and return NaN if True
    sensibility = tf.where(tf.math.is_nan(sensibility) | tf.math.is_inf(sensibility),
                           tf.constant(float('NaN')),
                           sensibility)
    return sensibility


def jaccard(y_true, y_pred):
    # True positives, false positives, false negatives
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)))
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)))
    # Calculate Jaccard index
    denominator = true_positives + false_positives + false_negatives + K.epsilon()  # Add epsilon to avoid division by zero
    result = true_positives / denominator
    # Handle NaN or Inf cases
    result = K.switch(K.is_inf(result) | K.is_nan(result), K.constant(float('NaN')), result)
    return result


# Hausdorff distance (approximation for use in Keras)
def hausdorff(y_true, y_pred):
    # Flatten the coordinates of the true and predicted segmentation masks
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    # Compute the Euclidean distance between every pair of points
    dist_matrix = K.square(y_true_flat - y_pred_flat)
    # Get the maximum distance in both directions (directed Hausdorff)
    directed_hausdorff_1 = K.max(dist_matrix, axis=1)  # From y_true to y_pred
    directed_hausdorff_2 = K.max(dist_matrix, axis=0)  # From y_pred to y_true
    # Take the maximum of both directed Hausdorff distances
    hausdorff_dist = K.maximum(directed_hausdorff_1, directed_hausdorff_2)
    # Handle NaN or Inf values by replacing them with NaN (if needed)
    hausdorff_dist = K.switch(K.is_inf(hausdorff_dist) | K.is_nan(hausdorff_dist), K.constant(float('NaN')), hausdorff_dist)
    return hausdorff_dist

# %% [markdown]
# #### 3 - 5: Define training params

# %%
from keras import Input

MODEL_VERSION = 1
DATA_GENERATOR_VERSION = 3

EPOCHS = 200
STEPS_PER_EPOCH = len(datas_train)

INPUT_LAYER = Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
KER_INIT = 'he_normal'
DROPOUT = 0.2
KERNEL_SIZE = 5
LEARNING_RATE = 1e-4
# LOSS_FUNCTION = "categorical_crossentropy"
LOSS_FUNCTION = focal_dice_loss

# %% [markdown]
# #### 3 - 6: Build the model

# %%
# Build and compile the model
model_builders = {
    1: unet_v1,
    2: unet_v2
}
model = model_builders.get(MODEL_VERSION, unet_v1)(inputs=INPUT_LAYER, ker_init=KER_INIT, dropout=DROPOUT, kernel_size=KERNEL_SIZE)

model.compile(loss=LOSS_FUNCTION, optimizer=tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity ] )
# Out:
# ****** using U-Net V1 ******

# %% [markdown]
# #### 3 - 7: Set up DataGenerator

# %%
data_generators = {
    1: DataGenerator_UnetV1,
    2: DataGenerator_UnetV2,
    3: DataGenerator_UnetV3_count_image_ratio
}

training_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(TRAIN_PKL if DATA_GENERATOR_VERSION == 3 else datas_train)
valid_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(VAL_PKL if DATA_GENERATOR_VERSION == 3 else datas_val)
# Out:
# ------ usging Data Generator V3: use crop NIIs ------
# ------ usging Data Generator V3: use crop NIIs ------

# %% [markdown]
# #### 3 - 8: Do the GC and check the GPU and memory status

# %%
import tensorflow as tf
import gc

gc.collect()

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for i, gpu in enumerate(gpus):
        device_name = f"GPU:{i}"  # Properly format the device name
        details = tf.config.experimental.get_memory_info(device_name)
        print(f"GPU: {device_name}")
        print(f"Current Memory Usage: {details['current']} bytes")
        print(f"Peak Memory Usage: {details['peak']} bytes")
else:
    print("No GPU devices found.")

for gpu in gpus:
    print(f"Memory growth for {gpu}: {tf.config.experimental.get_memory_growth(gpu)}")
# Out:
# GPU: GPU:0
# Current Memory Usage: 683746816 bytes
# Peak Memory Usage: 4785219072 bytes
# Memory growth for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): None

# %%
# Mixed Precision Training
# from tensorflow.keras.mixed_precision import experimental as mixed_precision

# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_policy(policy)

# %% [markdown]
# #### 3 - 9: Set up callbacks
#
# Callbacks are functions that can be executed during the training process.
#
# We will use three callbacks:
#
# - **ReduceLROnPlateau**: This callback reduces the learning rate when a metric has stopped improving (validation loss here). The learning rate is reduced by a factor of 0.2, the patience is set to 2 epochs, and the minimum learning rate is set to 0.000001.
#
# - **ModelCheckpoint**: Saves the best model weights (model that has obtained the lowest validation loss during the different epochs). Saving a model allows us to reuse it later or to share it, without having to retrain it from scratch. This will save us time and resources!
#
# - **CSVLogger**: Add metrics to a CSV file, which is named *training.log* (parameter `append` is set to `False` so the file is overwritten if it already exists).

# %%
from datetime import datetime
import os

# Generate timestamp for filenames
start_train_timestamp = datetime.now().strftime("%b-%d_%H-%M-%S")

# model_dir = f'./model/model_v{MODEL_VERSION}_{start_train_timestamp}'
model_dir = f'/home/cbel/Desktop/YIHAN/unet/model/model_v{MODEL_VERSION}_{start_train_timestamp}'


if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print(f"Model dir {model_dir} created.")
else:
    print(f"Model dir {model_dir} existed.")

# Define file paths with timestamps
training_log_filename = f"{model_dir}/training-{start_train_timestamp}.log"
model_checkpoint_path = f"{model_dir}/model_epoch{{epoch:02d}}-val_loss{{val_loss:.6f}}_{start_train_timestamp}.m5"

callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.000001, verbose=1),
    
    keras.callbacks.ModelCheckpoint(filepath=model_checkpoint_path, verbose=1, save_best_only=True, save_weights_only=True),

    CSVLogger(training_log_filename, separator=',', append=False)  # Save logs with timestamp
]
# Out:
# Model dir /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59 created.

# %% [markdown]
# ### Step 4 - Train & Save the model

# %% [markdown]
# #### 4 - 1: log all cell outputs during training

# %%
import sys

print(f'----------')
print(f'model name: {model_builders[MODEL_VERSION].__name__}')
print(f'epochs: {EPOCHS}')
print(f'steps_per_epoch: {STEPS_PER_EPOCH}')
print(f'dimension: {IMG_SIZE}')
print(f'n_channels: {N_CHANNELS}')
print(f'input layer: {INPUT_LAYER}')
print(f'kernel init: {KER_INIT}')
print(f'kernel size: {KERNEL_SIZE}')
print(f'dropout: {DROPOUT}')
print(f'learning rate: {LEARNING_RATE}')
print(f'loss function: {LOSS_FUNCTION}')
    
print(f"train cases: {len(datas_train)}")
print(f'train slices: {total_slices_dict["train"]}')
print(f"validation cases: {len(datas_val)}")
print(f'val slices: {total_slices_dict["val"]}')
print(f'slice index: {VOLUME_START_AT} ~ {VOLUME_START_AT + VOLUME_SLICES_PLUS}')
print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')
print(f"test cases: {len(datas_test)}")

print(f'start training at: {start_train_timestamp}')
print(f'----------')

original_stdout = sys.stdout
with open(f'{model_dir}/info.log', 'w') as predict_log_file:
    sys.stdout = predict_log_file
    print(f'----------')
    print(f'model name: {model_builders[MODEL_VERSION].__name__}')
    print(f'epochs: {EPOCHS}')
    print(f'steps_per_epoch: {STEPS_PER_EPOCH}')
    print(f'dimension: {IMG_SIZE}')
    print(f'n_channels: {N_CHANNELS}')
    print(f'input layer: {INPUT_LAYER}')
    print(f'kernel init: {KER_INIT}')
    print(f'kernel size: {KERNEL_SIZE}')
    print(f'dropout: {DROPOUT}')
    print(f'learning rate: {LEARNING_RATE}')
    print(f'loss function: {LOSS_FUNCTION}')

    print(f"train cases: {len(datas_train)}")
    print(f'train slices: {total_slices_dict["train"]}')
    print(f"validation cases: {len(datas_val)}")
    print(f'val slices: {total_slices_dict["val"]}')
    print(f'slice index: {VOLUME_START_AT} ~ {VOLUME_START_AT + VOLUME_SLICES_PLUS}')
    print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')
    print(f"test cases: {len(datas_test)}")

    print(f'start training at: {start_train_timestamp}')
    print(f'----------')

sys.stdout = original_stdout
# Out:
# ----------
# model name: unet_v1
# epochs: 200
# steps_per_epoch: 850
# dimension: 256
# n_channels: 2
# input layer: KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 2), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'")
# kernel init: he_normal
# kernel size: 5
# dropout: 0.2
# learning rate: 0.0001
# loss function: <function focal_dice_loss at 0x7efd9cf54700>
# train cases: 850
# train slices: 3615
# validation cases: 251
# val slices: 1092
# slice index: 40 ~ 116
# tumor ratio: 0.2 ~ 0.25
# test cases: 150
# start training at: Apr-22_00-58-59
# ----------

# %% [markdown]
# #### 4 - 2: train

# %%
model.fit(training_generator,
          epochs=EPOCHS,
          steps_per_epoch=STEPS_PER_EPOCH,
          callbacks=callbacks,
          validation_data=valid_generator)
# Out:
# Epoch 1/200
# 850/850 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 0.9353 - mean_io_u_3: 0.6781 - dice_coef: 0.4862 - precision: 0.9487 - sensitivity: 0.9203 - specificity: 0.9853
# Epoch 00001: val_loss improved from inf to 0.35312, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch01-val_loss0.353120_Apr-22_00-58-59.m5
# 850/850 [==============================] - 29s 32ms/step - loss: 0.5269 - accuracy: 0.9353 - mean_io_u_3: 0.6781 - dice_coef: 0.4862 - precision: 0.9487 - sensitivity: 0.9203 - specificity: 0.9853 - val_loss: 0.3531 - val_accuracy: 0.9653 - val_mean_io_u_3: 0.8772 - val_dice_coef: 0.6501 - val_precision: 0.9657 - val_sensitivity: 0.9640 - val_specificity: 0.9886 - lr: 1.0000e-04
# Epoch 2/200
# 850/850 [==============================] - ETA: 0s - loss: 0.3733 - accuracy: 0.9592 - mean_io_u_3: 0.7244 - dice_coef: 0.6355 - precision: 0.9598 - sensitivity: 0.9578 - specificity: 0.9866
# Epoch 00002: val_loss improved from 0.35312 to 0.30245, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch02-val_loss0.302446_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 31ms/step - loss: 0.3733 - accuracy: 0.9592 - mean_io_u_3: 0.7244 - dice_coef: 0.6355 - precision: 0.9598 - sensitivity: 0.9578 - specificity: 0.9866 - val_loss: 0.3024 - val_accuracy: 0.9650 - val_mean_io_u_3: 0.6377 - val_dice_coef: 0.7010 - val_precision: 0.9650 - val_sensitivity: 0.9640 - val_specificity: 0.9883 - lr: 1.0000e-04
# Epoch 3/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.9708 - mean_io_u_3: 0.7642 - dice_coef: 0.7194 - precision: 0.9706 - sensitivity: 0.9700 - specificity: 0.9902
# Epoch 00003: val_loss improved from 0.30245 to 0.27030, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch03-val_loss0.270295_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.2854 - accuracy: 0.9708 - mean_io_u_3: 0.7642 - dice_coef: 0.7194 - precision: 0.9706 - sensitivity: 0.9700 - specificity: 0.9902 - val_loss: 0.2703 - val_accuracy: 0.9747 - val_mean_io_u_3: 0.8457 - val_dice_coef: 0.7345 - val_precision: 0.9745 - val_sensitivity: 0.9740 - val_specificity: 0.9915 - lr: 1.0000e-04
# Epoch 4/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.9753 - mean_io_u_3: 0.8045 - dice_coef: 0.7532 - precision: 0.9750 - sensitivity: 0.9747 - specificity: 0.9917
# Epoch 00004: val_loss improved from 0.27030 to 0.25795, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch04-val_loss0.257948_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.2538 - accuracy: 0.9753 - mean_io_u_3: 0.8045 - dice_coef: 0.7532 - precision: 0.9750 - sensitivity: 0.9747 - specificity: 0.9917 - val_loss: 0.2579 - val_accuracy: 0.9760 - val_mean_io_u_3: 0.9088 - val_dice_coef: 0.7565 - val_precision: 0.9756 - val_sensitivity: 0.9754 - val_specificity: 0.9919 - lr: 1.0000e-04
# Epoch 5/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9769 - mean_io_u_3: 0.8760 - dice_coef: 0.7501 - precision: 0.9766 - sensitivity: 0.9763 - specificity: 0.9922
# Epoch 00005: val_loss did not improve from 0.25795
# 850/850 [==============================] - 27s 32ms/step - loss: 0.2597 - accuracy: 0.9769 - mean_io_u_3: 0.8760 - dice_coef: 0.7501 - precision: 0.9766 - sensitivity: 0.9763 - specificity: 0.9922 - val_loss: 0.2601 - val_accuracy: 0.9764 - val_mean_io_u_3: 0.9025 - val_dice_coef: 0.7435 - val_precision: 0.9761 - val_sensitivity: 0.9758 - val_specificity: 0.9920 - lr: 1.0000e-04
# Epoch 6/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9791 - mean_io_u_3: 0.8985 - dice_coef: 0.7707 - precision: 0.9787 - sensitivity: 0.9785 - specificity: 0.9929
# Epoch 00006: val_loss improved from 0.25795 to 0.24655, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch06-val_loss0.246549_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.2361 - accuracy: 0.9791 - mean_io_u_3: 0.8985 - dice_coef: 0.7707 - precision: 0.9787 - sensitivity: 0.9785 - specificity: 0.9929 - val_loss: 0.2465 - val_accuracy: 0.9768 - val_mean_io_u_3: 0.9045 - val_dice_coef: 0.7592 - val_precision: 0.9765 - val_sensitivity: 0.9763 - val_specificity: 0.9922 - lr: 1.0000e-04
# Epoch 7/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9793 - mean_io_u_3: 0.8638 - dice_coef: 0.7704 - precision: 0.9790 - sensitivity: 0.9788 - specificity: 0.9930
# Epoch 00007: val_loss improved from 0.24655 to 0.22803, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch07-val_loss0.228026_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.2400 - accuracy: 0.9793 - mean_io_u_3: 0.8638 - dice_coef: 0.7704 - precision: 0.9790 - sensitivity: 0.9788 - specificity: 0.9930 - val_loss: 0.2280 - val_accuracy: 0.9795 - val_mean_io_u_3: 0.8064 - val_dice_coef: 0.7798 - val_precision: 0.9791 - val_sensitivity: 0.9790 - val_specificity: 0.9930 - lr: 1.0000e-04
# Epoch 8/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9809 - mean_io_u_3: 0.8626 - dice_coef: 0.7856 - precision: 0.9806 - sensitivity: 0.9804 - specificity: 0.9935
# Epoch 00008: val_loss did not improve from 0.22803
# 850/850 [==============================] - 27s 31ms/step - loss: 0.2257 - accuracy: 0.9809 - mean_io_u_3: 0.8626 - dice_coef: 0.7856 - precision: 0.9806 - sensitivity: 0.9804 - specificity: 0.9935 - val_loss: 0.2295 - val_accuracy: 0.9804 - val_mean_io_u_3: 0.8953 - val_dice_coef: 0.7765 - val_precision: 0.9800 - val_sensitivity: 0.9798 - val_specificity: 0.9933 - lr: 1.0000e-04
# Epoch 9/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9825 - mean_io_u_3: 0.9085 - dice_coef: 0.7981 - precision: 0.9821 - sensitivity: 0.9820 - specificity: 0.9940
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00009: val_loss did not improve from 0.22803
# 850/850 [==============================] - 27s 31ms/step - loss: 0.2124 - accuracy: 0.9825 - mean_io_u_3: 0.9085 - dice_coef: 0.7981 - precision: 0.9821 - sensitivity: 0.9820 - specificity: 0.9940 - val_loss: 0.2373 - val_accuracy: 0.9795 - val_mean_io_u_3: 0.9214 - val_dice_coef: 0.7783 - val_precision: 0.9791 - val_sensitivity: 0.9791 - val_specificity: 0.9931 - lr: 1.0000e-04
# Epoch 10/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9859 - mean_io_u_3: 0.9065 - dice_coef: 0.8192 - precision: 0.9855 - sensitivity: 0.9854 - specificity: 0.9952
# Epoch 00010: val_loss improved from 0.22803 to 0.20843, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch10-val_loss0.208431_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1949 - accuracy: 0.9859 - mean_io_u_3: 0.9065 - dice_coef: 0.8192 - precision: 0.9855 - sensitivity: 0.9854 - specificity: 0.9952 - val_loss: 0.2084 - val_accuracy: 0.9838 - val_mean_io_u_3: 0.9379 - val_dice_coef: 0.8034 - val_precision: 0.9834 - val_sensitivity: 0.9834 - val_specificity: 0.9945 - lr: 2.0000e-05
# Epoch 11/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9862 - mean_io_u_3: 0.9220 - dice_coef: 0.8273 - precision: 0.9858 - sensitivity: 0.9857 - specificity: 0.9953
# Epoch 00011: val_loss improved from 0.20843 to 0.20392, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch11-val_loss0.203918_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1829 - accuracy: 0.9862 - mean_io_u_3: 0.9220 - dice_coef: 0.8273 - precision: 0.9858 - sensitivity: 0.9857 - specificity: 0.9953 - val_loss: 0.2039 - val_accuracy: 0.9834 - val_mean_io_u_3: 0.8954 - val_dice_coef: 0.8035 - val_precision: 0.9830 - val_sensitivity: 0.9830 - val_specificity: 0.9943 - lr: 2.0000e-05
# Epoch 12/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9874 - mean_io_u_3: 0.9170 - dice_coef: 0.8343 - precision: 0.9870 - sensitivity: 0.9869 - specificity: 0.9957
# Epoch 00012: val_loss improved from 0.20392 to 0.20318, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch12-val_loss0.203178_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1820 - accuracy: 0.9874 - mean_io_u_3: 0.9170 - dice_coef: 0.8343 - precision: 0.9870 - sensitivity: 0.9869 - specificity: 0.9957 - val_loss: 0.2032 - val_accuracy: 0.9847 - val_mean_io_u_3: 0.9224 - val_dice_coef: 0.8088 - val_precision: 0.9844 - val_sensitivity: 0.9843 - val_specificity: 0.9948 - lr: 2.0000e-05
# Epoch 13/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9880 - mean_io_u_3: 0.9205 - dice_coef: 0.8451 - precision: 0.9876 - sensitivity: 0.9876 - specificity: 0.9959
# Epoch 00013: val_loss improved from 0.20318 to 0.20040, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch13-val_loss0.200396_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1700 - accuracy: 0.9880 - mean_io_u_3: 0.9205 - dice_coef: 0.8451 - precision: 0.9876 - sensitivity: 0.9876 - specificity: 0.9959 - val_loss: 0.2004 - val_accuracy: 0.9851 - val_mean_io_u_3: 0.9309 - val_dice_coef: 0.8123 - val_precision: 0.9847 - val_sensitivity: 0.9847 - val_specificity: 0.9949 - lr: 2.0000e-05
# Epoch 14/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9878 - mean_io_u_3: 0.9296 - dice_coef: 0.8437 - precision: 0.9874 - sensitivity: 0.9874 - specificity: 0.9958
# Epoch 00014: val_loss improved from 0.20040 to 0.20013, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch14-val_loss0.200126_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1789 - accuracy: 0.9878 - mean_io_u_3: 0.9296 - dice_coef: 0.8437 - precision: 0.9874 - sensitivity: 0.9874 - specificity: 0.9958 - val_loss: 0.2001 - val_accuracy: 0.9845 - val_mean_io_u_3: 0.9305 - val_dice_coef: 0.8105 - val_precision: 0.9841 - val_sensitivity: 0.9841 - val_specificity: 0.9947 - lr: 2.0000e-05
# Epoch 15/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9884 - mean_io_u_3: 0.9322 - dice_coef: 0.8502 - precision: 0.9880 - sensitivity: 0.9880 - specificity: 0.9960
# Epoch 00015: val_loss did not improve from 0.20013
# 850/850 [==============================] - 27s 31ms/step - loss: 0.1689 - accuracy: 0.9884 - mean_io_u_3: 0.9322 - dice_coef: 0.8502 - precision: 0.9880 - sensitivity: 0.9880 - specificity: 0.9960 - val_loss: 0.2023 - val_accuracy: 0.9835 - val_mean_io_u_3: 0.9208 - val_dice_coef: 0.8109 - val_precision: 0.9832 - val_sensitivity: 0.9832 - val_specificity: 0.9944 - lr: 2.0000e-05
# Epoch 16/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9888 - mean_io_u_3: 0.9400 - dice_coef: 0.8479 - precision: 0.9884 - sensitivity: 0.9884 - specificity: 0.9961
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 00016: val_loss did not improve from 0.20013
# 850/850 [==============================] - 27s 31ms/step - loss: 0.1761 - accuracy: 0.9888 - mean_io_u_3: 0.9400 - dice_coef: 0.8479 - precision: 0.9884 - sensitivity: 0.9884 - specificity: 0.9961 - val_loss: 0.2047 - val_accuracy: 0.9843 - val_mean_io_u_3: 0.9644 - val_dice_coef: 0.8138 - val_precision: 0.9840 - val_sensitivity: 0.9840 - val_specificity: 0.9947 - lr: 2.0000e-05
# Epoch 17/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9892 - mean_io_u_3: 0.9688 - dice_coef: 0.8604 - precision: 0.9888 - sensitivity: 0.9888 - specificity: 0.9963
# Epoch 00017: val_loss improved from 0.20013 to 0.19971, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch17-val_loss0.199707_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1582 - accuracy: 0.9892 - mean_io_u_3: 0.9688 - dice_coef: 0.8604 - precision: 0.9888 - sensitivity: 0.9888 - specificity: 0.9963 - val_loss: 0.1997 - val_accuracy: 0.9847 - val_mean_io_u_3: 0.9686 - val_dice_coef: 0.8178 - val_precision: 0.9844 - val_sensitivity: 0.9844 - val_specificity: 0.9948 - lr: 4.0000e-06
# Epoch 18/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9893 - mean_io_u_3: 0.9739 - dice_coef: 0.8614 - precision: 0.9889 - sensitivity: 0.9889 - specificity: 0.9963
# Epoch 00018: val_loss improved from 0.19971 to 0.19880, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch18-val_loss0.198796_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1623 - accuracy: 0.9893 - mean_io_u_3: 0.9739 - dice_coef: 0.8614 - precision: 0.9889 - sensitivity: 0.9889 - specificity: 0.9963 - val_loss: 0.1988 - val_accuracy: 0.9849 - val_mean_io_u_3: 0.9741 - val_dice_coef: 0.8251 - val_precision: 0.9846 - val_sensitivity: 0.9846 - val_specificity: 0.9949 - lr: 4.0000e-06
# Epoch 19/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9895 - mean_io_u_3: 0.9769 - dice_coef: 0.8673 - precision: 0.9891 - sensitivity: 0.9891 - specificity: 0.9964
# Epoch 00019: val_loss did not improve from 0.19880
# 850/850 [==============================] - 27s 31ms/step - loss: 0.1499 - accuracy: 0.9895 - mean_io_u_3: 0.9769 - dice_coef: 0.8673 - precision: 0.9891 - sensitivity: 0.9891 - specificity: 0.9964 - val_loss: 0.1996 - val_accuracy: 0.9849 - val_mean_io_u_3: 0.9754 - val_dice_coef: 0.8239 - val_precision: 0.9846 - val_sensitivity: 0.9846 - val_specificity: 0.9949 - lr: 4.0000e-06
# Epoch 20/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9897 - mean_io_u_3: 0.9773 - dice_coef: 0.8706 - precision: 0.9894 - sensitivity: 0.9894 - specificity: 0.9965
# Epoch 00020: val_loss improved from 0.19880 to 0.19336, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch20-val_loss0.193359_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1422 - accuracy: 0.9897 - mean_io_u_3: 0.9773 - dice_coef: 0.8706 - precision: 0.9894 - sensitivity: 0.9894 - specificity: 0.9965 - val_loss: 0.1934 - val_accuracy: 0.9853 - val_mean_io_u_3: 0.9729 - val_dice_coef: 0.8261 - val_precision: 0.9850 - val_sensitivity: 0.9850 - val_specificity: 0.9950 - lr: 4.0000e-06
# Epoch 21/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9892 - mean_io_u_3: 0.9730 - dice_coef: 0.8678 - precision: 0.9888 - sensitivity: 0.9889 - specificity: 0.9963
# Epoch 00021: val_loss did not improve from 0.19336
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1485 - accuracy: 0.9892 - mean_io_u_3: 0.9730 - dice_coef: 0.8678 - precision: 0.9888 - sensitivity: 0.9889 - specificity: 0.9963 - val_loss: 0.1947 - val_accuracy: 0.9850 - val_mean_io_u_3: 0.9690 - val_dice_coef: 0.8254 - val_precision: 0.9847 - val_sensitivity: 0.9848 - val_specificity: 0.9949 - lr: 4.0000e-06
# Epoch 22/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9897 - mean_io_u_3: 0.9692 - dice_coef: 0.8750 - precision: 0.9894 - sensitivity: 0.9894 - specificity: 0.9965
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00022: val_loss did not improve from 0.19336
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1400 - accuracy: 0.9897 - mean_io_u_3: 0.9692 - dice_coef: 0.8750 - precision: 0.9894 - sensitivity: 0.9894 - specificity: 0.9965 - val_loss: 0.1985 - val_accuracy: 0.9847 - val_mean_io_u_3: 0.9680 - val_dice_coef: 0.8236 - val_precision: 0.9844 - val_sensitivity: 0.9844 - val_specificity: 0.9948 - lr: 4.0000e-06
# Epoch 23/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9896 - mean_io_u_3: 0.9706 - dice_coef: 0.8752 - precision: 0.9893 - sensitivity: 0.9893 - specificity: 0.9964
# Epoch 00023: val_loss improved from 0.19336 to 0.19334, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch23-val_loss0.193339_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1381 - accuracy: 0.9896 - mean_io_u_3: 0.9706 - dice_coef: 0.8752 - precision: 0.9893 - sensitivity: 0.9893 - specificity: 0.9964 - val_loss: 0.1933 - val_accuracy: 0.9854 - val_mean_io_u_3: 0.9678 - val_dice_coef: 0.8254 - val_precision: 0.9851 - val_sensitivity: 0.9851 - val_specificity: 0.9950 - lr: 1.0000e-06
# Epoch 24/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9897 - mean_io_u_3: 0.9681 - dice_coef: 0.8729 - precision: 0.9894 - sensitivity: 0.9894 - specificity: 0.9965
# Epoch 00024: val_loss improved from 0.19334 to 0.19125, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch24-val_loss0.191253_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 32ms/step - loss: 0.1442 - accuracy: 0.9897 - mean_io_u_3: 0.9681 - dice_coef: 0.8729 - precision: 0.9894 - sensitivity: 0.9894 - specificity: 0.9965 - val_loss: 0.1913 - val_accuracy: 0.9854 - val_mean_io_u_3: 0.9646 - val_dice_coef: 0.8270 - val_precision: 0.9851 - val_sensitivity: 0.9851 - val_specificity: 0.9950 - lr: 1.0000e-06
# Epoch 25/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9899 - mean_io_u_3: 0.9661 - dice_coef: 0.8737 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965
# Epoch 00025: val_loss did not improve from 0.19125
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1390 - accuracy: 0.9899 - mean_io_u_3: 0.9661 - dice_coef: 0.8737 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965 - val_loss: 0.1928 - val_accuracy: 0.9853 - val_mean_io_u_3: 0.9646 - val_dice_coef: 0.8269 - val_precision: 0.9850 - val_sensitivity: 0.9850 - val_specificity: 0.9950 - lr: 1.0000e-06
# Epoch 26/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9899 - mean_io_u_3: 0.9660 - dice_coef: 0.8781 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965
# Epoch 00026: val_loss improved from 0.19125 to 0.19089, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch26-val_loss0.190886_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 32ms/step - loss: 0.1372 - accuracy: 0.9899 - mean_io_u_3: 0.9660 - dice_coef: 0.8781 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965 - val_loss: 0.1909 - val_accuracy: 0.9855 - val_mean_io_u_3: 0.9632 - val_dice_coef: 0.8275 - val_precision: 0.9852 - val_sensitivity: 0.9852 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 27/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9898 - mean_io_u_3: 0.9651 - dice_coef: 0.8741 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965
# Epoch 00027: val_loss improved from 0.19089 to 0.19042, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch27-val_loss0.190421_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 32ms/step - loss: 0.1364 - accuracy: 0.9898 - mean_io_u_3: 0.9651 - dice_coef: 0.8741 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965 - val_loss: 0.1904 - val_accuracy: 0.9854 - val_mean_io_u_3: 0.9607 - val_dice_coef: 0.8264 - val_precision: 0.9851 - val_sensitivity: 0.9851 - val_specificity: 0.9950 - lr: 1.0000e-06
# Epoch 28/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9899 - mean_io_u_3: 0.9615 - dice_coef: 0.8749 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965
# Epoch 00028: val_loss did not improve from 0.19042
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1351 - accuracy: 0.9899 - mean_io_u_3: 0.9615 - dice_coef: 0.8749 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965 - val_loss: 0.1906 - val_accuracy: 0.9854 - val_mean_io_u_3: 0.9588 - val_dice_coef: 0.8266 - val_precision: 0.9851 - val_sensitivity: 0.9851 - val_specificity: 0.9950 - lr: 1.0000e-06
# Epoch 29/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9899 - mean_io_u_3: 0.9629 - dice_coef: 0.8747 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965
# Epoch 00029: val_loss improved from 0.19042 to 0.18958, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch29-val_loss0.189580_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 32ms/step - loss: 0.1353 - accuracy: 0.9899 - mean_io_u_3: 0.9629 - dice_coef: 0.8747 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965 - val_loss: 0.1896 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9577 - val_dice_coef: 0.8273 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 30/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9900 - mean_io_u_3: 0.9608 - dice_coef: 0.8804 - precision: 0.9896 - sensitivity: 0.9897 - specificity: 0.9965
# Epoch 00030: val_loss improved from 0.18958 to 0.18937, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch30-val_loss0.189375_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 32ms/step - loss: 0.1315 - accuracy: 0.9900 - mean_io_u_3: 0.9608 - dice_coef: 0.8804 - precision: 0.9896 - sensitivity: 0.9897 - specificity: 0.9965 - val_loss: 0.1894 - val_accuracy: 0.9855 - val_mean_io_u_3: 0.9593 - val_dice_coef: 0.8272 - val_precision: 0.9852 - val_sensitivity: 0.9852 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 31/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9900 - mean_io_u_3: 0.9620 - dice_coef: 0.8729 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965
# Epoch 00031: val_loss improved from 0.18937 to 0.18822, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch31-val_loss0.188219_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 32ms/step - loss: 0.1400 - accuracy: 0.9900 - mean_io_u_3: 0.9620 - dice_coef: 0.8729 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965 - val_loss: 0.1882 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9588 - val_dice_coef: 0.8280 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 32/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9899 - mean_io_u_3: 0.9600 - dice_coef: 0.8782 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965
# Epoch 00032: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1328 - accuracy: 0.9899 - mean_io_u_3: 0.9600 - dice_coef: 0.8782 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965 - val_loss: 0.1889 - val_accuracy: 0.9855 - val_mean_io_u_3: 0.9570 - val_dice_coef: 0.8277 - val_precision: 0.9852 - val_sensitivity: 0.9852 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 33/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9901 - mean_io_u_3: 0.9598 - dice_coef: 0.8779 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00033: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1337 - accuracy: 0.9901 - mean_io_u_3: 0.9598 - dice_coef: 0.8779 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1891 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9557 - val_dice_coef: 0.8274 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 34/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9900 - mean_io_u_3: 0.9607 - dice_coef: 0.8747 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965
# Epoch 00034: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1384 - accuracy: 0.9900 - mean_io_u_3: 0.9607 - dice_coef: 0.8747 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965 - val_loss: 0.1884 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9560 - val_dice_coef: 0.8271 - val_precision: 0.9853 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 35/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9901 - mean_io_u_3: 0.9584 - dice_coef: 0.8763 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00035: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1365 - accuracy: 0.9901 - mean_io_u_3: 0.9584 - dice_coef: 0.8763 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1890 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9530 - val_dice_coef: 0.8278 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 36/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9900 - mean_io_u_3: 0.9577 - dice_coef: 0.8732 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00036: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1380 - accuracy: 0.9900 - mean_io_u_3: 0.9577 - dice_coef: 0.8732 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1885 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9544 - val_dice_coef: 0.8284 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 37/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9901 - mean_io_u_3: 0.9575 - dice_coef: 0.8741 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00037: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1378 - accuracy: 0.9901 - mean_io_u_3: 0.9575 - dice_coef: 0.8741 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1883 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9542 - val_dice_coef: 0.8281 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 38/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9900 - mean_io_u_3: 0.9557 - dice_coef: 0.8764 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965
# Epoch 00038: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1356 - accuracy: 0.9900 - mean_io_u_3: 0.9557 - dice_coef: 0.8764 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965 - val_loss: 0.1886 - val_accuracy: 0.9855 - val_mean_io_u_3: 0.9537 - val_dice_coef: 0.8281 - val_precision: 0.9852 - val_sensitivity: 0.9852 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 39/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9901 - mean_io_u_3: 0.9584 - dice_coef: 0.8764 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00039: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1358 - accuracy: 0.9901 - mean_io_u_3: 0.9584 - dice_coef: 0.8764 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1894 - val_accuracy: 0.9855 - val_mean_io_u_3: 0.9540 - val_dice_coef: 0.8272 - val_precision: 0.9852 - val_sensitivity: 0.9852 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 40/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9901 - mean_io_u_3: 0.9576 - dice_coef: 0.8761 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00040: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1358 - accuracy: 0.9901 - mean_io_u_3: 0.9576 - dice_coef: 0.8761 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1884 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9525 - val_dice_coef: 0.8279 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 41/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9900 - mean_io_u_3: 0.9582 - dice_coef: 0.8755 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00041: val_loss did not improve from 0.18822
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1351 - accuracy: 0.9900 - mean_io_u_3: 0.9582 - dice_coef: 0.8755 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1884 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9547 - val_dice_coef: 0.8280 - val_precision: 0.9853 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 42/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9904 - mean_io_u_3: 0.9587 - dice_coef: 0.8794 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967
# Epoch 00042: val_loss improved from 0.18822 to 0.18792, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch42-val_loss0.187917_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1310 - accuracy: 0.9904 - mean_io_u_3: 0.9587 - dice_coef: 0.8794 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967 - val_loss: 0.1879 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9532 - val_dice_coef: 0.8283 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 43/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9900 - mean_io_u_3: 0.9557 - dice_coef: 0.8772 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965
# Epoch 00043: val_loss improved from 0.18792 to 0.18774, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch43-val_loss0.187741_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1341 - accuracy: 0.9900 - mean_io_u_3: 0.9557 - dice_coef: 0.8772 - precision: 0.9896 - sensitivity: 0.9896 - specificity: 0.9965 - val_loss: 0.1877 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9523 - val_dice_coef: 0.8280 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 44/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9902 - mean_io_u_3: 0.9567 - dice_coef: 0.8763 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966
# Epoch 00044: val_loss improved from 0.18774 to 0.18749, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch44-val_loss0.187491_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1351 - accuracy: 0.9902 - mean_io_u_3: 0.9567 - dice_coef: 0.8763 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966 - val_loss: 0.1875 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9518 - val_dice_coef: 0.8284 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 45/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9902 - mean_io_u_3: 0.9538 - dice_coef: 0.8790 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966
# Epoch 00045: val_loss did not improve from 0.18749
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1320 - accuracy: 0.9902 - mean_io_u_3: 0.9538 - dice_coef: 0.8790 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966 - val_loss: 0.1876 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9502 - val_dice_coef: 0.8280 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 46/200
# 849/850 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9901 - mean_io_u_3: 0.9531 - dice_coef: 0.8788 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00046: val_loss did not improve from 0.18749
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1304 - accuracy: 0.9901 - mean_io_u_3: 0.9531 - dice_coef: 0.8789 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1880 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9493 - val_dice_coef: 0.8278 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 47/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9903 - mean_io_u_3: 0.9541 - dice_coef: 0.8770 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00047: val_loss improved from 0.18749 to 0.18742, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch47-val_loss0.187418_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1339 - accuracy: 0.9903 - mean_io_u_3: 0.9541 - dice_coef: 0.8770 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.1874 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9491 - val_dice_coef: 0.8284 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 48/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9901 - mean_io_u_3: 0.9524 - dice_coef: 0.8775 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00048: val_loss improved from 0.18742 to 0.18716, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch48-val_loss0.187162_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1323 - accuracy: 0.9901 - mean_io_u_3: 0.9524 - dice_coef: 0.8775 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1872 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9471 - val_dice_coef: 0.8278 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 49/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9903 - mean_io_u_3: 0.9530 - dice_coef: 0.8813 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00049: val_loss improved from 0.18716 to 0.18705, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch49-val_loss0.187046_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1274 - accuracy: 0.9903 - mean_io_u_3: 0.9530 - dice_coef: 0.8813 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.1870 - val_accuracy: 0.9856 - val_mean_io_u_3: 0.9483 - val_dice_coef: 0.8285 - val_precision: 0.9853 - val_sensitivity: 0.9853 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 50/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9902 - mean_io_u_3: 0.9543 - dice_coef: 0.8782 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966
# Epoch 00050: val_loss improved from 0.18705 to 0.18669, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch50-val_loss0.186688_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1317 - accuracy: 0.9902 - mean_io_u_3: 0.9543 - dice_coef: 0.8782 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966 - val_loss: 0.1867 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9502 - val_dice_coef: 0.8283 - val_precision: 0.9854 - val_sensitivity: 0.9855 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 51/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9904 - mean_io_u_3: 0.9545 - dice_coef: 0.8815 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967
# Epoch 00051: val_loss improved from 0.18669 to 0.18613, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch51-val_loss0.186129_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1281 - accuracy: 0.9904 - mean_io_u_3: 0.9545 - dice_coef: 0.8815 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967 - val_loss: 0.1861 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9500 - val_dice_coef: 0.8288 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 52/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1276 - accuracy: 0.9903 - mean_io_u_3: 0.9535 - dice_coef: 0.8815 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00052: val_loss did not improve from 0.18613
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1276 - accuracy: 0.9903 - mean_io_u_3: 0.9535 - dice_coef: 0.8815 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.1862 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9502 - val_dice_coef: 0.8293 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 53/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9905 - mean_io_u_3: 0.9530 - dice_coef: 0.8855 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00053: val_loss did not improve from 0.18613
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1238 - accuracy: 0.9905 - mean_io_u_3: 0.9530 - dice_coef: 0.8855 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1869 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9483 - val_dice_coef: 0.8290 - val_precision: 0.9853 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 54/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9904 - mean_io_u_3: 0.9537 - dice_coef: 0.8842 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967
# Epoch 00054: val_loss did not improve from 0.18613
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1241 - accuracy: 0.9904 - mean_io_u_3: 0.9537 - dice_coef: 0.8842 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967 - val_loss: 0.1865 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9499 - val_dice_coef: 0.8289 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 55/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9907 - mean_io_u_3: 0.9522 - dice_coef: 0.8879 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00055: val_loss improved from 0.18613 to 0.18610, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch55-val_loss0.186098_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1193 - accuracy: 0.9907 - mean_io_u_3: 0.9522 - dice_coef: 0.8879 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1861 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9489 - val_dice_coef: 0.8286 - val_precision: 0.9853 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 56/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9905 - mean_io_u_3: 0.9534 - dice_coef: 0.8828 - precision: 0.9901 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00056: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1244 - accuracy: 0.9905 - mean_io_u_3: 0.9534 - dice_coef: 0.8828 - precision: 0.9901 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1872 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9523 - val_dice_coef: 0.8291 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 57/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9903 - mean_io_u_3: 0.9531 - dice_coef: 0.8795 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00057: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1295 - accuracy: 0.9903 - mean_io_u_3: 0.9531 - dice_coef: 0.8795 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.1863 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9499 - val_dice_coef: 0.8283 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 58/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9905 - mean_io_u_3: 0.9532 - dice_coef: 0.8802 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00058: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1279 - accuracy: 0.9905 - mean_io_u_3: 0.9532 - dice_coef: 0.8802 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1869 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9474 - val_dice_coef: 0.8283 - val_precision: 0.9853 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 59/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9904 - mean_io_u_3: 0.9540 - dice_coef: 0.8790 - precision: 0.9900 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00059: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1289 - accuracy: 0.9904 - mean_io_u_3: 0.9540 - dice_coef: 0.8790 - precision: 0.9900 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1864 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9470 - val_dice_coef: 0.8292 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 60/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9905 - mean_io_u_3: 0.9499 - dice_coef: 0.8794 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00060: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1297 - accuracy: 0.9905 - mean_io_u_3: 0.9499 - dice_coef: 0.8794 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1863 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9469 - val_dice_coef: 0.8290 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 61/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9903 - mean_io_u_3: 0.9523 - dice_coef: 0.8810 - precision: 0.9899 - sensitivity: 0.9900 - specificity: 0.9966
# Epoch 00061: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1281 - accuracy: 0.9903 - mean_io_u_3: 0.9523 - dice_coef: 0.8810 - precision: 0.9899 - sensitivity: 0.9900 - specificity: 0.9966 - val_loss: 0.1862 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9468 - val_dice_coef: 0.8288 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 62/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9905 - mean_io_u_3: 0.9513 - dice_coef: 0.8835 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00062: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1261 - accuracy: 0.9905 - mean_io_u_3: 0.9513 - dice_coef: 0.8835 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1862 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9471 - val_dice_coef: 0.8286 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 63/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9906 - mean_io_u_3: 0.9521 - dice_coef: 0.8809 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00063: val_loss did not improve from 0.18610
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1272 - accuracy: 0.9906 - mean_io_u_3: 0.9521 - dice_coef: 0.8809 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1863 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9487 - val_dice_coef: 0.8298 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 64/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9904 - mean_io_u_3: 0.9507 - dice_coef: 0.8839 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967
# Epoch 00064: val_loss improved from 0.18610 to 0.18581, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch64-val_loss0.185810_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1245 - accuracy: 0.9904 - mean_io_u_3: 0.9507 - dice_coef: 0.8839 - precision: 0.9900 - sensitivity: 0.9900 - specificity: 0.9967 - val_loss: 0.1858 - val_accuracy: 0.9857 - val_mean_io_u_3: 0.9456 - val_dice_coef: 0.8289 - val_precision: 0.9854 - val_sensitivity: 0.9854 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 65/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9906 - mean_io_u_3: 0.9478 - dice_coef: 0.8853 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00065: val_loss did not improve from 0.18581
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1224 - accuracy: 0.9906 - mean_io_u_3: 0.9478 - dice_coef: 0.8853 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1862 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9480 - val_dice_coef: 0.8290 - val_precision: 0.9854 - val_sensitivity: 0.9855 - val_specificity: 0.9951 - lr: 1.0000e-06
# Epoch 66/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9905 - mean_io_u_3: 0.9516 - dice_coef: 0.8805 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00066: val_loss improved from 0.18581 to 0.18538, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch66-val_loss0.185379_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1279 - accuracy: 0.9905 - mean_io_u_3: 0.9516 - dice_coef: 0.8805 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1854 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9477 - val_dice_coef: 0.8297 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 67/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9905 - mean_io_u_3: 0.9528 - dice_coef: 0.8783 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00067: val_loss improved from 0.18538 to 0.18521, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch67-val_loss0.185207_Apr-22_00-58-59.m5
# 850/850 [==============================] - 28s 33ms/step - loss: 0.1281 - accuracy: 0.9905 - mean_io_u_3: 0.9528 - dice_coef: 0.8783 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1852 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9465 - val_dice_coef: 0.8292 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 68/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9905 - mean_io_u_3: 0.9518 - dice_coef: 0.8842 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00068: val_loss did not improve from 0.18521
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1246 - accuracy: 0.9905 - mean_io_u_3: 0.9518 - dice_coef: 0.8842 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1857 - val_accuracy: 0.9858 - val_mean_io_u_3: 0.9475 - val_dice_coef: 0.8289 - val_precision: 0.9855 - val_sensitivity: 0.9855 - val_specificity: 0.9952 - lr: 1.0000e-06
# Epoch 69/200
# ...
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1099 - accuracy: 0.9917 - mean_io_u_3: 0.9617 - dice_coef: 0.8961 - precision: 0.9913 - sensitivity: 0.9913 - specificity: 0.9971 - val_loss: 0.1834 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9588 - val_dice_coef: 0.8318 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 177/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9920 - mean_io_u_3: 0.9629 - dice_coef: 0.8943 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00177: val_loss did not improve from 0.18269
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1124 - accuracy: 0.9920 - mean_io_u_3: 0.9629 - dice_coef: 0.8943 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1851 - val_accuracy: 0.9861 - val_mean_io_u_3: 0.9593 - val_dice_coef: 0.8324 - val_precision: 0.9858 - val_sensitivity: 0.9858 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 178/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9919 - mean_io_u_3: 0.9626 - dice_coef: 0.8963 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00178: val_loss did not improve from 0.18269
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1102 - accuracy: 0.9919 - mean_io_u_3: 0.9626 - dice_coef: 0.8963 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1837 - val_accuracy: 0.9861 - val_mean_io_u_3: 0.9572 - val_dice_coef: 0.8323 - val_precision: 0.9858 - val_sensitivity: 0.9858 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 179/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9919 - mean_io_u_3: 0.9623 - dice_coef: 0.8954 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972
# Epoch 00179: val_loss did not improve from 0.18269
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1103 - accuracy: 0.9919 - mean_io_u_3: 0.9623 - dice_coef: 0.8954 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972 - val_loss: 0.1836 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9579 - val_dice_coef: 0.8322 - val_precision: 0.9858 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 180/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9921 - mean_io_u_3: 0.9625 - dice_coef: 0.9014 - precision: 0.9916 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00180: val_loss did not improve from 0.18269
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1033 - accuracy: 0.9921 - mean_io_u_3: 0.9625 - dice_coef: 0.9014 - precision: 0.9916 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1831 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9585 - val_dice_coef: 0.8324 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 181/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9923 - mean_io_u_3: 0.9643 - dice_coef: 0.9011 - precision: 0.9918 - sensitivity: 0.9918 - specificity: 0.9973
# Epoch 00181: val_loss did not improve from 0.18269
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1031 - accuracy: 0.9923 - mean_io_u_3: 0.9643 - dice_coef: 0.9011 - precision: 0.9918 - sensitivity: 0.9918 - specificity: 0.9973 - val_loss: 0.1837 - val_accuracy: 0.9861 - val_mean_io_u_3: 0.9590 - val_dice_coef: 0.8322 - val_precision: 0.9858 - val_sensitivity: 0.9858 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 182/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9920 - mean_io_u_3: 0.9641 - dice_coef: 0.8957 - precision: 0.9915 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00182: val_loss did not improve from 0.18269
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1093 - accuracy: 0.9920 - mean_io_u_3: 0.9641 - dice_coef: 0.8957 - precision: 0.9915 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1832 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9578 - val_dice_coef: 0.8321 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 183/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9920 - mean_io_u_3: 0.9638 - dice_coef: 0.8970 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00183: val_loss improved from 0.18269 to 0.18251, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch183-val_loss0.182515_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1088 - accuracy: 0.9920 - mean_io_u_3: 0.9638 - dice_coef: 0.8970 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1825 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9563 - val_dice_coef: 0.8327 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 184/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9919 - mean_io_u_3: 0.9621 - dice_coef: 0.8955 - precision: 0.9914 - sensitivity: 0.9915 - specificity: 0.9971
# Epoch 00184: val_loss did not improve from 0.18251
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1094 - accuracy: 0.9919 - mean_io_u_3: 0.9621 - dice_coef: 0.8955 - precision: 0.9914 - sensitivity: 0.9915 - specificity: 0.9971 - val_loss: 0.1833 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9585 - val_dice_coef: 0.8341 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 185/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9921 - mean_io_u_3: 0.9633 - dice_coef: 0.8966 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00185: val_loss did not improve from 0.18251
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1086 - accuracy: 0.9921 - mean_io_u_3: 0.9633 - dice_coef: 0.8966 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1826 - val_accuracy: 0.9863 - val_mean_io_u_3: 0.9582 - val_dice_coef: 0.8328 - val_precision: 0.9860 - val_sensitivity: 0.9860 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 186/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9921 - mean_io_u_3: 0.9629 - dice_coef: 0.8981 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00186: val_loss did not improve from 0.18251
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1079 - accuracy: 0.9921 - mean_io_u_3: 0.9629 - dice_coef: 0.8981 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1829 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9568 - val_dice_coef: 0.8331 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 187/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1039 - accuracy: 0.9921 - mean_io_u_3: 0.9636 - dice_coef: 0.9003 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00187: val_loss did not improve from 0.18251
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1039 - accuracy: 0.9921 - mean_io_u_3: 0.9636 - dice_coef: 0.9003 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1838 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9603 - val_dice_coef: 0.8328 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 188/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9919 - mean_io_u_3: 0.9642 - dice_coef: 0.8912 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972
# Epoch 00188: val_loss did not improve from 0.18251
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1156 - accuracy: 0.9919 - mean_io_u_3: 0.9642 - dice_coef: 0.8912 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972 - val_loss: 0.1838 - val_accuracy: 0.9863 - val_mean_io_u_3: 0.9594 - val_dice_coef: 0.8329 - val_precision: 0.9859 - val_sensitivity: 0.9860 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 189/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9920 - mean_io_u_3: 0.9630 - dice_coef: 0.8968 - precision: 0.9915 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00189: val_loss improved from 0.18251 to 0.18232, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/model_epoch189-val_loss0.182320_Apr-22_00-58-59.m5
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1082 - accuracy: 0.9920 - mean_io_u_3: 0.9630 - dice_coef: 0.8968 - precision: 0.9915 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1823 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9570 - val_dice_coef: 0.8332 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 190/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9920 - mean_io_u_3: 0.9639 - dice_coef: 0.8956 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00190: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1105 - accuracy: 0.9920 - mean_io_u_3: 0.9639 - dice_coef: 0.8956 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1836 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9588 - val_dice_coef: 0.8329 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 191/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9922 - mean_io_u_3: 0.9627 - dice_coef: 0.9008 - precision: 0.9917 - sensitivity: 0.9918 - specificity: 0.9973
# Epoch 00191: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1032 - accuracy: 0.9922 - mean_io_u_3: 0.9627 - dice_coef: 0.9008 - precision: 0.9917 - sensitivity: 0.9918 - specificity: 0.9973 - val_loss: 0.1829 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9586 - val_dice_coef: 0.8327 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 192/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9920 - mean_io_u_3: 0.9637 - dice_coef: 0.8990 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00192: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1054 - accuracy: 0.9920 - mean_io_u_3: 0.9637 - dice_coef: 0.8990 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1825 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9585 - val_dice_coef: 0.8327 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 193/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9921 - mean_io_u_3: 0.9618 - dice_coef: 0.8992 - precision: 0.9916 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00193: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1052 - accuracy: 0.9921 - mean_io_u_3: 0.9618 - dice_coef: 0.8992 - precision: 0.9916 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1833 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9565 - val_dice_coef: 0.8331 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 194/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9922 - mean_io_u_3: 0.9645 - dice_coef: 0.8960 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00194: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1088 - accuracy: 0.9922 - mean_io_u_3: 0.9645 - dice_coef: 0.8960 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1834 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9596 - val_dice_coef: 0.8339 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 195/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9925 - mean_io_u_3: 0.9655 - dice_coef: 0.9010 - precision: 0.9920 - sensitivity: 0.9921 - specificity: 0.9973
# Epoch 00195: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1042 - accuracy: 0.9925 - mean_io_u_3: 0.9655 - dice_coef: 0.9010 - precision: 0.9920 - sensitivity: 0.9921 - specificity: 0.9973 - val_loss: 0.1838 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9589 - val_dice_coef: 0.8332 - val_precision: 0.9858 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 196/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9921 - mean_io_u_3: 0.9639 - dice_coef: 0.8995 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00196: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1053 - accuracy: 0.9921 - mean_io_u_3: 0.9639 - dice_coef: 0.8995 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1832 - val_accuracy: 0.9863 - val_mean_io_u_3: 0.9603 - val_dice_coef: 0.8340 - val_precision: 0.9859 - val_sensitivity: 0.9860 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 197/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.9921 - mean_io_u_3: 0.9643 - dice_coef: 0.8972 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00197: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1061 - accuracy: 0.9921 - mean_io_u_3: 0.9643 - dice_coef: 0.8972 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1836 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9597 - val_dice_coef: 0.8334 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 198/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9921 - mean_io_u_3: 0.9640 - dice_coef: 0.8983 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00198: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1054 - accuracy: 0.9921 - mean_io_u_3: 0.9640 - dice_coef: 0.8983 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1837 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9588 - val_dice_coef: 0.8331 - val_precision: 0.9858 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 199/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9922 - mean_io_u_3: 0.9651 - dice_coef: 0.8949 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972
# Epoch 00199: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1102 - accuracy: 0.9922 - mean_io_u_3: 0.9651 - dice_coef: 0.8949 - precision: 0.9917 - sensitivity: 0.9917 - specificity: 0.9972 - val_loss: 0.1839 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9607 - val_dice_coef: 0.8333 - val_precision: 0.9858 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06
# Epoch 200/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9920 - mean_io_u_3: 0.9645 - dice_coef: 0.8996 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00200: val_loss did not improve from 0.18232
# 850/850 [==============================] - 27s 32ms/step - loss: 0.1057 - accuracy: 0.9920 - mean_io_u_3: 0.9645 - dice_coef: 0.8996 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1825 - val_accuracy: 0.9862 - val_mean_io_u_3: 0.9594 - val_dice_coef: 0.8342 - val_precision: 0.9859 - val_sensitivity: 0.9859 - val_specificity: 0.9953 - lr: 1.0000e-06

# %% [markdown]
# #### 4 - 3: Plot the training process

# %%
import glob

training_log_filename = glob.glob(os.path.join(model_dir, 'training-*.log'))[0]
plt_filename = os.path.splitext(os.path.basename(training_log_filename))[0]
print(f'plt image will be saved in: {training_log_filename}\nwith name: {plt_filename}')
# Out:
# plt image will be saved in: /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-22_00-58-59/training-Apr-22_00-58-59.log
# with name: training-Apr-22_00-58-59

# %%
# Read the CSVlogger file that contains all our metrics (accuracy, loss, dice_coef, ...) of our training
history = pd.read_csv(training_log_filename, sep=',', engine='python')

# Plot training and validation metrics
fig, axs = plt.subplots(1, 3, figsize=(16, 8))
# fig, axs = plt.subplots(1, 4, figsize=(16, 8))

axs[0].plot(history['epoch'], history['accuracy'], 'b', label='Training Accuracy')
axs[0].plot(history['epoch'], history['val_accuracy'], 'r', label='Validation Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

axs[1].plot(history['epoch'], history['loss'], 'b', label='Training Loss')
axs[1].plot(history['epoch'], history['val_loss'], 'r', label='Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(history['epoch'], history['dice_coef'], 'b', label='Training dice coef')
axs[2].plot(history['epoch'], history['val_dice_coef'], 'r', label='Validation dice coef')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Dice Coefficient')
axs[2].legend()

# axs[3].plot(history['epoch'], history['mean_io_u'], 'b', label='Training mean IOU')
# axs[3].plot(history['epoch'], history['val_mean_io_u'], 'r', label='Validation mean IOU')
# axs[3].set_xlabel('Epoch')
# axs[3].set_ylabel('Mean IOU')
# axs[3].legend()

# Add space between subplots
plt.subplots_adjust(wspace=0.4)
plt.savefig(f'/home/cbel/Desktop/YIHAN/unet/plt/train/{plt_filename}.png', dpi=300)

plt.show()

# %% [markdown]
# ### Step 5 - Predict

# %%
PREDICT_PLT_DIR = f'/home/cbel/Desktop/YIHAN/unet/plt/predict/{model_dir.split("/home/cbel/Desktop/YIHAN/unet/model/")[1]}'
if not os.path.exists(PREDICT_PLT_DIR):
    os.makedirs(PREDICT_PLT_DIR)
    print(f"Dir {PREDICT_PLT_DIR} created.")
else:
    print(f"Dir {PREDICT_PLT_DIR} existed.")
# Out:
# Dir /home/cbel/Desktop/YIHAN/unet/plt/predict/model_v1_Apr-22_00-58-59 created.

# %%
import glob
import os

def find_latest_file(directory, pattern):
    search_pattern = os.path.join(directory, pattern)
    files = glob.glob(search_pattern)

    if not files:
        return None

    latest_file = max(files, key=os.path.getmtime)

    return latest_file

PATTERN = 'model_epoch*-val_loss*_*.m5.index'

latest_model_file = find_latest_file(f'{model_dir}', PATTERN)

latest_trained_model = os.path.splitext(os.path.splitext(os.path.basename(latest_model_file))[0])[0]

print(f'latest model file: {latest_trained_model}')
# Out:
# latest model file: model_epoch189-val_loss0.182320_Apr-22_00-58-59

# %%
# Compile a model and load our saved weights
from tensorflow.keras import Input

INPUT_LAYER = Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
KER_INIT = KER_INIT
DROPOUT = DROPOUT
LEARNING_RATE = LEARNING_RATE

best_saved_model = model_builders.get(MODEL_VERSION, unet_v1)(inputs=INPUT_LAYER, ker_init=KER_INIT, dropout=DROPOUT, kernel_size=KERNEL_SIZE)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity] )


best_saved_model.load_weights(f'{model_dir}/{latest_trained_model}.m5')
# Out:
# ****** using U-Net V1 ******

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '-t1c.nii.gz'
    flair_path = sample_path + '-t2f.nii.gz'
    #t1_path = sample_path + '_t1.nii'
    #t2_path = sample_path + '_t2.nii'
            
    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()
    
    # Create an empty array
    X = np.empty((VOLUME_SLICES_PLUS, IMG_SIZE, IMG_SIZE, 2))
    
    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES_PLUS):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
    # Send our images to the CNN model and return predicted segmentation 
    return best_saved_model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)
    print(f'random_sample: {random_sample}')
    
    # Get path of this patient
    random_sample_path = os.path.join(data_path_GLI_train_dir, random_sample, random_sample)
    print(f'random_sample_path: {random_sample_path}')
    
    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)
   
    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '-seg.nii.gz'
    seg = nib.load(seg_path).get_fdata()
    
    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    
    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    convert_all = all.astype(np.float32) if all.dtype == np.float16 else all
    convert_zero = zero.astype(np.float32) if zero.dtype == np.float16 else zero
    convert_first = first.astype(np.float32) if first.dtype == np.float16 else first
    convert_second = second.astype(np.float32) if second.dtype == np.float16 else second
    convert_third = third.astype(np.float32) if third.dtype == np.float16 else third

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')
    
    # Layers 1, 2, 3
    axstest[1].imshow(convert_all)
    axstest[1].set_title('Predicted Segmentation - all layers')
    
    # Layer 0
    axstest[2].imshow(convert_zero)
    axstest[2].set_title('Predicted Segmentation - layer 0')
    
    # Layer 1
    axstest[3].imshow(convert_first)
    axstest[3].set_title('Predicted Segmentation - layer 1')
    
    # Layer 2
    axstest[4].imshow(convert_second)
    axstest[4].set_title('Predicted Segmentation - layer 2')
    
    # Layer 3
    axstest[5].imshow(convert_third)
    axstest[5].set_title('Predicted Segmentation - layer 3')
    
    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.savefig(f'{PREDICT_PLT_DIR}/{random_sample}.png', dpi=300)

    plt.show()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# %%
show_predicted_segmentations(datas_test, 60, cmap, norm)
# Out:
# random_sample: BraTS-GLI-01403-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-01403-000/BraTS-GLI-01403-000
# 3/3 [==============================] - 0s 63ms/step
# Patient number:  BraTS-GLI-01403-000

# %%
show_predicted_segmentations(datas_test, 50, cmap, norm)
# Out:
# random_sample: BraTS-GLI-00729-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-00729-000/BraTS-GLI-00729-000
# 3/3 [==============================] - 0s 63ms/step
# Patient number:  BraTS-GLI-00729-000

# %%
show_predicted_segmentations(datas_test, 70, cmap, norm)
# Out:
# random_sample: BraTS-GLI-01342-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-01342-000/BraTS-GLI-01342-000
# 3/3 [==============================] - 0s 62ms/step
# Patient number:  BraTS-GLI-01342-000

# %%
def show_post_processed_segmentations(sample, slice_to_plot, cmap, norm):
    
    # Get path of this patient
    sample_path = os.path.join(data_path_GLI_train_dir, sample, sample)
    
    # Predict patient's segmentation
    predicted_seg = predict_segmentation(sample_path)
   
    # Load patient's original segmentation (Ground truth)
    seg_path = sample_path + '-seg.nii.gz'
    seg = nib.load(seg_path).get_fdata()
    
    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    
    # Fix 4 to 3 to have the same values as in the predicted segmentation, and then same colors
    seg[seg==4] = 3
    
    # Remove background layer (0) from original segmentation
    seg[seg==0] = np.nan
    
    # Post-processing
    # Get indexes for each class of the highest probability pixels. Array will then contain only [0 1 2 3] instead of probabilities
    my_pred = np.argmax(predicted_seg, axis=3)
    my_pred = my_pred[slice_to_plot, :, :]

    # Remove background layer (0) from post-processed predicted segmentation
    # To fix 0 to np.nan, we need to convert array as a float
    my_pred = my_pred.astype(float)
    my_pred[my_pred == 0] = np.nan

    # Remove background layer (0) from classical predicted segmentation
    all = predicted_seg[slice_to_plot,:,:,1:4] 

    convert_all = all.astype(np.float32) if all.dtype == np.float16 else all
    
    # Plot Original segmentation & predicted segmentation without processing & predicted segmentation
    print("Patient number: ", sample)
    fig, axstest = plt.subplots(1, 3, figsize=(15, 10))

    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')
    
    axstest[1].imshow(convert_all)
    axstest[1].set_title('Prediction (w/o post processing (layer 1,2,3)')
    
    axstest[2].imshow(my_pred, cmap, norm)
    axstest[2].set_title('Prediction (w/ post processing (layer 1,2,3)')
    
    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)
    plt.savefig(f'{PREDICT_PLT_DIR}/{sample}.png', dpi=300)
    
    plt.show()

# %%
show_post_processed_segmentations(sample = "BraTS-GLI-00777-000", slice_to_plot=60, cmap=cmap, norm=norm)
# Out:
# 3/3 [==============================] - 0s 63ms/step
# Patient number:  BraTS-GLI-00777-000

# %%
show_post_processed_segmentations(sample = "BraTS-GLI-00675-000", slice_to_plot=50, cmap=cmap, norm=norm)
# Out:
# 3/3 [==============================] - 0s 63ms/step
# Patient number:  BraTS-GLI-00675-000

# %% [markdown]
# ### Step 6 - Evaluate the model

# %%
import sys
# Evaluate the model on the test data
test_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(TEST_PKL if DATA_GENERATOR_VERSION == 3 else datas_test)
results = best_saved_model.evaluate(test_generator, batch_size=200, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

print("\nModel evaluation on the test set:")

original_stdout = sys.stdout
with open(f'{model_dir}/predict_result.log', 'w') as predict_log_file:
    sys.stdout = predict_log_file

    # Display each metric with its description
    print("==================================")
    for i, (metric, description) in enumerate(results_list):
        print(f"{description} : {round(metric, 4)}")
    print("==================================")

sys.stdout = original_stdout
# Out:
# ------ usging Data Generator V3: use crop NIIs ------
# 551/551 [==============================] - 5s 8ms/step - loss: 0.2580 - accuracy: 0.9856 - mean_io_u_4: 0.9588 - dice_coef: 0.8088 - precision: 0.9852 - sensitivity: 0.9853 - specificity: 0.9951
#
# Model evaluation on the test set:
