# %% [markdown]
# <div style="border-left: 5px solid green; padding: 10px; background-color:rgb(224, 247, 206);">
#     <b>⚡️ Information:</b>
#     Yihan's customized unet experiment
# </div>

# %% [markdown]
# ### Step 0 - Set & Check available memory

# %%
import tensorflow as tf
MEMORY_SIZE = 18
memory_limit = MEMORY_SIZE * 1024

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]  # Set limit to 15GB
        )
        print(f"Limited GPU memory usage to {MEMORY_SIZE}GB")
    except RuntimeError as e:
        print(e)
# Out:
# Limited GPU memory usage to 18GB

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for i, gpu in enumerate(gpus):
        device_name = f"GPU:{i}"  # Properly format the device name
        details = tf.config.experimental.get_memory_info(device_name)
        print(f"GPU: {device_name}")
        print(f"Current Memory Usage: {details['current']} bytes")
        print(f"Peak Memory Usage: {details['peak']} bytes")
else:
    print("No GPU devices found.")

for gpu in gpus:
    print(f"Memory growth for {gpu}: {tf.config.experimental.get_memory_growth(gpu)}")
# Out:
# GPU: GPU:0
# Current Memory Usage: 0 bytes
# Peak Memory Usage: 0 bytes
# Memory growth for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): None

# %% [markdown]
# ### Step 1 - Set up environment

# %%
import nibabel as nib
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from skimage.transform import rotate
from skimage.util import montage
import os
from sklearn.model_selection import train_test_split
import keras
import cv2
import tensorflow
import random
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import numpy as np
from keras.callbacks import CSVLogger
import keras.backend as K
import zipfile
import pandas as pd

# %% [markdown]
# #### paths, VOLUME_*, IMG_SIZE, N_CHANNELS

# %%
# Specify a sample path (here we will take the first patient of the Training dataset)
brats_index = 'BraTS-GLI-00077-000'
brats_sample_path = f'../brain_tumor_seg/data/raw_data/GLI_train/{brats_index}/{brats_index}-'

# Specify the root data path of training data
# data_path_GLI_train_dir = f'../brain_tumor_seg/data/raw_data/GLI_train'
data_path_GLI_train_dir = f'/home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train'


# Define selected slices range
VOLUME_START_AT = 40 
VOLUME_SLICES_PLUS = 76 
TUMOR_RATIO_LOWER_BOUND = 0.1
TUMOR_RATIO_UPPER_BOUND = 0.15

# For DataGenerator
IMG_SIZE = 256
N_CHANNELS = 2

# %% [markdown]
# ### Not a Step - Explore data

# %%
# Load the 4 MRI modalities and the segmentation located in the patient's path using the nibabel library
t1_img_sample=nib.load(brats_sample_path + 't1n.nii.gz')
t1ce_img_sample=nib.load(brats_sample_path + 't1c.nii.gz')
t2_img_sample=nib.load(brats_sample_path + 't2w.nii.gz')
flair_img_sample=nib.load(brats_sample_path + 't2f.nii.gz')
seg_img_sample=nib.load(brats_sample_path + 'seg.nii.gz')

# Get the image data
t1_data_sample = t1_img_sample.get_fdata()
t1ce_data_sample = t1ce_img_sample.get_fdata()
t2_data_sample = t2_img_sample.get_fdata()
flair_data_sample = flair_img_sample.get_fdata()
seg_data_sample = seg_img_sample.get_fdata()

# Plot the 100th slice of the 4 RMI modalities and the segmentation
slice_nb = 100

fig, axs = plt.subplots(1, 5, figsize=(20,20))
axs[0].imshow(t1_data_sample[:,:,slice_nb], cmap="gray")
axs[0].set_title('T1')
axs[1].imshow(t1ce_data_sample[:,:,slice_nb], cmap="gray")
axs[1].set_title('T1CE')
axs[2].imshow(t2_data_sample[:,:,slice_nb], cmap="gray")
axs[2].set_title('T2')
axs[3].imshow(flair_data_sample[:,:,slice_nb], cmap="gray")
axs[3].set_title('FLAIR')
axs[4].imshow(seg_data_sample[:,:,slice_nb], cmap="gray")
axs[4].set_title('Segmentation')
plt.savefig(f'./plt/seg_classes_{brats_index}.png', dpi=300)
plt.show()

# %%
# Plot a RMI modality through all planes
slice_nb = 100

fig, axs2 = plt.subplots(1, 3, figsize=(10,10))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
axs2[0].imshow(rotate(t1_data_sample[slice_nb,:,:], 90, resize=True), cmap="gray")
axs2[0].set_title('T1 - Sagittal View')

axs2[1].imshow(rotate(t1_data_sample[:,slice_nb,:], 90, resize=True), cmap="gray")
axs2[1].set_title('T1 - Coronal View')

axs2[2].imshow(t1_data_sample[:,:,slice_nb], cmap="gray")
axs2[2].set_title('T1 - Axial View')

plt.show()

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data_sample[:,:,:]), 90, resize=True), cmap ='gray')

# montage allows us to concatenate multiple images of the same size horizontally and vertically

# %%
# Display all slices of a segmentation
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(seg_data_sample[:,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data_sample[60:135,:,:]), 90, resize=True), cmap ='gray')

# %%
# Plot a segmantation
some_seg_img = nib.load(f'{brats_sample_path}seg.nii.gz').get_fdata()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

plt.imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
plt.title(brats_index)
plt.colorbar()

# %%
seg_samples = [os.path.join(data_path_GLI_train_dir, sample, f"{sample}-seg.nii.gz") for sample in os.listdir(data_path_GLI_train_dir) if not sample.endswith('.csv')]

saved_values = []
max_nb_values = 0
for sample in seg_samples:
    seg_img_sample = nib.load(sample).get_fdata()
    unique_values = np.unique(seg_img_sample)
    nb_unique_values = len(np.unique(seg_img_sample))
    
    if nb_unique_values > max_nb_values:
        max_nb_values = nb_unique_values
        saved_values = unique_values

print(f"Maximum number of values in all segmentation images: {max_nb_values}")
print(f"Values: {saved_values}")

# %%
# Deletion of class 0
seg_0 = some_seg_img.astype(float).copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = some_seg_img.astype(float).copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = some_seg_img.astype(float).copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_3 = some_seg_img.astype(float).copy()
seg_3[seg_3 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 3']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, axs3 = plt.subplots(1, 5, figsize=(15, 15))

axs3[0].imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
axs3[0].set_title('Original Segmentation')
axs3[0].legend(handles=legend, loc='upper right')

axs3[1].imshow(seg_0[100,:,:], cmap=cmap, norm=norm)
axs3[1].set_title('[Not Tumor] class 0')

axs3[2].imshow(seg_1[100,:,:], cmap=cmap, norm=norm)
axs3[2].set_title('[NCR] class 1')

axs3[3].imshow(seg_2[100,:,:], cmap=cmap, norm=norm)
axs3[3].set_title('[ED] class 2')

axs3[4].imshow(seg_3[100,:,:], cmap=cmap, norm=norm)
axs3[4].set_title('[ET] class 3')

# Save the figure to a file
plt.savefig('segmentation_classes.png', dpi=300)  # Saves the image as 'segmentation_classes.png'

plt.show()

# %%
values, counts = np.unique(some_seg_img, return_counts=True)
print(f'distribution of 4 classes: {counts}')

# %%
# Modality shape
print(f'modality shape: {t1_data_sample.shape}')

# Segmentation shape
print(f'segmentation shape: {seg_data_sample.shape}')

# %% [markdown]
# ### Step 2 - Load images and parameters

# %%
# Retrieve all samples from path with listdir(). This method lists of all files + directories in the specified directory.
all_datas = os.listdir(data_path_GLI_train_dir)
print("Number of samples:", len(all_datas))
# Out:
# Number of samples: 1251

# %%
# Split the dataset into train and validation sets
datas_train, datas_val = train_test_split(all_datas, test_size=0.189, random_state=42)

# Split the train set into the real train set and in a test set 
datas_train, datas_test = train_test_split(datas_train, test_size=0.065, random_state=42)

# Print data distribution (Train: 68%, Test: 12%, Val: 20%)
print(f"Train length: {len(datas_train)}")
print(f"Validation length: {len(datas_val)}")
print(f"Test length: {len(datas_test)}")
# Out:
# Train length: 948
# Validation length: 237
# Test length: 66

# %%
pip show keras tensorflow # type: ignore
# Out:
# Name: keras
# Version: 2.7.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /home/cbel/Desktop/YIHAN/venv/lib/python3.8/site-packages
# Requires:
# Required-by: tensorflow
# ---
# Name: tensorflow
# Version: 2.7.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /home/cbel/Desktop/YIHAN/venv/lib/python3.8/site-packages
# Requires: grpcio, wheel, numpy, astunparse, termcolor, keras-preprocessing, h5py, opt-einsum, typing-extensions, libclang, six, tensorflow-io-gcs-filesystem, flatbuffers, keras, wrapt, tensorflow-estimator, gast, protobuf, tensorboard, absl-py, google-pasta
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print("===============================")
print(f'tensorflow version: {tf.__version__}')  # Should print 2.7.0
print(f'is built with CUDA: {tf.test.is_built_with_cuda()}')  # Should return True
print(f'GPU details: {tf.config.list_physical_devices("GPU")}')  # Should show GPU details

# Check if TensorFlow can detect a GPU
if tf.config.list_physical_devices('GPU'):
    print("GPU is available.")
else:
    print("GPU is not available.")

print("===============================")
# Out:
# ===============================
# tensorflow version: 2.7.0
# is built with CUDA: True
# GPU details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU is available.
# ===============================

# %% [markdown]
# ### Skip if no need - combine existing pkl

# %%
import pickle
import csv

DATA_1_DIR = 'processed_data_0.05_0.1'
DATA_2_DIR = 'processed_data_0.1_0.25'
COMBINED_DATA_DIR = 'processed_data_0.05_0.25'
SET = 'test'


with open(f'./data/{DATA_1_DIR}/processed_{SET}_data.pkl', 'rb') as f:
    data1 = pickle.load(f)
with open(f'./data/{DATA_2_DIR}/processed_{SET}_data.pkl', 'rb') as f:
    data2 = pickle.load(f)
combined_data = data1.copy()
combined_data.update(data2)
with open(f'./data/{COMBINED_DATA_DIR}/processed_{SET}_data.pkl', 'wb') as f:
    pickle.dump(combined_data, f)


with open(f'./data/{DATA_1_DIR}/{SET}_data_info.csv', 'r') as csv1, open(f'./data/{DATA_2_DIR}/{SET}_data_info.csv', 'r') as csv2:
    reader1 = csv.reader(csv1)
    reader2 = csv.reader(csv2)

    with open(f'./data/{COMBINED_DATA_DIR}/{SET}_data_info.csv', 'w', newline='') as csv_out:
        writer = csv.writer(csv_out)
        for row in reader1:
            writer.writerow(row)
        next(reader2)
        for row in reader2:
            writer.writerow(row)

# %% [markdown]
# ### Step * Crop Nii files

# %% [markdown]
# #### Step * - 1: Set up params & crop method

# %%
import nibabel as nib

# Load the NIfTI files
seg_path = '/home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-00000-000/BraTS-GLI-00000-000-seg.nii.gz'
t2f_path = '/home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2f.nii.gz'

seg_img = nib.load(seg_path)
t2f_img = nib.load(t2f_path)

# Get voxel dimensions (in mm)
seg_voxel_dims = seg_img.header.get_zooms()
t2f_voxel_dims = t2f_img.header.get_zooms()

print("Segmentation Voxel Dimensions (mm):", seg_voxel_dims)
print("T2F Voxel Dimensions (mm):", t2f_voxel_dims)

# Get the shape of the images
seg_shape = seg_img.shape
t2f_shape = t2f_img.shape

# Calculate the physical size (in mm)
seg_physical_size = [s * v for s, v in zip(seg_shape, seg_voxel_dims)]
t2f_physical_size = [s * v for s, v in zip(t2f_shape, t2f_voxel_dims)]

print("Segmentation Physical Size (mm):", seg_physical_size)
print("T2F Physical Size (mm):", t2f_physical_size)
# Out:
# Segmentation Voxel Dimensions (mm): (1.0, 1.0, 1.0)
# T2F Voxel Dimensions (mm): (1.0, 1.0, 1.0)
# Segmentation Physical Size (mm): [240.0, 240.0, 155.0]
# T2F Physical Size (mm): [240.0, 240.0, 155.0]

# %%
import pickle
import os
import nibabel as nib
import cv2
import numpy as np
import csv

total_slices_dict = {
    "train": 0,
    "val": 0,
    "test": 0
}

def preprocess_and_save(data_list, save_path, log_path, tumor_ratio_lower_bound, tumor_ratio_upper_bound):
    processed_data = {'X': [], 'y': []}
    slice_info = {}  # Dictionary to store slice information for each NIfTI

    with open(log_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['NIfTI ID', 'Slice Index', 'Tumor Ratio', 'Tumor Area (in pixel)', 'Brain Area (in pixel)', 'Tumor Area (in mm)', 'Brain Area (in mm)'])

        total_slices = 0

        for i in data_list:
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()

            # get voxel dimension in mm
            seg_voxel_dims = nib.load(seg_path).header.get_zooms()
            t1ce_voxel_dims = nib.load(t1ce_path).header.get_zooms()

            slice_info[i] = []  # Initialize list for each NIfTI

            for j in range(VOLUME_SLICES_PLUS):
                slice_seg = seg[:, :, j + VOLUME_START_AT]
                slice_flair = flair[:, :, j + VOLUME_START_AT]
                tumor_area = np.sum(slice_seg > 0)
                brain_area = np.sum(slice_flair > 0)  # Use non-zero pixels in FLAIR as brain area

                # Avoid division by zero
                if brain_area == 0:
                    continue

                tumor_percentage = tumor_area / brain_area

                if tumor_ratio_lower_bound < tumor_percentage <= tumor_ratio_upper_bound:
                    X_slice = np.zeros((IMG_SIZE, IMG_SIZE, N_CHANNELS))
                    X_slice[:, :, 0] = cv2.resize(slice_flair, (IMG_SIZE, IMG_SIZE))
                    X_slice[:, :, 1] = cv2.resize(t1ce[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                    processed_data['X'].append(X_slice)
                    processed_data['y'].append(slice_seg)
                    slice_info[i].append(j + VOLUME_START_AT)  # Record the slice index

                    # calculate actual tumor area in mm
                    seg_voxel_area = seg_voxel_dims[0] * seg_voxel_dims[1]
                    actual_tumor_area = tumor_area * seg_voxel_area
                    t1ce_voxel_area = t1ce_voxel_dims[0] * t1ce_voxel_dims[1]
                    actual_brain_area = brain_area * t1ce_voxel_area

                    # Write slice information to CSV file
                    csv_writer.writerow([i, j + VOLUME_START_AT, round(tumor_percentage, 4), tumor_area, brain_area, actual_tumor_area, actual_brain_area])
                    total_slices += 1

        total_slices_dict[log_path.split('/')[-1].split('_')[0]] = total_slices

    # Save the processed data
    with open(save_path, 'wb') as f:
        pickle.dump(processed_data, f)

def count_rows_in_csv(file_path):
    with open(file_path, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader, None)
        row_count = sum(1 for row in reader)
    return row_count

# %%
import csv
import os

def append_to_csv(file_path, data, header=None):
    file_exists = os.path.isfile(file_path)

    with open(file_path, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        if header and not file_exists:
            writer.writerow(header)
        writer.writerows(data)

# %% [markdown]
# #### Step * - 2: Crop

# %%
from datetime import datetime
import gc

processed_data_dir_root = f'/home/cbel/Desktop/YIHAN/unet/data/dimension_{IMG_SIZE}/processed_data_{TUMOR_RATIO_LOWER_BOUND}_{TUMOR_RATIO_UPPER_BOUND}'
processed_data_lists_csv = f'/home/cbel/Desktop/YIHAN/unet/data/dimension_{IMG_SIZE}/processed_data_lists.csv'
processed_data_lists_header = ['tumor_ratio_lower_bound', 'tumor_ratio_upper_bound', 'train_slices', 'val_slices', 'test_slices', 'generated_timestamp']

print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')

if not os.path.exists(processed_data_dir_root):
    os.makedirs(processed_data_dir_root)
    print(f"dir processed_data '{processed_data_dir_root}' created.")

    preprocess_and_save(datas_train, f'{processed_data_dir_root}/processed_train_data.pkl', f'{processed_data_dir_root}/train_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()
    preprocess_and_save(datas_val, f'{processed_data_dir_root}/processed_val_data.pkl', f'{processed_data_dir_root}/val_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()
    preprocess_and_save(datas_test, f'{processed_data_dir_root}/processed_test_data.pkl', f'{processed_data_dir_root}/test_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()

    processed_data_lists_data = [
        [TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND, total_slices_dict["train"], total_slices_dict["val"], total_slices_dict["test"], datetime.now().strftime("%b-%d_%H-%M-%S")]
    ]
    append_to_csv(processed_data_lists_csv, processed_data_lists_data, processed_data_lists_header)

else:
    print(f'dir processed_data existed at {processed_data_dir_root}.')

# set the data info to params
TRAIN_PKL = f'{processed_data_dir_root}/processed_train_data.pkl'
VAL_PKL = f'{processed_data_dir_root}/processed_val_data.pkl'
TEST_PKL = f'{processed_data_dir_root}/processed_test_data.pkl'
TRAIN_PKL_CSV = f'{processed_data_dir_root}/train_data_info.csv'
VAL_PKL_CSV = f'{processed_data_dir_root}/val_data_info.csv'
TEST_PKL_CSV = f'{processed_data_dir_root}/test_data_info.csv'
total_slices_dict.update({
    "train": count_rows_in_csv(TRAIN_PKL_CSV),
    "val": count_rows_in_csv(VAL_PKL_CSV),
    "test": count_rows_in_csv(TEST_PKL_CSV)
})

print(f'train: {total_slices_dict["train"]} slices')
print(f'val: {total_slices_dict["val"]} slices')
print(f'test: {total_slices_dict["test"]} slices')
# Out:
# tumor ratio: 0.1 ~ 0.15
# dir processed_data existed at /home/cbel/Desktop/YIHAN/unet/data/dimension_256/processed_data_0.1_0.15.
# train: 11370 slices
# val: 2645 slices
# test: 795 slices

# %% [markdown]
# ### Step 3 - Set up training compoenents

# %% [markdown]
# **When generating `DataGenerator`**:
# - We use a data generator to be able to process and send our data to our neural network (since all our images cannot be stored in memory at once).
# - For each epoch (single pass of the entire training dataset through a neural network), the model will receive 250 samples (those contained in our training dataset).
# - For each sample, the model will have to analyze 150 slices (since there are two modalities, and 75(VOLUME_SLICES) selected slices for both of them), received in a (128, 128) shape, as an X array of a (128, 128, 75, 2) shape. This array will be provided with the ground truth segmentation of the patient, which will be One-Hot encoded and will then have a (75, 128, 128, 4) shape.

# %% [markdown]
# #### 3 - 1: DataGenerator

# %% [markdown]
# ##### 3-1-1 DataGenerator_UnetV1

# %%
from tensorflow.keras import layers, models

# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net

class DataGenerator_UnetV1(keras.utils.all_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = N_CHANNELS, shuffle=True):
        print('------ usging Data Generator V1 ------')
        'Initialization'
        self.dim = dim # Resized image dimensions (128 x 128)
        self.batch_size = batch_size #  Number of images to load each time
        self.list_IDs = list_IDs # Patients IDs
        self.n_channels = n_channels # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle # Indicates if data is shuffled for each epoch
        self.on_epoch_end() # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):
            
            # Get path of each RMI modality and the segmentation
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            #t1_path = sample_path + '_t1.nii.gz'
            #t2_path = sample_path + '_t2.nii.gz'
            
            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()
        
            for j in range(VOLUME_SLICES_PLUS):
                 X[j +VOLUME_SLICES_PLUS*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                 X[j +VOLUME_SLICES_PLUS*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES_PLUS*c] = seg[:,:,j+VOLUME_START_AT]
                    
        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %% [markdown]
# ##### 3-1-2 DataGenerator_UnetV2

# %%
from tensorflow.keras import layers, models

# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net

class DataGenerator_UnetV2(keras.utils.all_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = N_CHANNELS, shuffle=True):
        print('------ usging Data Generator V2 ------')
        'Initialization'
        self.dim = dim # Resized image dimensions (128 x 128)
        self.batch_size = batch_size #  Number of images to load each time
        self.list_IDs = list_IDs # Patients IDs
        self.n_channels = n_channels # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle # Indicates if data is shuffled for each epoch
        self.on_epoch_end() # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):
            
            # Get path of each RMI modality and the segmentation
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            #t1_path = sample_path + '_t1.nii.gz'
            #t2_path = sample_path + '_t2.nii.gz'
            
            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()
        
            for j in range(VOLUME_SLICES_PLUS):
                 X[j +VOLUME_SLICES_PLUS*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES_PLUS*c] = seg[:,:,j+VOLUME_START_AT]
                    
        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %% [markdown]
# ##### 3-1-3 DataGenerator_UnetV3_count_image_ratio

# %%
from tensorflow.keras import layers, models

class DataGenerator_UnetV3_count_image_ratio(keras.utils.all_utils.Sequence):
    def __init__(self, data_path, batch_size=1, shuffle=True):
        print('------ usging Data Generator V3: use crop NIIs ------')
        with open(data_path, 'rb') as f:
            self.data = pickle.load(f)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.data['X']))
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.data['X']) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        X_batch = [self.data['X'][k] for k in indexes]
        y_batch = [self.data['y'][k] for k in indexes]

        y_batch = np.array(y_batch)
        y_batch[y_batch == 4] = 3
        mask = tensorflow.one_hot(y_batch, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))

        return np.array(X_batch) / np.max(X_batch), Y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# #### 3 -2: U-Net model

# %% [markdown]
# ##### 3-2-1 U-Net v1

# %%
# U-Net implementation for BraTS 2019 by Naomi Fridman, https://naomi-fridman.medium.com/multi-class-image-segmentation-a5cc671e647a
def unet_v1(inputs, ker_init, dropout, kernel_size=3):
    print('****** using U-Net V1 ******')
    conv1 = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)
    
    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    
    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    conv10 = Conv2D(4, 1, activation = 'softmax')(conv)
    
    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# ##### 3-2-2: U-Net V2

# %%
def unet_v2(inputs, ker_init, dropout=0.5, kernel_size=3):
    print('****** using U-Net V2 ******')
    conv1 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool3)
    conv4 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv4)
    drop4 = Dropout(dropout)(conv4)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
    conv5 = Conv2D(1024, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(1024, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge6)
    conv6 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    conv9 = Conv2D(2, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    conv10 = Conv2D(4, 1, activation = 'sigmoid')(conv9)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# #### 3 - 3: Loss Functions

# %%
def categorical_dice_loss(y_true, y_pred, smooth=1e-6):
    intersection = K.sum(y_true * y_pred, axis=[0,1,2])
    union = K.sum(y_true, axis=[0,1,2]) + K.sum(y_pred, axis=[0,1,2])
    dice_loss = 1 - K.mean((2. * intersection + smooth) / (union + smooth))
    return dice_loss

def focal_loss(alpha=0.25, gamma=2.0):
    def loss(y_true, y_pred):
        ce = tf.keras.losses.CategoricalCrossentropy()(y_true, y_pred)
        pt = tf.exp(-ce)  # 計算 p_t
        focal_loss = alpha * (1 - pt) ** gamma * ce
        return focal_loss
    return loss

def focal_dice_loss(y_true, y_pred):
    return focal_loss()(y_true, y_pred) + categorical_dice_loss(y_true, y_pred)

# %% [markdown]
# #### 3 - 4: Metrics

# %%
# Compute metric between the predicted segmentation and the ground truth
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

########################### my customized metrics ###########################

def sensibility(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Calculate the sensibility
    sensibility = 1 - (false_positives / (true_positives + possible_positives + K.epsilon()))
    # Check for NaN or Inf values and return NaN if True
    sensibility = tf.where(tf.math.is_nan(sensibility) | tf.math.is_inf(sensibility),
                           tf.constant(float('NaN')),
                           sensibility)
    return sensibility


def jaccard(y_true, y_pred):
    # True positives, false positives, false negatives
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)))
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)))
    # Calculate Jaccard index
    denominator = true_positives + false_positives + false_negatives + K.epsilon()  # Add epsilon to avoid division by zero
    result = true_positives / denominator
    # Handle NaN or Inf cases
    result = K.switch(K.is_inf(result) | K.is_nan(result), K.constant(float('NaN')), result)
    return result


# Hausdorff distance (approximation for use in Keras)
def hausdorff(y_true, y_pred):
    # Flatten the coordinates of the true and predicted segmentation masks
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    # Compute the Euclidean distance between every pair of points
    dist_matrix = K.square(y_true_flat - y_pred_flat)
    # Get the maximum distance in both directions (directed Hausdorff)
    directed_hausdorff_1 = K.max(dist_matrix, axis=1)  # From y_true to y_pred
    directed_hausdorff_2 = K.max(dist_matrix, axis=0)  # From y_pred to y_true
    # Take the maximum of both directed Hausdorff distances
    hausdorff_dist = K.maximum(directed_hausdorff_1, directed_hausdorff_2)
    # Handle NaN or Inf values by replacing them with NaN (if needed)
    hausdorff_dist = K.switch(K.is_inf(hausdorff_dist) | K.is_nan(hausdorff_dist), K.constant(float('NaN')), hausdorff_dist)
    return hausdorff_dist

# %% [markdown]
# #### 3 - 5: Define training params

# %%
from keras import Input

MODEL_VERSION = 1
DATA_GENERATOR_VERSION = 3

EPOCHS = 200
STEPS_PER_EPOCH = len(datas_train)

INPUT_LAYER = Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
KER_INIT = 'he_normal'
DROPOUT = 0.2
KERNEL_SIZE = 1
LEARNING_RATE = 1e-4
# LOSS_FUNCTION = "categorical_crossentropy"
LOSS_FUNCTION = focal_dice_loss

# %% [markdown]
# #### 3 - 6: Build the model

# %%
# Build and compile the model
model_builders = {
    1: unet_v1,
    2: unet_v2
}
model = model_builders.get(MODEL_VERSION, unet_v1)(inputs=INPUT_LAYER, ker_init=KER_INIT, dropout=DROPOUT, kernel_size=KERNEL_SIZE)

model.compile(loss=LOSS_FUNCTION, optimizer=tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity ] )
# Out:
# ****** using U-Net V1 ******

# %% [markdown]
# #### 3 - 7: Set up DataGenerator

# %%
data_generators = {
    1: DataGenerator_UnetV1,
    2: DataGenerator_UnetV2,
    3: DataGenerator_UnetV3_count_image_ratio
}

training_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(TRAIN_PKL if DATA_GENERATOR_VERSION == 3 else datas_train)
valid_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(VAL_PKL if DATA_GENERATOR_VERSION == 3 else datas_val)
# Out:
# ------ usging Data Generator V3: use crop NIIs ------
# ------ usging Data Generator V3: use crop NIIs ------

# %% [markdown]
# #### 3 - 8: Do the GC and check the GPU and memory status

# %%
import tensorflow as tf
import gc

gc.collect()

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for i, gpu in enumerate(gpus):
        device_name = f"GPU:{i}"  # Properly format the device name
        details = tf.config.experimental.get_memory_info(device_name)
        print(f"GPU: {device_name}")
        print(f"Current Memory Usage: {details['current']} bytes")
        print(f"Peak Memory Usage: {details['peak']} bytes")
else:
    print("No GPU devices found.")

for gpu in gpus:
    print(f"Memory growth for {gpu}: {tf.config.experimental.get_memory_growth(gpu)}")
# Out:
# GPU: GPU:0
# Current Memory Usage: 5938460 bytes
# Peak Memory Usage: 8393768 bytes
# Memory growth for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): None

# %%
# Mixed Precision Training
# from tensorflow.keras.mixed_precision import experimental as mixed_precision

# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_policy(policy)

# %% [markdown]
# #### 3 - 9: Set up callbacks
#
# Callbacks are functions that can be executed during the training process.
#
# We will use three callbacks:
#
# - **ReduceLROnPlateau**: This callback reduces the learning rate when a metric has stopped improving (validation loss here). The learning rate is reduced by a factor of 0.2, the patience is set to 2 epochs, and the minimum learning rate is set to 0.000001.
#
# - **ModelCheckpoint**: Saves the best model weights (model that has obtained the lowest validation loss during the different epochs). Saving a model allows us to reuse it later or to share it, without having to retrain it from scratch. This will save us time and resources!
#
# - **CSVLogger**: Add metrics to a CSV file, which is named *training.log* (parameter `append` is set to `False` so the file is overwritten if it already exists).

# %%
from datetime import datetime
import os

# Generate timestamp for filenames
start_train_timestamp = datetime.now().strftime("%b-%d_%H-%M-%S")
# start_train_timestamp = 'Apr-28_12-43-36'

# model_dir = f'./model/model_v{MODEL_VERSION}_{start_train_timestamp}'
model_dir = f'/home/cbel/Desktop/YIHAN/unet/model/model_v{MODEL_VERSION}_{start_train_timestamp}'
# model_dir = f'/home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_12-43-36'


if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print(f"Model dir {model_dir} created.")
else:
    print(f"Model dir {model_dir} existed.")

# Define file paths with timestamps
training_log_filename = f"{model_dir}/training-{start_train_timestamp}.log"
model_checkpoint_path = f"{model_dir}/model_epoch{{epoch:02d}}-val_loss{{val_loss:.6f}}_{start_train_timestamp}.m5"

callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.000001, verbose=1),
    
    keras.callbacks.ModelCheckpoint(filepath=model_checkpoint_path, verbose=1, save_best_only=True, save_weights_only=True),

    CSVLogger(training_log_filename, separator=',', append=False)  # Save logs with timestamp
]
# Out:
# Model dir /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34 created.

# %% [markdown]
# ### Step 4 - Train & Save the model

# %% [markdown]
# #### 4 - 1: log all cell outputs during training

# %%
import sys

print(f'----------')
print(f'model name: {model_builders[MODEL_VERSION].__name__}')
print(f'epochs: {EPOCHS}')
print(f'steps_per_epoch: {STEPS_PER_EPOCH}')
print(f'dimension: {IMG_SIZE}')
print(f'n_channels: {N_CHANNELS}')
print(f'input layer: {INPUT_LAYER}')
print(f'kernel init: {KER_INIT}')
print(f'kernel size: {KERNEL_SIZE}')
print(f'dropout: {DROPOUT}')
print(f'learning rate: {LEARNING_RATE}')
print(f'loss function: {LOSS_FUNCTION}')
    
print(f"train cases: {len(datas_train)}")
print(f'train slices: {total_slices_dict["train"]}')
print(f"validation cases: {len(datas_val)}")
print(f'val slices: {total_slices_dict["val"]}')
print(f'slice index: {VOLUME_START_AT} ~ {VOLUME_START_AT + VOLUME_SLICES_PLUS}')
print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')
print(f"test cases: {len(datas_test)}")

print(f'start training at: {start_train_timestamp}')
print(f'----------')

original_stdout = sys.stdout
with open(f'{model_dir}/info.log', 'w') as predict_log_file:
    sys.stdout = predict_log_file
    print(f'----------')
    print(f'model name: {model_builders[MODEL_VERSION].__name__}')
    print(f'epochs: {EPOCHS}')
    print(f'steps_per_epoch: {STEPS_PER_EPOCH}')
    print(f'dimension: {IMG_SIZE}')
    print(f'n_channels: {N_CHANNELS}')
    print(f'input layer: {INPUT_LAYER}')
    print(f'kernel init: {KER_INIT}')
    print(f'kernel size: {KERNEL_SIZE}')
    print(f'dropout: {DROPOUT}')
    print(f'learning rate: {LEARNING_RATE}')
    print(f'loss function: {LOSS_FUNCTION}')

    print(f"train cases: {len(datas_train)}")
    print(f'train slices: {total_slices_dict["train"]}')
    print(f"validation cases: {len(datas_val)}")
    print(f'val slices: {total_slices_dict["val"]}')
    print(f'slice index: {VOLUME_START_AT} ~ {VOLUME_START_AT + VOLUME_SLICES_PLUS}')
    print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')
    print(f"test cases: {len(datas_test)}")

    print(f'start training at: {start_train_timestamp}')
    print(f'----------')

sys.stdout = original_stdout
# Out:
# ----------
# model name: unet_v1
# epochs: 200
# steps_per_epoch: 948
# dimension: 256
# n_channels: 2
# input layer: KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 2), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# kernel init: he_normal
# kernel size: 1
# dropout: 0.2
# learning rate: 0.0001
# loss function: <function focal_dice_loss at 0x7fcb3a14a8b0>
# train cases: 948
# train slices: 11370
# validation cases: 237
# val slices: 2645
# slice index: 40 ~ 116
# tumor ratio: 0.1 ~ 0.15
# test cases: 66
# start training at: Apr-28_18-53-34
# ----------

# %% [markdown]
# #### 4 - 2: train

# %%
model.fit(training_generator,
          epochs=EPOCHS,
          steps_per_epoch=STEPS_PER_EPOCH,
          callbacks=callbacks,
          validation_data=valid_generator)
# Out:
# Epoch 1/200
# 2025-04-28 18:53:50.954916: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8202
# 948/948 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.9182 - mean_io_u: 0.6958 - dice_coef: 0.3273 - precision: 0.9299 - sensitivity: 0.8569 - specificity: 0.9840
# Epoch 00001: val_loss improved from inf to 0.59841, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch01-val_loss0.598405_Apr-28_18-53-34.m5
# 948/948 [==============================] - 29s 28ms/step - loss: 0.6906 - accuracy: 0.9182 - mean_io_u: 0.6958 - dice_coef: 0.3273 - precision: 0.9299 - sensitivity: 0.8569 - specificity: 0.9840 - val_loss: 0.5984 - val_accuracy: 0.9257 - val_mean_io_u: 0.3766 - val_dice_coef: 0.4082 - val_precision: 0.9308 - val_sensitivity: 0.9205 - val_specificity: 0.9772 - lr: 1.0000e-04
# Epoch 2/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.5773 - accuracy: 0.9392 - mean_io_u: 0.6304 - dice_coef: 0.4458 - precision: 0.9421 - sensitivity: 0.9373 - specificity: 0.9809
# Epoch 00002: val_loss improved from 0.59841 to 0.54902, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch02-val_loss0.549023_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 27ms/step - loss: 0.5767 - accuracy: 0.9393 - mean_io_u: 0.6310 - dice_coef: 0.4464 - precision: 0.9421 - sensitivity: 0.9374 - specificity: 0.9809 - val_loss: 0.5490 - val_accuracy: 0.9645 - val_mean_io_u: 0.8064 - val_dice_coef: 0.4736 - val_precision: 0.9665 - val_sensitivity: 0.9621 - val_specificity: 0.9889 - lr: 1.0000e-04
# Epoch 3/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.5178 - accuracy: 0.9523 - mean_io_u: 0.5989 - dice_coef: 0.5030 - precision: 0.9535 - sensitivity: 0.9512 - specificity: 0.9846
# Epoch 00003: val_loss improved from 0.54902 to 0.53486, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch03-val_loss0.534862_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.5175 - accuracy: 0.9523 - mean_io_u: 0.5980 - dice_coef: 0.5032 - precision: 0.9536 - sensitivity: 0.9512 - specificity: 0.9846 - val_loss: 0.5349 - val_accuracy: 0.9655 - val_mean_io_u: 0.3765 - val_dice_coef: 0.5041 - val_precision: 0.9662 - val_sensitivity: 0.9647 - val_specificity: 0.9888 - lr: 1.0000e-04
# Epoch 4/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.5031 - accuracy: 0.9572 - mean_io_u: 0.5464 - dice_coef: 0.5160 - precision: 0.9583 - sensitivity: 0.9562 - specificity: 0.9862
# Epoch 00004: val_loss improved from 0.53486 to 0.49454, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch04-val_loss0.494539_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.5027 - accuracy: 0.9572 - mean_io_u: 0.5458 - dice_coef: 0.5163 - precision: 0.9583 - sensitivity: 0.9562 - specificity: 0.9862 - val_loss: 0.4945 - val_accuracy: 0.9527 - val_mean_io_u: 0.3767 - val_dice_coef: 0.5320 - val_precision: 0.9530 - val_sensitivity: 0.9522 - val_specificity: 0.9844 - lr: 1.0000e-04
# Epoch 5/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.4835 - accuracy: 0.9612 - mean_io_u: 0.4646 - dice_coef: 0.5383 - precision: 0.9619 - sensitivity: 0.9604 - specificity: 0.9874
# Epoch 00005: val_loss did not improve from 0.49454
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4838 - accuracy: 0.9612 - mean_io_u: 0.4645 - dice_coef: 0.5381 - precision: 0.9619 - sensitivity: 0.9604 - specificity: 0.9873 - val_loss: 0.4987 - val_accuracy: 0.9480 - val_mean_io_u: 0.3765 - val_dice_coef: 0.5086 - val_precision: 0.9500 - val_sensitivity: 0.9469 - val_specificity: 0.9835 - lr: 1.0000e-04
# Epoch 6/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.4693 - accuracy: 0.9631 - mean_io_u: 0.5099 - dice_coef: 0.5526 - precision: 0.9637 - sensitivity: 0.9623 - specificity: 0.9879
# Epoch 00006: val_loss improved from 0.49454 to 0.44856, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch06-val_loss0.448562_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4689 - accuracy: 0.9631 - mean_io_u: 0.5096 - dice_coef: 0.5528 - precision: 0.9638 - sensitivity: 0.9623 - specificity: 0.9880 - val_loss: 0.4486 - val_accuracy: 0.9661 - val_mean_io_u: 0.3786 - val_dice_coef: 0.5621 - val_precision: 0.9668 - val_sensitivity: 0.9653 - val_specificity: 0.9890 - lr: 1.0000e-04
# Epoch 7/200
# 948/948 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.9641 - mean_io_u: 0.4599 - dice_coef: 0.5632 - precision: 0.9646 - sensitivity: 0.9635 - specificity: 0.9882
# Epoch 00007: val_loss did not improve from 0.44856
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4605 - accuracy: 0.9641 - mean_io_u: 0.4599 - dice_coef: 0.5632 - precision: 0.9646 - sensitivity: 0.9635 - specificity: 0.9882 - val_loss: 0.4812 - val_accuracy: 0.9415 - val_mean_io_u: 0.3763 - val_dice_coef: 0.5266 - val_precision: 0.9443 - val_sensitivity: 0.9402 - val_specificity: 0.9816 - lr: 1.0000e-04
# Epoch 8/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.4395 - accuracy: 0.9686 - mean_io_u: 0.5260 - dice_coef: 0.5819 - precision: 0.9688 - sensitivity: 0.9681 - specificity: 0.9896
# Epoch 00008: val_loss improved from 0.44856 to 0.44519, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch08-val_loss0.445189_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 27ms/step - loss: 0.4398 - accuracy: 0.9685 - mean_io_u: 0.5261 - dice_coef: 0.5817 - precision: 0.9687 - sensitivity: 0.9680 - specificity: 0.9896 - val_loss: 0.4452 - val_accuracy: 0.9581 - val_mean_io_u: 0.4247 - val_dice_coef: 0.5713 - val_precision: 0.9592 - val_sensitivity: 0.9569 - val_specificity: 0.9865 - lr: 1.0000e-04
# Epoch 9/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.4408 - accuracy: 0.9670 - mean_io_u: 0.5867 - dice_coef: 0.5851 - precision: 0.9673 - sensitivity: 0.9665 - specificity: 0.9891
# Epoch 00009: val_loss improved from 0.44519 to 0.43260, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch09-val_loss0.432597_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 27ms/step - loss: 0.4403 - accuracy: 0.9670 - mean_io_u: 0.5860 - dice_coef: 0.5856 - precision: 0.9673 - sensitivity: 0.9665 - specificity: 0.9891 - val_loss: 0.4326 - val_accuracy: 0.9726 - val_mean_io_u: 0.3846 - val_dice_coef: 0.6103 - val_precision: 0.9725 - val_sensitivity: 0.9723 - val_specificity: 0.9908 - lr: 1.0000e-04
# Epoch 10/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.4183 - accuracy: 0.9725 - mean_io_u: 0.7127 - dice_coef: 0.6081 - precision: 0.9726 - sensitivity: 0.9721 - specificity: 0.9909
# Epoch 00010: val_loss did not improve from 0.43260
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4184 - accuracy: 0.9726 - mean_io_u: 0.7130 - dice_coef: 0.6082 - precision: 0.9727 - sensitivity: 0.9722 - specificity: 0.9909 - val_loss: 0.4372 - val_accuracy: 0.9772 - val_mean_io_u: 0.7778 - val_dice_coef: 0.6137 - val_precision: 0.9771 - val_sensitivity: 0.9770 - val_specificity: 0.9924 - lr: 1.0000e-04
# Epoch 11/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.4202 - accuracy: 0.9703 - mean_io_u: 0.7003 - dice_coef: 0.6062 - precision: 0.9704 - sensitivity: 0.9699 - specificity: 0.9902
# Epoch 00011: val_loss improved from 0.43260 to 0.43073, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch11-val_loss0.430732_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4201 - accuracy: 0.9703 - mean_io_u: 0.7007 - dice_coef: 0.6063 - precision: 0.9704 - sensitivity: 0.9699 - specificity: 0.9902 - val_loss: 0.4307 - val_accuracy: 0.9699 - val_mean_io_u: 0.8139 - val_dice_coef: 0.6109 - val_precision: 0.9706 - val_sensitivity: 0.9695 - val_specificity: 0.9902 - lr: 1.0000e-04
# Epoch 12/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.4150 - accuracy: 0.9729 - mean_io_u: 0.7722 - dice_coef: 0.6134 - precision: 0.9731 - sensitivity: 0.9725 - specificity: 0.9910
# Epoch 00012: val_loss did not improve from 0.43073
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4147 - accuracy: 0.9730 - mean_io_u: 0.7724 - dice_coef: 0.6136 - precision: 0.9731 - sensitivity: 0.9726 - specificity: 0.9910 - val_loss: 0.4490 - val_accuracy: 0.9739 - val_mean_io_u: 0.8124 - val_dice_coef: 0.5976 - val_precision: 0.9739 - val_sensitivity: 0.9736 - val_specificity: 0.9913 - lr: 1.0000e-04
# Epoch 13/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.4017 - accuracy: 0.9750 - mean_io_u: 0.7589 - dice_coef: 0.6245 - precision: 0.9751 - sensitivity: 0.9747 - specificity: 0.9917
# Epoch 00013: val_loss improved from 0.43073 to 0.42587, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch13-val_loss0.425869_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4013 - accuracy: 0.9751 - mean_io_u: 0.7586 - dice_coef: 0.6249 - precision: 0.9751 - sensitivity: 0.9747 - specificity: 0.9917 - val_loss: 0.4259 - val_accuracy: 0.9678 - val_mean_io_u: 0.4292 - val_dice_coef: 0.6095 - val_precision: 0.9678 - val_sensitivity: 0.9675 - val_specificity: 0.9893 - lr: 1.0000e-04
# Epoch 14/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.4145 - accuracy: 0.9740 - mean_io_u: 0.7149 - dice_coef: 0.6142 - precision: 0.9740 - sensitivity: 0.9737 - specificity: 0.9913
# Epoch 00014: val_loss improved from 0.42587 to 0.40962, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch14-val_loss0.409617_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4147 - accuracy: 0.9741 - mean_io_u: 0.7151 - dice_coef: 0.6148 - precision: 0.9741 - sensitivity: 0.9737 - specificity: 0.9914 - val_loss: 0.4096 - val_accuracy: 0.9804 - val_mean_io_u: 0.8043 - val_dice_coef: 0.6308 - val_precision: 0.9804 - val_sensitivity: 0.9800 - val_specificity: 0.9935 - lr: 1.0000e-04
# Epoch 15/200
# 948/948 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.9739 - mean_io_u: 0.6748 - dice_coef: 0.6249 - precision: 0.9739 - sensitivity: 0.9735 - specificity: 0.9913
# Epoch 00015: val_loss did not improve from 0.40962
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4083 - accuracy: 0.9739 - mean_io_u: 0.6748 - dice_coef: 0.6249 - precision: 0.9739 - sensitivity: 0.9735 - specificity: 0.9913 - val_loss: 0.4181 - val_accuracy: 0.9728 - val_mean_io_u: 0.7687 - val_dice_coef: 0.6326 - val_precision: 0.9728 - val_sensitivity: 0.9725 - val_specificity: 0.9909 - lr: 1.0000e-04
# Epoch 16/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3967 - accuracy: 0.9748 - mean_io_u: 0.7878 - dice_coef: 0.6291 - precision: 0.9748 - sensitivity: 0.9744 - specificity: 0.9916
# Epoch 00016: val_loss improved from 0.40962 to 0.40615, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch16-val_loss0.406150_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3970 - accuracy: 0.9748 - mean_io_u: 0.7878 - dice_coef: 0.6288 - precision: 0.9748 - sensitivity: 0.9745 - specificity: 0.9916 - val_loss: 0.4062 - val_accuracy: 0.9717 - val_mean_io_u: 0.7930 - val_dice_coef: 0.6152 - val_precision: 0.9719 - val_sensitivity: 0.9713 - val_specificity: 0.9906 - lr: 1.0000e-04
# Epoch 17/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.4054 - accuracy: 0.9730 - mean_io_u: 0.7664 - dice_coef: 0.6222 - precision: 0.9730 - sensitivity: 0.9727 - specificity: 0.9910
# Epoch 00017: val_loss did not improve from 0.40615
# 948/948 [==============================] - 25s 26ms/step - loss: 0.4060 - accuracy: 0.9729 - mean_io_u: 0.7665 - dice_coef: 0.6218 - precision: 0.9730 - sensitivity: 0.9726 - specificity: 0.9910 - val_loss: 0.4200 - val_accuracy: 0.9756 - val_mean_io_u: 0.7936 - val_dice_coef: 0.6427 - val_precision: 0.9755 - val_sensitivity: 0.9754 - val_specificity: 0.9918 - lr: 1.0000e-04
# Epoch 18/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3980 - accuracy: 0.9747 - mean_io_u: 0.6940 - dice_coef: 0.6326 - precision: 0.9748 - sensitivity: 0.9744 - specificity: 0.9916
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00018: val_loss did not improve from 0.40615
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3980 - accuracy: 0.9747 - mean_io_u: 0.6940 - dice_coef: 0.6326 - precision: 0.9748 - sensitivity: 0.9744 - specificity: 0.9916 - val_loss: 0.4142 - val_accuracy: 0.9688 - val_mean_io_u: 0.8026 - val_dice_coef: 0.6164 - val_precision: 0.9689 - val_sensitivity: 0.9684 - val_specificity: 0.9896 - lr: 1.0000e-04
# Epoch 19/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3749 - accuracy: 0.9788 - mean_io_u: 0.7538 - dice_coef: 0.6547 - precision: 0.9788 - sensitivity: 0.9785 - specificity: 0.9929
# Epoch 00019: val_loss improved from 0.40615 to 0.38251, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch19-val_loss0.382515_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3744 - accuracy: 0.9788 - mean_io_u: 0.7529 - dice_coef: 0.6551 - precision: 0.9788 - sensitivity: 0.9785 - specificity: 0.9929 - val_loss: 0.3825 - val_accuracy: 0.9768 - val_mean_io_u: 0.4422 - val_dice_coef: 0.6327 - val_precision: 0.9769 - val_sensitivity: 0.9764 - val_specificity: 0.9923 - lr: 2.0000e-05
# Epoch 20/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.9806 - mean_io_u: 0.5559 - dice_coef: 0.6619 - precision: 0.9805 - sensitivity: 0.9803 - specificity: 0.9935
# Epoch 00020: val_loss improved from 0.38251 to 0.37983, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch20-val_loss0.379827_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3665 - accuracy: 0.9806 - mean_io_u: 0.5559 - dice_coef: 0.6619 - precision: 0.9805 - sensitivity: 0.9803 - specificity: 0.9935 - val_loss: 0.3798 - val_accuracy: 0.9767 - val_mean_io_u: 0.4180 - val_dice_coef: 0.6383 - val_precision: 0.9768 - val_sensitivity: 0.9764 - val_specificity: 0.9923 - lr: 2.0000e-05
# Epoch 21/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3558 - accuracy: 0.9812 - mean_io_u: 0.6411 - dice_coef: 0.6722 - precision: 0.9811 - sensitivity: 0.9809 - specificity: 0.9937
# Epoch 00021: val_loss did not improve from 0.37983
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3559 - accuracy: 0.9812 - mean_io_u: 0.6413 - dice_coef: 0.6723 - precision: 0.9811 - sensitivity: 0.9809 - specificity: 0.9937 - val_loss: 0.3828 - val_accuracy: 0.9754 - val_mean_io_u: 0.7582 - val_dice_coef: 0.6388 - val_precision: 0.9754 - val_sensitivity: 0.9752 - val_specificity: 0.9918 - lr: 2.0000e-05
# Epoch 22/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3557 - accuracy: 0.9816 - mean_io_u: 0.7520 - dice_coef: 0.6702 - precision: 0.9815 - sensitivity: 0.9813 - specificity: 0.9938
# Epoch 00022: val_loss improved from 0.37983 to 0.37170, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch22-val_loss0.371704_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3558 - accuracy: 0.9816 - mean_io_u: 0.7518 - dice_coef: 0.6702 - precision: 0.9815 - sensitivity: 0.9813 - specificity: 0.9938 - val_loss: 0.3717 - val_accuracy: 0.9800 - val_mean_io_u: 0.7605 - val_dice_coef: 0.6632 - val_precision: 0.9799 - val_sensitivity: 0.9797 - val_specificity: 0.9933 - lr: 2.0000e-05
# Epoch 23/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3504 - accuracy: 0.9822 - mean_io_u: 0.6985 - dice_coef: 0.6762 - precision: 0.9821 - sensitivity: 0.9819 - specificity: 0.9940
# Epoch 00023: val_loss did not improve from 0.37170
# 948/948 [==============================] - 24s 26ms/step - loss: 0.3501 - accuracy: 0.9822 - mean_io_u: 0.6986 - dice_coef: 0.6764 - precision: 0.9821 - sensitivity: 0.9819 - specificity: 0.9940 - val_loss: 0.3725 - val_accuracy: 0.9797 - val_mean_io_u: 0.7685 - val_dice_coef: 0.6589 - val_precision: 0.9796 - val_sensitivity: 0.9794 - val_specificity: 0.9932 - lr: 2.0000e-05
# Epoch 24/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.9822 - mean_io_u: 0.7437 - dice_coef: 0.6712 - precision: 0.9821 - sensitivity: 0.9819 - specificity: 0.9940
# Epoch 00024: val_loss improved from 0.37170 to 0.36939, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch24-val_loss0.369389_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3533 - accuracy: 0.9822 - mean_io_u: 0.7437 - dice_coef: 0.6712 - precision: 0.9821 - sensitivity: 0.9819 - specificity: 0.9940 - val_loss: 0.3694 - val_accuracy: 0.9806 - val_mean_io_u: 0.7846 - val_dice_coef: 0.6671 - val_precision: 0.9805 - val_sensitivity: 0.9804 - val_specificity: 0.9935 - lr: 2.0000e-05
# Epoch 25/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3453 - accuracy: 0.9828 - mean_io_u: 0.7389 - dice_coef: 0.6838 - precision: 0.9827 - sensitivity: 0.9826 - specificity: 0.9942
# Epoch 00025: val_loss improved from 0.36939 to 0.36515, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch25-val_loss0.365153_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3452 - accuracy: 0.9828 - mean_io_u: 0.7385 - dice_coef: 0.6838 - precision: 0.9827 - sensitivity: 0.9826 - specificity: 0.9942 - val_loss: 0.3652 - val_accuracy: 0.9798 - val_mean_io_u: 0.4476 - val_dice_coef: 0.6660 - val_precision: 0.9797 - val_sensitivity: 0.9795 - val_specificity: 0.9932 - lr: 2.0000e-05
# Epoch 26/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3515 - accuracy: 0.9816 - mean_io_u: 0.7356 - dice_coef: 0.6780 - precision: 0.9815 - sensitivity: 0.9813 - specificity: 0.9938
# Epoch 00026: val_loss did not improve from 0.36515
# 948/948 [==============================] - 24s 26ms/step - loss: 0.3511 - accuracy: 0.9816 - mean_io_u: 0.7357 - dice_coef: 0.6783 - precision: 0.9815 - sensitivity: 0.9813 - specificity: 0.9938 - val_loss: 0.3653 - val_accuracy: 0.9821 - val_mean_io_u: 0.7896 - val_dice_coef: 0.6767 - val_precision: 0.9820 - val_sensitivity: 0.9818 - val_specificity: 0.9940 - lr: 2.0000e-05
# Epoch 27/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.9828 - mean_io_u: 0.7239 - dice_coef: 0.6880 - precision: 0.9827 - sensitivity: 0.9825 - specificity: 0.9942
# Epoch 00027: val_loss improved from 0.36515 to 0.36473, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch27-val_loss0.364728_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3394 - accuracy: 0.9828 - mean_io_u: 0.7241 - dice_coef: 0.6880 - precision: 0.9827 - sensitivity: 0.9826 - specificity: 0.9942 - val_loss: 0.3647 - val_accuracy: 0.9827 - val_mean_io_u: 0.7697 - val_dice_coef: 0.6680 - val_precision: 0.9826 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 2.0000e-05
# Epoch 28/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3408 - accuracy: 0.9830 - mean_io_u: 0.7541 - dice_coef: 0.6833 - precision: 0.9828 - sensitivity: 0.9827 - specificity: 0.9943
# Epoch 00028: val_loss improved from 0.36473 to 0.36317, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch28-val_loss0.363165_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3406 - accuracy: 0.9830 - mean_io_u: 0.7542 - dice_coef: 0.6835 - precision: 0.9828 - sensitivity: 0.9827 - specificity: 0.9943 - val_loss: 0.3632 - val_accuracy: 0.9800 - val_mean_io_u: 0.7726 - val_dice_coef: 0.6667 - val_precision: 0.9799 - val_sensitivity: 0.9797 - val_specificity: 0.9933 - lr: 2.0000e-05
# Epoch 29/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3538 - accuracy: 0.9817 - mean_io_u: 0.7641 - dice_coef: 0.6737 - precision: 0.9816 - sensitivity: 0.9815 - specificity: 0.9939
# Epoch 00029: val_loss did not improve from 0.36317
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3534 - accuracy: 0.9817 - mean_io_u: 0.7641 - dice_coef: 0.6741 - precision: 0.9816 - sensitivity: 0.9815 - specificity: 0.9939 - val_loss: 0.3660 - val_accuracy: 0.9809 - val_mean_io_u: 0.7759 - val_dice_coef: 0.6570 - val_precision: 0.9808 - val_sensitivity: 0.9806 - val_specificity: 0.9936 - lr: 2.0000e-05
# Epoch 30/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3403 - accuracy: 0.9829 - mean_io_u: 0.7777 - dice_coef: 0.6892 - precision: 0.9828 - sensitivity: 0.9826 - specificity: 0.9943
# Epoch 00030: val_loss improved from 0.36317 to 0.36300, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch30-val_loss0.362998_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3408 - accuracy: 0.9828 - mean_io_u: 0.7778 - dice_coef: 0.6887 - precision: 0.9827 - sensitivity: 0.9825 - specificity: 0.9942 - val_loss: 0.3630 - val_accuracy: 0.9824 - val_mean_io_u: 0.8017 - val_dice_coef: 0.6672 - val_precision: 0.9823 - val_sensitivity: 0.9821 - val_specificity: 0.9941 - lr: 2.0000e-05
# Epoch 31/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3411 - accuracy: 0.9828 - mean_io_u: 0.7674 - dice_coef: 0.6923 - precision: 0.9827 - sensitivity: 0.9825 - specificity: 0.9942
# Epoch 00031: val_loss improved from 0.36300 to 0.36273, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch31-val_loss0.362729_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3409 - accuracy: 0.9828 - mean_io_u: 0.7674 - dice_coef: 0.6925 - precision: 0.9827 - sensitivity: 0.9825 - specificity: 0.9942 - val_loss: 0.3627 - val_accuracy: 0.9819 - val_mean_io_u: 0.7881 - val_dice_coef: 0.6765 - val_precision: 0.9818 - val_sensitivity: 0.9817 - val_specificity: 0.9939 - lr: 2.0000e-05
# Epoch 32/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3562 - accuracy: 0.9828 - mean_io_u: 0.7656 - dice_coef: 0.6716 - precision: 0.9826 - sensitivity: 0.9825 - specificity: 0.9942
# Epoch 00032: val_loss did not improve from 0.36273
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3565 - accuracy: 0.9827 - mean_io_u: 0.7657 - dice_coef: 0.6713 - precision: 0.9826 - sensitivity: 0.9825 - specificity: 0.9942 - val_loss: 0.3688 - val_accuracy: 0.9790 - val_mean_io_u: 0.7832 - val_dice_coef: 0.6548 - val_precision: 0.9790 - val_sensitivity: 0.9787 - val_specificity: 0.9930 - lr: 2.0000e-05
# Epoch 33/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3442 - accuracy: 0.9821 - mean_io_u: 0.7775 - dice_coef: 0.6808 - precision: 0.9820 - sensitivity: 0.9818 - specificity: 0.9940
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 00033: val_loss did not improve from 0.36273
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3442 - accuracy: 0.9821 - mean_io_u: 0.7775 - dice_coef: 0.6808 - precision: 0.9820 - sensitivity: 0.9818 - specificity: 0.9940 - val_loss: 0.3631 - val_accuracy: 0.9816 - val_mean_io_u: 0.7934 - val_dice_coef: 0.6644 - val_precision: 0.9815 - val_sensitivity: 0.9813 - val_specificity: 0.9938 - lr: 2.0000e-05
# Epoch 34/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3396 - accuracy: 0.9834 - mean_io_u: 0.7917 - dice_coef: 0.6875 - precision: 0.9833 - sensitivity: 0.9831 - specificity: 0.9944
# Epoch 00034: val_loss improved from 0.36273 to 0.35728, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch34-val_loss0.357279_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3396 - accuracy: 0.9834 - mean_io_u: 0.7918 - dice_coef: 0.6876 - precision: 0.9833 - sensitivity: 0.9831 - specificity: 0.9944 - val_loss: 0.3573 - val_accuracy: 0.9818 - val_mean_io_u: 0.7899 - val_dice_coef: 0.6730 - val_precision: 0.9817 - val_sensitivity: 0.9815 - val_specificity: 0.9939 - lr: 4.0000e-06
# Epoch 35/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3506 - accuracy: 0.9829 - mean_io_u: 0.7890 - dice_coef: 0.6796 - precision: 0.9827 - sensitivity: 0.9826 - specificity: 0.9942
# Epoch 00035: val_loss improved from 0.35728 to 0.35636, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch35-val_loss0.356360_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3504 - accuracy: 0.9828 - mean_io_u: 0.7890 - dice_coef: 0.6797 - precision: 0.9827 - sensitivity: 0.9826 - specificity: 0.9942 - val_loss: 0.3564 - val_accuracy: 0.9828 - val_mean_io_u: 0.7969 - val_dice_coef: 0.6784 - val_precision: 0.9827 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 4.0000e-06
# Epoch 36/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3329 - accuracy: 0.9839 - mean_io_u: 0.7879 - dice_coef: 0.6928 - precision: 0.9838 - sensitivity: 0.9836 - specificity: 0.9946
# Epoch 00036: val_loss did not improve from 0.35636
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3332 - accuracy: 0.9839 - mean_io_u: 0.7879 - dice_coef: 0.6925 - precision: 0.9837 - sensitivity: 0.9836 - specificity: 0.9946 - val_loss: 0.3581 - val_accuracy: 0.9809 - val_mean_io_u: 0.7849 - val_dice_coef: 0.6677 - val_precision: 0.9808 - val_sensitivity: 0.9806 - val_specificity: 0.9936 - lr: 4.0000e-06
# Epoch 37/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3315 - accuracy: 0.9838 - mean_io_u: 0.7861 - dice_coef: 0.6996 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946
# Epoch 00037: val_loss improved from 0.35636 to 0.35618, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch37-val_loss0.356183_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3315 - accuracy: 0.9838 - mean_io_u: 0.7861 - dice_coef: 0.6995 - precision: 0.9836 - sensitivity: 0.9835 - specificity: 0.9945 - val_loss: 0.3562 - val_accuracy: 0.9825 - val_mean_io_u: 0.7902 - val_dice_coef: 0.6781 - val_precision: 0.9824 - val_sensitivity: 0.9822 - val_specificity: 0.9941 - lr: 4.0000e-06
# Epoch 38/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3352 - accuracy: 0.9842 - mean_io_u: 0.7825 - dice_coef: 0.6990 - precision: 0.9840 - sensitivity: 0.9839 - specificity: 0.9947
# Epoch 00038: val_loss did not improve from 0.35618
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3350 - accuracy: 0.9842 - mean_io_u: 0.7826 - dice_coef: 0.6991 - precision: 0.9840 - sensitivity: 0.9839 - specificity: 0.9947 - val_loss: 0.3562 - val_accuracy: 0.9834 - val_mean_io_u: 0.7937 - val_dice_coef: 0.6809 - val_precision: 0.9833 - val_sensitivity: 0.9831 - val_specificity: 0.9944 - lr: 4.0000e-06
# Epoch 39/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.9836 - mean_io_u: 0.7821 - dice_coef: 0.6885 - precision: 0.9835 - sensitivity: 0.9834 - specificity: 0.9945
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00039: val_loss did not improve from 0.35618
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3435 - accuracy: 0.9836 - mean_io_u: 0.7821 - dice_coef: 0.6880 - precision: 0.9834 - sensitivity: 0.9833 - specificity: 0.9945 - val_loss: 0.3564 - val_accuracy: 0.9816 - val_mean_io_u: 0.7807 - val_dice_coef: 0.6725 - val_precision: 0.9815 - val_sensitivity: 0.9813 - val_specificity: 0.9938 - lr: 4.0000e-06
# Epoch 40/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3371 - accuracy: 0.9840 - mean_io_u: 0.7794 - dice_coef: 0.6927 - precision: 0.9839 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00040: val_loss improved from 0.35618 to 0.35517, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch40-val_loss0.355167_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3371 - accuracy: 0.9840 - mean_io_u: 0.7795 - dice_coef: 0.6927 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946 - val_loss: 0.3552 - val_accuracy: 0.9828 - val_mean_io_u: 0.7896 - val_dice_coef: 0.6796 - val_precision: 0.9826 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 41/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3302 - accuracy: 0.9837 - mean_io_u: 0.7827 - dice_coef: 0.7013 - precision: 0.9836 - sensitivity: 0.9835 - specificity: 0.9945
# Epoch 00041: val_loss improved from 0.35517 to 0.35488, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch41-val_loss0.354884_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3297 - accuracy: 0.9837 - mean_io_u: 0.7826 - dice_coef: 0.7017 - precision: 0.9836 - sensitivity: 0.9835 - specificity: 0.9945 - val_loss: 0.3549 - val_accuracy: 0.9827 - val_mean_io_u: 0.7880 - val_dice_coef: 0.6776 - val_precision: 0.9826 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 42/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3309 - accuracy: 0.9840 - mean_io_u: 0.7814 - dice_coef: 0.6971 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00042: val_loss improved from 0.35488 to 0.35477, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch42-val_loss0.354769_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3305 - accuracy: 0.9840 - mean_io_u: 0.7814 - dice_coef: 0.6974 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946 - val_loss: 0.3548 - val_accuracy: 0.9825 - val_mean_io_u: 0.7875 - val_dice_coef: 0.6772 - val_precision: 0.9824 - val_sensitivity: 0.9823 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 43/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3229 - accuracy: 0.9846 - mean_io_u: 0.7808 - dice_coef: 0.7053 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00043: val_loss did not improve from 0.35477
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3230 - accuracy: 0.9846 - mean_io_u: 0.7808 - dice_coef: 0.7051 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3550 - val_accuracy: 0.9824 - val_mean_io_u: 0.7874 - val_dice_coef: 0.6768 - val_precision: 0.9823 - val_sensitivity: 0.9821 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 44/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3324 - accuracy: 0.9842 - mean_io_u: 0.7822 - dice_coef: 0.6964 - precision: 0.9840 - sensitivity: 0.9839 - specificity: 0.9947
# Epoch 00044: val_loss did not improve from 0.35477
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3325 - accuracy: 0.9842 - mean_io_u: 0.7821 - dice_coef: 0.6965 - precision: 0.9841 - sensitivity: 0.9839 - specificity: 0.9947 - val_loss: 0.3549 - val_accuracy: 0.9827 - val_mean_io_u: 0.7890 - val_dice_coef: 0.6771 - val_precision: 0.9826 - val_sensitivity: 0.9824 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 45/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3357 - accuracy: 0.9836 - mean_io_u: 0.7817 - dice_coef: 0.6894 - precision: 0.9835 - sensitivity: 0.9833 - specificity: 0.9945
# Epoch 00045: val_loss did not improve from 0.35477
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3357 - accuracy: 0.9836 - mean_io_u: 0.7816 - dice_coef: 0.6894 - precision: 0.9835 - sensitivity: 0.9833 - specificity: 0.9945 - val_loss: 0.3551 - val_accuracy: 0.9821 - val_mean_io_u: 0.7857 - val_dice_coef: 0.6756 - val_precision: 0.9820 - val_sensitivity: 0.9819 - val_specificity: 0.9940 - lr: 1.0000e-06
# Epoch 46/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3431 - accuracy: 0.9839 - mean_io_u: 0.7811 - dice_coef: 0.6878 - precision: 0.9838 - sensitivity: 0.9836 - specificity: 0.9946
# Epoch 00046: val_loss did not improve from 0.35477
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3434 - accuracy: 0.9839 - mean_io_u: 0.7811 - dice_coef: 0.6875 - precision: 0.9837 - sensitivity: 0.9836 - specificity: 0.9946 - val_loss: 0.3550 - val_accuracy: 0.9825 - val_mean_io_u: 0.7831 - val_dice_coef: 0.6766 - val_precision: 0.9824 - val_sensitivity: 0.9822 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 47/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.9840 - mean_io_u: 0.7798 - dice_coef: 0.6865 - precision: 0.9839 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00047: val_loss improved from 0.35477 to 0.35469, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch47-val_loss0.354691_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3399 - accuracy: 0.9840 - mean_io_u: 0.7798 - dice_coef: 0.6865 - precision: 0.9839 - sensitivity: 0.9837 - specificity: 0.9946 - val_loss: 0.3547 - val_accuracy: 0.9825 - val_mean_io_u: 0.7866 - val_dice_coef: 0.6789 - val_precision: 0.9824 - val_sensitivity: 0.9823 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 48/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3330 - accuracy: 0.9839 - mean_io_u: 0.7823 - dice_coef: 0.6949 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00048: val_loss did not improve from 0.35469
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3328 - accuracy: 0.9840 - mean_io_u: 0.7823 - dice_coef: 0.6951 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946 - val_loss: 0.3551 - val_accuracy: 0.9822 - val_mean_io_u: 0.7861 - val_dice_coef: 0.6773 - val_precision: 0.9821 - val_sensitivity: 0.9819 - val_specificity: 0.9940 - lr: 1.0000e-06
# Epoch 49/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3434 - accuracy: 0.9839 - mean_io_u: 0.7848 - dice_coef: 0.6885 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00049: val_loss did not improve from 0.35469
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3434 - accuracy: 0.9839 - mean_io_u: 0.7847 - dice_coef: 0.6885 - precision: 0.9838 - sensitivity: 0.9836 - specificity: 0.9946 - val_loss: 0.3548 - val_accuracy: 0.9823 - val_mean_io_u: 0.7890 - val_dice_coef: 0.6766 - val_precision: 0.9822 - val_sensitivity: 0.9820 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 50/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3424 - accuracy: 0.9832 - mean_io_u: 0.7835 - dice_coef: 0.6871 - precision: 0.9831 - sensitivity: 0.9829 - specificity: 0.9944
# Epoch 00050: val_loss improved from 0.35469 to 0.35435, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch50-val_loss0.354347_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3422 - accuracy: 0.9832 - mean_io_u: 0.7836 - dice_coef: 0.6871 - precision: 0.9831 - sensitivity: 0.9829 - specificity: 0.9944 - val_loss: 0.3543 - val_accuracy: 0.9825 - val_mean_io_u: 0.7900 - val_dice_coef: 0.6784 - val_precision: 0.9824 - val_sensitivity: 0.9822 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 51/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.9842 - mean_io_u: 0.7844 - dice_coef: 0.6991 - precision: 0.9840 - sensitivity: 0.9839 - specificity: 0.9947
# Epoch 00051: val_loss did not improve from 0.35435
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3317 - accuracy: 0.9842 - mean_io_u: 0.7844 - dice_coef: 0.6991 - precision: 0.9840 - sensitivity: 0.9839 - specificity: 0.9947 - val_loss: 0.3548 - val_accuracy: 0.9828 - val_mean_io_u: 0.7881 - val_dice_coef: 0.6773 - val_precision: 0.9827 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 52/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3310 - accuracy: 0.9842 - mean_io_u: 0.7866 - dice_coef: 0.6973 - precision: 0.9841 - sensitivity: 0.9839 - specificity: 0.9947
# Epoch 00052: val_loss did not improve from 0.35435
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3312 - accuracy: 0.9842 - mean_io_u: 0.7867 - dice_coef: 0.6974 - precision: 0.9841 - sensitivity: 0.9839 - specificity: 0.9947 - val_loss: 0.3548 - val_accuracy: 0.9824 - val_mean_io_u: 0.7905 - val_dice_coef: 0.6780 - val_precision: 0.9823 - val_sensitivity: 0.9821 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 53/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3343 - accuracy: 0.9840 - mean_io_u: 0.7832 - dice_coef: 0.6987 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00053: val_loss did not improve from 0.35435
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3340 - accuracy: 0.9840 - mean_io_u: 0.7833 - dice_coef: 0.6989 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946 - val_loss: 0.3548 - val_accuracy: 0.9828 - val_mean_io_u: 0.7886 - val_dice_coef: 0.6781 - val_precision: 0.9827 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 54/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.9838 - mean_io_u: 0.7861 - dice_coef: 0.6918 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946
# Epoch 00054: val_loss did not improve from 0.35435
# 948/948 [==============================] - 24s 26ms/step - loss: 0.3350 - accuracy: 0.9838 - mean_io_u: 0.7861 - dice_coef: 0.6919 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946 - val_loss: 0.3546 - val_accuracy: 0.9828 - val_mean_io_u: 0.7908 - val_dice_coef: 0.6775 - val_precision: 0.9827 - val_sensitivity: 0.9826 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 55/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3264 - accuracy: 0.9846 - mean_io_u: 0.7852 - dice_coef: 0.6978 - precision: 0.9845 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00055: val_loss improved from 0.35435 to 0.35427, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch55-val_loss0.354266_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3270 - accuracy: 0.9846 - mean_io_u: 0.7853 - dice_coef: 0.6973 - precision: 0.9845 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3543 - val_accuracy: 0.9830 - val_mean_io_u: 0.7916 - val_dice_coef: 0.6791 - val_precision: 0.9829 - val_sensitivity: 0.9827 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 56/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.9832 - mean_io_u: 0.7862 - dice_coef: 0.6837 - precision: 0.9830 - sensitivity: 0.9829 - specificity: 0.9943
# Epoch 00056: val_loss did not improve from 0.35427
# 948/948 [==============================] - 24s 26ms/step - loss: 0.3481 - accuracy: 0.9832 - mean_io_u: 0.7862 - dice_coef: 0.6842 - precision: 0.9830 - sensitivity: 0.9829 - specificity: 0.9944 - val_loss: 0.3553 - val_accuracy: 0.9831 - val_mean_io_u: 0.7907 - val_dice_coef: 0.6787 - val_precision: 0.9830 - val_sensitivity: 0.9829 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 57/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.9845 - mean_io_u: 0.7838 - dice_coef: 0.6991 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00057: val_loss did not improve from 0.35427
# 948/948 [==============================] - 24s 26ms/step - loss: 0.3294 - accuracy: 0.9845 - mean_io_u: 0.7838 - dice_coef: 0.6991 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3547 - val_accuracy: 0.9822 - val_mean_io_u: 0.7871 - val_dice_coef: 0.6777 - val_precision: 0.9821 - val_sensitivity: 0.9820 - val_specificity: 0.9940 - lr: 1.0000e-06
# Epoch 58/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3292 - accuracy: 0.9838 - mean_io_u: 0.7830 - dice_coef: 0.6953 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946
# Epoch 00058: val_loss did not improve from 0.35427
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3287 - accuracy: 0.9838 - mean_io_u: 0.7830 - dice_coef: 0.6958 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946 - val_loss: 0.3549 - val_accuracy: 0.9827 - val_mean_io_u: 0.7896 - val_dice_coef: 0.6773 - val_precision: 0.9826 - val_sensitivity: 0.9824 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 59/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.9845 - mean_io_u: 0.7832 - dice_coef: 0.6989 - precision: 0.9844 - sensitivity: 0.9842 - specificity: 0.9948
# Epoch 00059: val_loss did not improve from 0.35427
# 948/948 [==============================] - 26s 27ms/step - loss: 0.3353 - accuracy: 0.9845 - mean_io_u: 0.7832 - dice_coef: 0.6988 - precision: 0.9844 - sensitivity: 0.9842 - specificity: 0.9948 - val_loss: 0.3551 - val_accuracy: 0.9828 - val_mean_io_u: 0.7879 - val_dice_coef: 0.6751 - val_precision: 0.9827 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 60/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.9841 - mean_io_u: 0.7826 - dice_coef: 0.6931 - precision: 0.9839 - sensitivity: 0.9838 - specificity: 0.9946
# Epoch 00060: val_loss did not improve from 0.35427
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3354 - accuracy: 0.9841 - mean_io_u: 0.7827 - dice_coef: 0.6930 - precision: 0.9839 - sensitivity: 0.9838 - specificity: 0.9946 - val_loss: 0.3550 - val_accuracy: 0.9825 - val_mean_io_u: 0.7876 - val_dice_coef: 0.6757 - val_precision: 0.9824 - val_sensitivity: 0.9823 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 61/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3311 - accuracy: 0.9837 - mean_io_u: 0.7826 - dice_coef: 0.6919 - precision: 0.9835 - sensitivity: 0.9834 - specificity: 0.9945
# Epoch 00061: val_loss did not improve from 0.35427
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3311 - accuracy: 0.9837 - mean_io_u: 0.7826 - dice_coef: 0.6919 - precision: 0.9835 - sensitivity: 0.9834 - specificity: 0.9945 - val_loss: 0.3546 - val_accuracy: 0.9828 - val_mean_io_u: 0.7884 - val_dice_coef: 0.6781 - val_precision: 0.9827 - val_sensitivity: 0.9826 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 62/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3299 - accuracy: 0.9846 - mean_io_u: 0.7851 - dice_coef: 0.6999 - precision: 0.9845 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00062: val_loss did not improve from 0.35427
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3300 - accuracy: 0.9846 - mean_io_u: 0.7851 - dice_coef: 0.6998 - precision: 0.9845 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3546 - val_accuracy: 0.9824 - val_mean_io_u: 0.7848 - val_dice_coef: 0.6772 - val_precision: 0.9822 - val_sensitivity: 0.9821 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 63/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3406 - accuracy: 0.9839 - mean_io_u: 0.7804 - dice_coef: 0.6911 - precision: 0.9838 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00063: val_loss did not improve from 0.35427
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3412 - accuracy: 0.9839 - mean_io_u: 0.7804 - dice_coef: 0.6905 - precision: 0.9838 - sensitivity: 0.9836 - specificity: 0.9946 - val_loss: 0.3549 - val_accuracy: 0.9825 - val_mean_io_u: 0.7864 - val_dice_coef: 0.6749 - val_precision: 0.9824 - val_sensitivity: 0.9822 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 64/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3313 - accuracy: 0.9842 - mean_io_u: 0.7834 - dice_coef: 0.6980 - precision: 0.9841 - sensitivity: 0.9839 - specificity: 0.9947
# Epoch 00064: val_loss improved from 0.35427 to 0.35409, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch64-val_loss0.354091_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 27ms/step - loss: 0.3313 - accuracy: 0.9842 - mean_io_u: 0.7834 - dice_coef: 0.6980 - precision: 0.9841 - sensitivity: 0.9839 - specificity: 0.9947 - val_loss: 0.3541 - val_accuracy: 0.9820 - val_mean_io_u: 0.7869 - val_dice_coef: 0.6769 - val_precision: 0.9819 - val_sensitivity: 0.9817 - val_specificity: 0.9940 - lr: 1.0000e-06
# Epoch 65/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3253 - accuracy: 0.9843 - mean_io_u: 0.7843 - dice_coef: 0.6974 - precision: 0.9841 - sensitivity: 0.9840 - specificity: 0.9947
# Epoch 00065: val_loss improved from 0.35409 to 0.35377, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch65-val_loss0.353767_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 27ms/step - loss: 0.3249 - accuracy: 0.9843 - mean_io_u: 0.7842 - dice_coef: 0.6978 - precision: 0.9842 - sensitivity: 0.9840 - specificity: 0.9947 - val_loss: 0.3538 - val_accuracy: 0.9831 - val_mean_io_u: 0.7902 - val_dice_coef: 0.6804 - val_precision: 0.9830 - val_sensitivity: 0.9829 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 66/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3305 - accuracy: 0.9848 - mean_io_u: 0.7820 - dice_coef: 0.6996 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949
# Epoch 00066: val_loss did not improve from 0.35377
# 948/948 [==============================] - 25s 27ms/step - loss: 0.3304 - accuracy: 0.9848 - mean_io_u: 0.7820 - dice_coef: 0.6996 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949 - val_loss: 0.3541 - val_accuracy: 0.9824 - val_mean_io_u: 0.7872 - val_dice_coef: 0.6787 - val_precision: 0.9823 - val_sensitivity: 0.9821 - val_specificity: 0.9941 - lr: 1.0000e-06
# Epoch 67/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3362 - accuracy: 0.9838 - mean_io_u: 0.7814 - dice_coef: 0.6909 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946
# Epoch 00067: val_loss improved from 0.35377 to 0.35370, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch67-val_loss0.353700_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3362 - accuracy: 0.9838 - mean_io_u: 0.7814 - dice_coef: 0.6909 - precision: 0.9837 - sensitivity: 0.9835 - specificity: 0.9946 - val_loss: 0.3537 - val_accuracy: 0.9829 - val_mean_io_u: 0.7878 - val_dice_coef: 0.6779 - val_precision: 0.9828 - val_sensitivity: 0.9826 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 68/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3408 - accuracy: 0.9840 - mean_io_u: 0.7828 - dice_coef: 0.6899 - precision: 0.9839 - sensitivity: 0.9837 - specificity: 0.9946
# Epoch 00068: val_loss did not improve from 0.35370
# 948/948 [==============================] - 25s 27ms/step - loss: 0.3406 - accuracy: 0.9840 - mean_io_u: 0.7827 - dice_coef: 0.6901 - precision: 0.9839 - sensitivity: 0.9837 - specificity: 0.9946 - val_loss: 0.3539 - val_accuracy: 0.9827 - val_mean_io_u: 0.7876 - val_dice_coef: 0.6793 - val_precision: 0.9825 - val_sensitivity: 0.9824 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 69/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3289 - accuracy: 0.9846 - mean_io_u: 0.7814 - dice_coef: 0.7071 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00069: val_loss did not improve from 0.35370
# ...
# Epoch 00176: val_loss did not improve from 0.35040
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3228 - accuracy: 0.9847 - mean_io_u: 0.7737 - dice_coef: 0.7018 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948 - val_loss: 0.3513 - val_accuracy: 0.9836 - val_mean_io_u: 0.7800 - val_dice_coef: 0.6817 - val_precision: 0.9834 - val_sensitivity: 0.9833 - val_specificity: 0.9945 - lr: 1.0000e-06
# Epoch 177/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.9851 - mean_io_u: 0.7690 - dice_coef: 0.7086 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950
# Epoch 00177: val_loss did not improve from 0.35040
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3153 - accuracy: 0.9851 - mean_io_u: 0.7690 - dice_coef: 0.7086 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950 - val_loss: 0.3512 - val_accuracy: 0.9831 - val_mean_io_u: 0.7753 - val_dice_coef: 0.6820 - val_precision: 0.9829 - val_sensitivity: 0.9828 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 178/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3314 - accuracy: 0.9843 - mean_io_u: 0.7687 - dice_coef: 0.6991 - precision: 0.9841 - sensitivity: 0.9840 - specificity: 0.9947
# Epoch 00178: val_loss did not improve from 0.35040
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3311 - accuracy: 0.9843 - mean_io_u: 0.7687 - dice_coef: 0.6994 - precision: 0.9842 - sensitivity: 0.9840 - specificity: 0.9947 - val_loss: 0.3519 - val_accuracy: 0.9831 - val_mean_io_u: 0.7739 - val_dice_coef: 0.6798 - val_precision: 0.9830 - val_sensitivity: 0.9828 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 179/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3335 - accuracy: 0.9846 - mean_io_u: 0.7728 - dice_coef: 0.6946 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00179: val_loss did not improve from 0.35040
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3332 - accuracy: 0.9846 - mean_io_u: 0.7728 - dice_coef: 0.6948 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3512 - val_accuracy: 0.9827 - val_mean_io_u: 0.7791 - val_dice_coef: 0.6803 - val_precision: 0.9826 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 180/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3292 - accuracy: 0.9840 - mean_io_u: 0.7767 - dice_coef: 0.7005 - precision: 0.9839 - sensitivity: 0.9838 - specificity: 0.9946
# Epoch 00180: val_loss did not improve from 0.35040
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3290 - accuracy: 0.9841 - mean_io_u: 0.7766 - dice_coef: 0.7007 - precision: 0.9839 - sensitivity: 0.9838 - specificity: 0.9946 - val_loss: 0.3512 - val_accuracy: 0.9835 - val_mean_io_u: 0.7861 - val_dice_coef: 0.6831 - val_precision: 0.9834 - val_sensitivity: 0.9833 - val_specificity: 0.9945 - lr: 1.0000e-06
# Epoch 181/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3214 - accuracy: 0.9850 - mean_io_u: 0.7788 - dice_coef: 0.7066 - precision: 0.9848 - sensitivity: 0.9847 - specificity: 0.9949
# Epoch 00181: val_loss did not improve from 0.35040
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3211 - accuracy: 0.9850 - mean_io_u: 0.7787 - dice_coef: 0.7068 - precision: 0.9848 - sensitivity: 0.9847 - specificity: 0.9949 - val_loss: 0.3509 - val_accuracy: 0.9837 - val_mean_io_u: 0.7878 - val_dice_coef: 0.6837 - val_precision: 0.9836 - val_sensitivity: 0.9834 - val_specificity: 0.9945 - lr: 1.0000e-06
# Epoch 182/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3309 - accuracy: 0.9846 - mean_io_u: 0.7788 - dice_coef: 0.6971 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00182: val_loss improved from 0.35040 to 0.35029, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch182-val_loss0.350291_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3313 - accuracy: 0.9846 - mean_io_u: 0.7787 - dice_coef: 0.6969 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3503 - val_accuracy: 0.9834 - val_mean_io_u: 0.7824 - val_dice_coef: 0.6833 - val_precision: 0.9832 - val_sensitivity: 0.9831 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 183/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3175 - accuracy: 0.9852 - mean_io_u: 0.7731 - dice_coef: 0.7085 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950
# Epoch 00183: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3176 - accuracy: 0.9852 - mean_io_u: 0.7730 - dice_coef: 0.7088 - precision: 0.9851 - sensitivity: 0.9849 - specificity: 0.9950 - val_loss: 0.3514 - val_accuracy: 0.9828 - val_mean_io_u: 0.7733 - val_dice_coef: 0.6787 - val_precision: 0.9826 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 184/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3181 - accuracy: 0.9845 - mean_io_u: 0.7703 - dice_coef: 0.7046 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00184: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3184 - accuracy: 0.9845 - mean_io_u: 0.7703 - dice_coef: 0.7042 - precision: 0.9844 - sensitivity: 0.9842 - specificity: 0.9948 - val_loss: 0.3509 - val_accuracy: 0.9829 - val_mean_io_u: 0.7788 - val_dice_coef: 0.6810 - val_precision: 0.9828 - val_sensitivity: 0.9827 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 185/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3250 - accuracy: 0.9846 - mean_io_u: 0.7697 - dice_coef: 0.7052 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948
# Epoch 00185: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3250 - accuracy: 0.9846 - mean_io_u: 0.7697 - dice_coef: 0.7052 - precision: 0.9844 - sensitivity: 0.9843 - specificity: 0.9948 - val_loss: 0.3511 - val_accuracy: 0.9828 - val_mean_io_u: 0.7748 - val_dice_coef: 0.6806 - val_precision: 0.9827 - val_sensitivity: 0.9826 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 186/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.9849 - mean_io_u: 0.7675 - dice_coef: 0.7026 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949
# Epoch 00186: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3297 - accuracy: 0.9849 - mean_io_u: 0.7675 - dice_coef: 0.7025 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949 - val_loss: 0.3507 - val_accuracy: 0.9828 - val_mean_io_u: 0.7725 - val_dice_coef: 0.6816 - val_precision: 0.9827 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 187/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3185 - accuracy: 0.9849 - mean_io_u: 0.7708 - dice_coef: 0.7118 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949
# Epoch 00187: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3185 - accuracy: 0.9849 - mean_io_u: 0.7708 - dice_coef: 0.7118 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949 - val_loss: 0.3507 - val_accuracy: 0.9831 - val_mean_io_u: 0.7739 - val_dice_coef: 0.6827 - val_precision: 0.9830 - val_sensitivity: 0.9828 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 188/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3245 - accuracy: 0.9844 - mean_io_u: 0.7704 - dice_coef: 0.7030 - precision: 0.9842 - sensitivity: 0.9841 - specificity: 0.9947
# Epoch 00188: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3250 - accuracy: 0.9843 - mean_io_u: 0.7705 - dice_coef: 0.7026 - precision: 0.9842 - sensitivity: 0.9840 - specificity: 0.9947 - val_loss: 0.3506 - val_accuracy: 0.9834 - val_mean_io_u: 0.7796 - val_dice_coef: 0.6849 - val_precision: 0.9833 - val_sensitivity: 0.9832 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 189/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3271 - accuracy: 0.9846 - mean_io_u: 0.7679 - dice_coef: 0.7016 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948
# Epoch 00189: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3272 - accuracy: 0.9847 - mean_io_u: 0.7679 - dice_coef: 0.7014 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948 - val_loss: 0.3510 - val_accuracy: 0.9833 - val_mean_io_u: 0.7767 - val_dice_coef: 0.6827 - val_precision: 0.9832 - val_sensitivity: 0.9831 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 190/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3250 - accuracy: 0.9846 - mean_io_u: 0.7713 - dice_coef: 0.6993 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948
# Epoch 00190: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3245 - accuracy: 0.9846 - mean_io_u: 0.7714 - dice_coef: 0.6997 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948 - val_loss: 0.3511 - val_accuracy: 0.9832 - val_mean_io_u: 0.7790 - val_dice_coef: 0.6818 - val_precision: 0.9831 - val_sensitivity: 0.9830 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 191/200
# 948/948 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.9847 - mean_io_u: 0.7681 - dice_coef: 0.7014 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948
# Epoch 00191: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3240 - accuracy: 0.9847 - mean_io_u: 0.7681 - dice_coef: 0.7014 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948 - val_loss: 0.3505 - val_accuracy: 0.9832 - val_mean_io_u: 0.7767 - val_dice_coef: 0.6839 - val_precision: 0.9831 - val_sensitivity: 0.9829 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 192/200
# 945/948 [============================>.] - ETA: 0s - loss: 0.3285 - accuracy: 0.9846 - mean_io_u: 0.7712 - dice_coef: 0.7030 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948
# Epoch 00192: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3284 - accuracy: 0.9847 - mean_io_u: 0.7713 - dice_coef: 0.7035 - precision: 0.9845 - sensitivity: 0.9844 - specificity: 0.9948 - val_loss: 0.3509 - val_accuracy: 0.9831 - val_mean_io_u: 0.7767 - val_dice_coef: 0.6839 - val_precision: 0.9830 - val_sensitivity: 0.9829 - val_specificity: 0.9943 - lr: 1.0000e-06
# Epoch 193/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3208 - accuracy: 0.9850 - mean_io_u: 0.7618 - dice_coef: 0.7070 - precision: 0.9848 - sensitivity: 0.9847 - specificity: 0.9949
# Epoch 00193: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3205 - accuracy: 0.9850 - mean_io_u: 0.7618 - dice_coef: 0.7072 - precision: 0.9848 - sensitivity: 0.9847 - specificity: 0.9949 - val_loss: 0.3508 - val_accuracy: 0.9833 - val_mean_io_u: 0.7746 - val_dice_coef: 0.6831 - val_precision: 0.9832 - val_sensitivity: 0.9831 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 194/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3244 - accuracy: 0.9852 - mean_io_u: 0.7714 - dice_coef: 0.7023 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950
# Epoch 00194: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3244 - accuracy: 0.9852 - mean_io_u: 0.7714 - dice_coef: 0.7024 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950 - val_loss: 0.3510 - val_accuracy: 0.9835 - val_mean_io_u: 0.7772 - val_dice_coef: 0.6822 - val_precision: 0.9833 - val_sensitivity: 0.9832 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 195/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3268 - accuracy: 0.9853 - mean_io_u: 0.7721 - dice_coef: 0.7083 - precision: 0.9852 - sensitivity: 0.9851 - specificity: 0.9951
# Epoch 00195: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3268 - accuracy: 0.9853 - mean_io_u: 0.7722 - dice_coef: 0.7082 - precision: 0.9852 - sensitivity: 0.9851 - specificity: 0.9951 - val_loss: 0.3508 - val_accuracy: 0.9827 - val_mean_io_u: 0.7748 - val_dice_coef: 0.6812 - val_precision: 0.9826 - val_sensitivity: 0.9825 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 196/200
# 944/948 [============================>.] - ETA: 0s - loss: 0.3259 - accuracy: 0.9845 - mean_io_u: 0.7732 - dice_coef: 0.7067 - precision: 0.9843 - sensitivity: 0.9842 - specificity: 0.9948
# Epoch 00196: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3260 - accuracy: 0.9845 - mean_io_u: 0.7731 - dice_coef: 0.7066 - precision: 0.9843 - sensitivity: 0.9842 - specificity: 0.9948 - val_loss: 0.3506 - val_accuracy: 0.9829 - val_mean_io_u: 0.7796 - val_dice_coef: 0.6823 - val_precision: 0.9827 - val_sensitivity: 0.9826 - val_specificity: 0.9942 - lr: 1.0000e-06
# Epoch 197/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.9849 - mean_io_u: 0.7734 - dice_coef: 0.7017 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949
# Epoch 00197: val_loss did not improve from 0.35029
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3266 - accuracy: 0.9849 - mean_io_u: 0.7734 - dice_coef: 0.7019 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949 - val_loss: 0.3505 - val_accuracy: 0.9834 - val_mean_io_u: 0.7805 - val_dice_coef: 0.6846 - val_precision: 0.9832 - val_sensitivity: 0.9831 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 198/200
# 947/948 [============================>.] - ETA: 0s - loss: 0.3250 - accuracy: 0.9847 - mean_io_u: 0.7702 - dice_coef: 0.7053 - precision: 0.9846 - sensitivity: 0.9845 - specificity: 0.9949
# Epoch 00198: val_loss improved from 0.35029 to 0.34998, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch198-val_loss0.349984_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3254 - accuracy: 0.9847 - mean_io_u: 0.7702 - dice_coef: 0.7051 - precision: 0.9846 - sensitivity: 0.9845 - specificity: 0.9949 - val_loss: 0.3500 - val_accuracy: 0.9838 - val_mean_io_u: 0.7816 - val_dice_coef: 0.6854 - val_precision: 0.9837 - val_sensitivity: 0.9835 - val_specificity: 0.9946 - lr: 1.0000e-06
# Epoch 199/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3312 - accuracy: 0.9852 - mean_io_u: 0.7777 - dice_coef: 0.7046 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950
# Epoch 00199: val_loss improved from 0.34998 to 0.34966, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/model_epoch199-val_loss0.349663_Apr-28_18-53-34.m5
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3311 - accuracy: 0.9852 - mean_io_u: 0.7777 - dice_coef: 0.7046 - precision: 0.9850 - sensitivity: 0.9849 - specificity: 0.9950 - val_loss: 0.3497 - val_accuracy: 0.9833 - val_mean_io_u: 0.7816 - val_dice_coef: 0.6852 - val_precision: 0.9831 - val_sensitivity: 0.9830 - val_specificity: 0.9944 - lr: 1.0000e-06
# Epoch 200/200
# 946/948 [============================>.] - ETA: 0s - loss: 0.3193 - accuracy: 0.9848 - mean_io_u: 0.7719 - dice_coef: 0.7049 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949
# Epoch 00200: val_loss did not improve from 0.34966
# 948/948 [==============================] - 25s 26ms/step - loss: 0.3194 - accuracy: 0.9849 - mean_io_u: 0.7719 - dice_coef: 0.7048 - precision: 0.9847 - sensitivity: 0.9846 - specificity: 0.9949 - val_loss: 0.3505 - val_accuracy: 0.9834 - val_mean_io_u: 0.7803 - val_dice_coef: 0.6839 - val_precision: 0.9833 - val_sensitivity: 0.9832 - val_specificity: 0.9944 - lr: 1.0000e-06

# %% [markdown]
# #### 4 - 3: Plot the training process

# %%
import glob

# model_dir = f'/home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_12-43-36'
training_log_filename = glob.glob(os.path.join(model_dir, 'training-*.log'))[0]
plt_filename = os.path.splitext(os.path.basename(training_log_filename))[0]
print(f'plt image will be saved in: {training_log_filename}\nwith name: {plt_filename}')
# Out:
# plt image will be saved in: /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-28_18-53-34/training-Apr-28_18-53-34.log
# with name: training-Apr-28_18-53-34

# %%
# Read the CSVlogger file that contains all our metrics (accuracy, loss, dice_coef, ...) of our training
history = pd.read_csv(training_log_filename, sep=',', engine='python')

# Plot training and validation metrics
fig, axs = plt.subplots(1, 3, figsize=(16, 8))
# fig, axs = plt.subplots(1, 4, figsize=(16, 8))

axs[0].plot(history['epoch'], history['accuracy'], 'b', label='Training Accuracy')
axs[0].plot(history['epoch'], history['val_accuracy'], 'r', label='Validation Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

axs[1].plot(history['epoch'], history['loss'], 'b', label='Training Loss')
axs[1].plot(history['epoch'], history['val_loss'], 'r', label='Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(history['epoch'], history['dice_coef'], 'b', label='Training dice coef')
axs[2].plot(history['epoch'], history['val_dice_coef'], 'r', label='Validation dice coef')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Dice Coefficient')
axs[2].legend()

# axs[3].plot(history['epoch'], history['mean_io_u'], 'b', label='Training mean IOU')
# axs[3].plot(history['epoch'], history['val_mean_io_u'], 'r', label='Validation mean IOU')
# axs[3].set_xlabel('Epoch')
# axs[3].set_ylabel('Mean IOU')
# axs[3].legend()

# Add space between subplots
plt.subplots_adjust(wspace=0.4)
plt.savefig(f'/home/cbel/Desktop/YIHAN/unet/plt/train/{plt_filename}.png', dpi=300)

plt.show()

# %% [markdown]
# ### Step 5 - Predict

# %%
PREDICT_PLT_DIR = f'/home/cbel/Desktop/YIHAN/unet/plt/predict/{model_dir.split("/home/cbel/Desktop/YIHAN/unet/model/")[1]}'
if not os.path.exists(PREDICT_PLT_DIR):
    os.makedirs(PREDICT_PLT_DIR)
    print(f"Dir {PREDICT_PLT_DIR} created.")
else:
    print(f"Dir {PREDICT_PLT_DIR} existed.")
# Out:
# Dir /home/cbel/Desktop/YIHAN/unet/plt/predict/model_v1_Apr-28_18-53-34 created.

# %%
import glob
import os

def find_latest_file(directory, pattern):
    search_pattern = os.path.join(directory, pattern)
    files = glob.glob(search_pattern)

    if not files:
        return None

    latest_file = max(files, key=os.path.getmtime)

    return latest_file

PATTERN = 'model_epoch*-val_loss*_*.m5.index'

latest_model_file = find_latest_file(f'{model_dir}', PATTERN)

latest_trained_model = os.path.splitext(os.path.splitext(os.path.basename(latest_model_file))[0])[0]

print(f'latest model file: {latest_trained_model}')
# Out:
# latest model file: model_epoch199-val_loss0.349663_Apr-28_18-53-34

# %%
# Compile a model and load our saved weights
from tensorflow.keras import Input

INPUT_LAYER = Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
KER_INIT = KER_INIT
DROPOUT = DROPOUT
LEARNING_RATE = LEARNING_RATE

best_saved_model = model_builders.get(MODEL_VERSION, unet_v1)(inputs=INPUT_LAYER, ker_init=KER_INIT, dropout=DROPOUT, kernel_size=KERNEL_SIZE)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity] )


best_saved_model.load_weights(f'{model_dir}/{latest_trained_model}.m5')
# Out:
# ****** using U-Net V1 ******

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '-t1c.nii.gz'
    flair_path = sample_path + '-t2f.nii.gz'
    #t1_path = sample_path + '_t1.nii'
    #t2_path = sample_path + '_t2.nii'
            
    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()
    
    # Create an empty array
    X = np.empty((VOLUME_SLICES_PLUS, IMG_SIZE, IMG_SIZE, 2))
    
    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES_PLUS):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
    # Send our images to the CNN model and return predicted segmentation 
    return best_saved_model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)
    print(f'random_sample: {random_sample}')
    
    # Get path of this patient
    random_sample_path = os.path.join(data_path_GLI_train_dir, random_sample, random_sample)
    print(f'random_sample_path: {random_sample_path}')
    
    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)
   
    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '-seg.nii.gz'
    seg = nib.load(seg_path).get_fdata()
    
    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    
    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    convert_all = all.astype(np.float32) if all.dtype == np.float16 else all
    convert_zero = zero.astype(np.float32) if zero.dtype == np.float16 else zero
    convert_first = first.astype(np.float32) if first.dtype == np.float16 else first
    convert_second = second.astype(np.float32) if second.dtype == np.float16 else second
    convert_third = third.astype(np.float32) if third.dtype == np.float16 else third

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')
    
    # Layers 1, 2, 3
    axstest[1].imshow(convert_all)
    axstest[1].set_title('Predicted Segmentation - all layers')
    
    # Layer 0
    axstest[2].imshow(convert_zero)
    axstest[2].set_title('Predicted Segmentation - layer 0')
    
    # Layer 1
    axstest[3].imshow(convert_first)
    axstest[3].set_title('Predicted Segmentation - layer 1')
    
    # Layer 2
    axstest[4].imshow(convert_second)
    axstest[4].set_title('Predicted Segmentation - layer 2')
    
    # Layer 3
    axstest[5].imshow(convert_third)
    axstest[5].set_title('Predicted Segmentation - layer 3')
    
    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.savefig(f'{PREDICT_PLT_DIR}/{random_sample}.png', dpi=300)

    plt.show()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# %%
show_predicted_segmentations(datas_test, 60, cmap, norm)
# Out:
# random_sample: BraTS-GLI-00299-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-00299-000/BraTS-GLI-00299-000
# 3/3 [==============================] - 1s 193ms/step
# Patient number:  BraTS-GLI-00299-000

# %%
show_predicted_segmentations(datas_test, 50, cmap, norm)
# Out:
# random_sample: BraTS-GLI-01192-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-01192-000/BraTS-GLI-01192-000
# 3/3 [==============================] - 0s 39ms/step
# Patient number:  BraTS-GLI-01192-000

# %%
show_predicted_segmentations(datas_test, 70, cmap, norm)
# Out:
# random_sample: BraTS-GLI-00334-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-00334-000/BraTS-GLI-00334-000
# 3/3 [==============================] - 0s 39ms/step
# Patient number:  BraTS-GLI-00334-000

# %%
def show_post_processed_segmentations(sample, slice_to_plot, cmap, norm):
    
    # Get path of this patient
    sample_path = os.path.join(data_path_GLI_train_dir, sample, sample)
    
    # Predict patient's segmentation
    predicted_seg = predict_segmentation(sample_path)
   
    # Load patient's original segmentation (Ground truth)
    seg_path = sample_path + '-seg.nii.gz'
    seg = nib.load(seg_path).get_fdata()
    
    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    
    # Fix 4 to 3 to have the same values as in the predicted segmentation, and then same colors
    seg[seg==4] = 3
    
    # Remove background layer (0) from original segmentation
    seg[seg==0] = np.nan
    
    # Post-processing
    # Get indexes for each class of the highest probability pixels. Array will then contain only [0 1 2 3] instead of probabilities
    my_pred = np.argmax(predicted_seg, axis=3)
    my_pred = my_pred[slice_to_plot, :, :]

    # Remove background layer (0) from post-processed predicted segmentation
    # To fix 0 to np.nan, we need to convert array as a float
    my_pred = my_pred.astype(float)
    my_pred[my_pred == 0] = np.nan

    # Remove background layer (0) from classical predicted segmentation
    all = predicted_seg[slice_to_plot,:,:,1:4] 

    convert_all = all.astype(np.float32) if all.dtype == np.float16 else all
    
    # Plot Original segmentation & predicted segmentation without processing & predicted segmentation
    print("Patient number: ", sample)
    fig, axstest = plt.subplots(1, 3, figsize=(15, 10))

    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')
    
    axstest[1].imshow(convert_all)
    axstest[1].set_title('Prediction (w/o post processing (layer 1,2,3)')
    
    axstest[2].imshow(my_pred, cmap, norm)
    axstest[2].set_title('Prediction (w/ post processing (layer 1,2,3)')
    
    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)
    plt.savefig(f'{PREDICT_PLT_DIR}/{sample}.png', dpi=300)
    
    plt.show()

# %%
show_post_processed_segmentations(sample = "BraTS-GLI-00777-000", slice_to_plot=60, cmap=cmap, norm=norm)
# Out:
# 3/3 [==============================] - 0s 39ms/step
# Patient number:  BraTS-GLI-00777-000

# %%
show_post_processed_segmentations(sample = "BraTS-GLI-00675-000", slice_to_plot=50, cmap=cmap, norm=norm)
# Out:
# 3/3 [==============================] - 0s 39ms/step
# Patient number:  BraTS-GLI-00675-000

# %% [markdown]
# ### Step 6 - Evaluate the model

# %%
import sys
# Evaluate the model on the test data
test_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(TEST_PKL if DATA_GENERATOR_VERSION == 3 else datas_test)
results = best_saved_model.evaluate(test_generator, batch_size=200, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

print("\nModel evaluation on the test set:")

original_stdout = sys.stdout
with open(f'{model_dir}/predict_result.log', 'w') as predict_log_file:
    sys.stdout = predict_log_file

    # Display each metric with its description
    print("==================================")
    for i, (metric, description) in enumerate(results_list):
        print(f"{description} : {round(metric, 4)}")
    print("==================================")

sys.stdout = original_stdout
# Out:
# ------ usging Data Generator V3: use crop NIIs ------
# 795/795 [==============================] - 5s 5ms/step - loss: 0.1106 - accuracy: 0.9839 - mean_io_u_1: 0.7774 - dice_coef: 0.6949 - precision: 0.9837 - sensitivity: 0.9836 - specificity: 0.9946
#
# Model evaluation on the test set:
