# %% [markdown]
# <div style="border-left: 5px solid green; padding: 10px; background-color:rgb(224, 247, 206);">
#     <b>⚡️ Information:</b>
#     Yihan's customized unet experiment
# </div>

# %% [markdown]
# ### Step 0 - Set & Check available memory

# %%
import tensorflow as tf
MEMORY_SIZE = 18
memory_limit = MEMORY_SIZE * 1024

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]  # Set limit to 15GB
        )
        print(f"Limited GPU memory usage to {MEMORY_SIZE}GB")
    except RuntimeError as e:
        print(e)
# Out:
# Limited GPU memory usage to 18GB

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for i, gpu in enumerate(gpus):
        device_name = f"GPU:{i}"  # Properly format the device name
        details = tf.config.experimental.get_memory_info(device_name)
        print(f"GPU: {device_name}")
        print(f"Current Memory Usage: {details['current']} bytes")
        print(f"Peak Memory Usage: {details['peak']} bytes")
else:
    print("No GPU devices found.")

for gpu in gpus:
    print(f"Memory growth for {gpu}: {tf.config.experimental.get_memory_growth(gpu)}")
# Out:
# GPU: GPU:0
# Current Memory Usage: 93877248 bytes
# Peak Memory Usage: 1295544576 bytes
# Memory growth for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): None

# %% [markdown]
# ### Step 1 - Set up environment

# %%
import nibabel as nib
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from skimage.transform import rotate
from skimage.util import montage
import os
from sklearn.model_selection import train_test_split
import keras
import cv2
import tensorflow
import random
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import numpy as np
from keras.callbacks import CSVLogger
import keras.backend as K
import zipfile
import pandas as pd

# %% [markdown]
# #### paths, VOLUME_*, IMG_SIZE, N_CHANNELS

# %%
# Specify a sample path (here we will take the first patient of the Training dataset)
brats_index = 'BraTS-GLI-00077-000'
brats_sample_path = f'../brain_tumor_seg/data/raw_data/GLI_train/{brats_index}/{brats_index}-'

# Specify the root data path of training data
# data_path_GLI_train_dir = f'../brain_tumor_seg/data/raw_data/GLI_train'
data_path_GLI_train_dir = f'/home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train'


# Define selected slices range
VOLUME_START_AT = 40 
VOLUME_SLICES_PLUS = 76 
TUMOR_RATIO_LOWER_BOUND = 0.15
TUMOR_RATIO_UPPER_BOUND = 0.2

# For DataGenerator
IMG_SIZE = 64
N_CHANNELS = 2

# %% [markdown]
# ### Not a Step - Explore data

# %%
# Load the 4 MRI modalities and the segmentation located in the patient's path using the nibabel library
t1_img_sample=nib.load(brats_sample_path + 't1n.nii.gz')
t1ce_img_sample=nib.load(brats_sample_path + 't1c.nii.gz')
t2_img_sample=nib.load(brats_sample_path + 't2w.nii.gz')
flair_img_sample=nib.load(brats_sample_path + 't2f.nii.gz')
seg_img_sample=nib.load(brats_sample_path + 'seg.nii.gz')

# Get the image data
t1_data_sample = t1_img_sample.get_fdata()
t1ce_data_sample = t1ce_img_sample.get_fdata()
t2_data_sample = t2_img_sample.get_fdata()
flair_data_sample = flair_img_sample.get_fdata()
seg_data_sample = seg_img_sample.get_fdata()

# Plot the 100th slice of the 4 RMI modalities and the segmentation
slice_nb = 100

fig, axs = plt.subplots(1, 5, figsize=(20,20))
axs[0].imshow(t1_data_sample[:,:,slice_nb], cmap="gray")
axs[0].set_title('T1')
axs[1].imshow(t1ce_data_sample[:,:,slice_nb], cmap="gray")
axs[1].set_title('T1CE')
axs[2].imshow(t2_data_sample[:,:,slice_nb], cmap="gray")
axs[2].set_title('T2')
axs[3].imshow(flair_data_sample[:,:,slice_nb], cmap="gray")
axs[3].set_title('FLAIR')
axs[4].imshow(seg_data_sample[:,:,slice_nb], cmap="gray")
axs[4].set_title('Segmentation')
plt.savefig(f'./plt/seg_classes_{brats_index}.png', dpi=300)
plt.show()

# %%
# Plot a RMI modality through all planes
slice_nb = 100

fig, axs2 = plt.subplots(1, 3, figsize=(10,10))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
axs2[0].imshow(rotate(t1_data_sample[slice_nb,:,:], 90, resize=True), cmap="gray")
axs2[0].set_title('T1 - Sagittal View')

axs2[1].imshow(rotate(t1_data_sample[:,slice_nb,:], 90, resize=True), cmap="gray")
axs2[1].set_title('T1 - Coronal View')

axs2[2].imshow(t1_data_sample[:,:,slice_nb], cmap="gray")
axs2[2].set_title('T1 - Axial View')

plt.show()

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data_sample[:,:,:]), 90, resize=True), cmap ='gray')

# montage allows us to concatenate multiple images of the same size horizontally and vertically

# %%
# Display all slices of a segmentation
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(seg_data_sample[:,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(t1_data_sample[60:135,:,:]), 90, resize=True), cmap ='gray')

# %%
# Plot a segmantation
some_seg_img = nib.load(f'{brats_sample_path}seg.nii.gz').get_fdata()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

plt.imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
plt.title(brats_index)
plt.colorbar()

# %%
seg_samples = [os.path.join(data_path_GLI_train_dir, sample, f"{sample}-seg.nii.gz") for sample in os.listdir(data_path_GLI_train_dir) if not sample.endswith('.csv')]

saved_values = []
max_nb_values = 0
for sample in seg_samples:
    seg_img_sample = nib.load(sample).get_fdata()
    unique_values = np.unique(seg_img_sample)
    nb_unique_values = len(np.unique(seg_img_sample))
    
    if nb_unique_values > max_nb_values:
        max_nb_values = nb_unique_values
        saved_values = unique_values

print(f"Maximum number of values in all segmentation images: {max_nb_values}")
print(f"Values: {saved_values}")

# %%
# Deletion of class 0
seg_0 = some_seg_img.astype(float).copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = some_seg_img.astype(float).copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = some_seg_img.astype(float).copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_3 = some_seg_img.astype(float).copy()
seg_3[seg_3 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 3']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, axs3 = plt.subplots(1, 5, figsize=(15, 15))

axs3[0].imshow(some_seg_img[100,:,:], cmap=cmap, norm=norm)
axs3[0].set_title('Original Segmentation')
axs3[0].legend(handles=legend, loc='upper right')

axs3[1].imshow(seg_0[100,:,:], cmap=cmap, norm=norm)
axs3[1].set_title('[Not Tumor] class 0')

axs3[2].imshow(seg_1[100,:,:], cmap=cmap, norm=norm)
axs3[2].set_title('[NCR] class 1')

axs3[3].imshow(seg_2[100,:,:], cmap=cmap, norm=norm)
axs3[3].set_title('[ED] class 2')

axs3[4].imshow(seg_3[100,:,:], cmap=cmap, norm=norm)
axs3[4].set_title('[ET] class 3')

# Save the figure to a file
plt.savefig('segmentation_classes.png', dpi=300)  # Saves the image as 'segmentation_classes.png'

plt.show()

# %%
values, counts = np.unique(some_seg_img, return_counts=True)
print(f'distribution of 4 classes: {counts}')

# %%
# Modality shape
print(f'modality shape: {t1_data_sample.shape}')

# Segmentation shape
print(f'segmentation shape: {seg_data_sample.shape}')

# %% [markdown]
# ### Step 2 - Load images and parameters

# %%
# Retrieve all samples from path with listdir(). This method lists of all files + directories in the specified directory.
all_datas = os.listdir(data_path_GLI_train_dir)
print("Number of samples:", len(all_datas))
# Out:
# Number of samples: 1251

# %%
# Split the dataset into train and validation sets
datas_train, datas_val = train_test_split(all_datas, test_size=0.2, random_state=42)

# Split the train set into the real train set and in a test set 
datas_train, datas_test = train_test_split(datas_train, test_size=0.15, random_state=42)

# Print data distribution (Train: 68%, Test: 12%, Val: 20%)
print(f"Train length: {len(datas_train)}")
print(f"Validation length: {len(datas_val)}")
print(f"Test length: {len(datas_test)}")
# Out:
# Train length: 850
# Validation length: 251
# Test length: 150

# %%
pip show keras tensorflow # type: ignore
# Out:
# Name: keras
# Version: 2.7.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /home/cbel/Desktop/YIHAN/venv/lib/python3.8/site-packages
# Requires:
# Required-by: tensorflow
# ---
# Name: tensorflow
# Version: 2.7.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /home/cbel/Desktop/YIHAN/venv/lib/python3.8/site-packages
# Requires: tensorflow-estimator, wrapt, wheel, keras-preprocessing, tensorboard, opt-einsum, google-pasta, grpcio, h5py, six, astunparse, numpy, termcolor, keras, protobuf, tensorflow-io-gcs-filesystem, libclang, gast, typing-extensions, absl-py, flatbuffers
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print("===============================")
print(f'tensorflow version: {tf.__version__}')  # Should print 2.7.0
print(f'is built with CUDA: {tf.test.is_built_with_cuda()}')  # Should return True
print(f'GPU details: {tf.config.list_physical_devices("GPU")}')  # Should show GPU details

# Check if TensorFlow can detect a GPU
if tf.config.list_physical_devices('GPU'):
    print("GPU is available.")
else:
    print("GPU is not available.")

print("===============================")
# Out:
# ===============================
# tensorflow version: 2.7.0
# is built with CUDA: True
# GPU details: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU is available.
# ===============================

# %% [markdown]
# ### Skip if no need - combine existing pkl

# %%
import pickle
import csv

DATA_1_DIR = 'processed_data_0.05_0.1'
DATA_2_DIR = 'processed_data_0.1_0.25'
COMBINED_DATA_DIR = 'processed_data_0.05_0.25'
SET = 'test'


with open(f'./data/{DATA_1_DIR}/processed_{SET}_data.pkl', 'rb') as f:
    data1 = pickle.load(f)
with open(f'./data/{DATA_2_DIR}/processed_{SET}_data.pkl', 'rb') as f:
    data2 = pickle.load(f)
combined_data = data1.copy()
combined_data.update(data2)
with open(f'./data/{COMBINED_DATA_DIR}/processed_{SET}_data.pkl', 'wb') as f:
    pickle.dump(combined_data, f)


with open(f'./data/{DATA_1_DIR}/{SET}_data_info.csv', 'r') as csv1, open(f'./data/{DATA_2_DIR}/{SET}_data_info.csv', 'r') as csv2:
    reader1 = csv.reader(csv1)
    reader2 = csv.reader(csv2)

    with open(f'./data/{COMBINED_DATA_DIR}/{SET}_data_info.csv', 'w', newline='') as csv_out:
        writer = csv.writer(csv_out)
        for row in reader1:
            writer.writerow(row)
        next(reader2)
        for row in reader2:
            writer.writerow(row)

# %% [markdown]
# ### Step * Crop Nii files

# %% [markdown]
# #### Step * - 1: Set up params & crop method

# %%
import pickle
import os
import nibabel as nib
import cv2
import numpy as np
import csv

total_slices_dict = {
    "train": 0,
    "val": 0,
    "test": 0
}

def preprocess_and_save(data_list, save_path, log_path, tumor_ratio_lower_bound, tumor_ratio_upper_bound):
    processed_data = {'X': [], 'y': []}
    slice_info = {}  # Dictionary to store slice information for each NIfTI

    with open(log_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['NIfTI ID', 'Slice Index', 'Tumor Ratio', 'Brain Area'])

        total_slices = 0

        for i in data_list:
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()

            slice_info[i] = []  # Initialize list for each NIfTI

            for j in range(VOLUME_SLICES_PLUS):
                slice_seg = seg[:, :, j + VOLUME_START_AT]
                slice_flair = flair[:, :, j + VOLUME_START_AT]
                tumor_area = np.sum(slice_seg > 0)
                brain_area = np.sum(slice_flair > 0)  # Use non-zero pixels in FLAIR as brain area

                # Avoid division by zero
                if brain_area == 0:
                    continue

                tumor_percentage = tumor_area / brain_area

                if tumor_ratio_lower_bound < tumor_percentage <= tumor_ratio_upper_bound:
                    X_slice = np.zeros((IMG_SIZE, IMG_SIZE, N_CHANNELS))
                    X_slice[:, :, 0] = cv2.resize(slice_flair, (IMG_SIZE, IMG_SIZE))
                    X_slice[:, :, 1] = cv2.resize(t1ce[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                    processed_data['X'].append(X_slice)
                    processed_data['y'].append(slice_seg)
                    slice_info[i].append(j + VOLUME_START_AT)  # Record the slice index

                    # Write slice information to CSV file
                    csv_writer.writerow([i, j + VOLUME_START_AT, round(tumor_percentage, 4), brain_area])
                    total_slices += 1

        total_slices_dict[log_path.split('/')[-1].split('_')[0]] = total_slices

    # Save the processed data
    with open(save_path, 'wb') as f:
        pickle.dump(processed_data, f)

def count_rows_in_csv(file_path):
    with open(file_path, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader, None)
        row_count = sum(1 for row in reader)
    return row_count

# %%
import csv
import os

def append_to_csv(file_path, data, header=None):
    file_exists = os.path.isfile(file_path)

    with open(file_path, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        if header and not file_exists:
            writer.writerow(header)
        writer.writerows(data)

# %% [markdown]
# #### Step * - 2: Crop

# %%
from datetime import datetime
import gc

processed_data_dir_root = f'./data/dimension_{IMG_SIZE}/processed_data_{TUMOR_RATIO_LOWER_BOUND}_{TUMOR_RATIO_UPPER_BOUND}'
processed_data_lists_csv = f'./data/dimension_{IMG_SIZE}/processed_data_lists.csv'
processed_data_lists_header = ['tumor_ratio_lower_bound', 'tumor_ratio_upper_bound', 'train_slices', 'val_slices', 'test_slices', 'generated_timestamp']

print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')

if not os.path.exists(processed_data_dir_root):
    os.makedirs(processed_data_dir_root)
    print("dir processed_data created.")

    preprocess_and_save(datas_train, f'{processed_data_dir_root}/processed_train_data.pkl', f'{processed_data_dir_root}/train_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()
    preprocess_and_save(datas_val, f'{processed_data_dir_root}/processed_val_data.pkl', f'{processed_data_dir_root}/val_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()
    preprocess_and_save(datas_test, f'{processed_data_dir_root}/processed_test_data.pkl', f'{processed_data_dir_root}/test_data_info.csv', TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND)
    gc.collect()

    processed_data_lists_data = [
        [TUMOR_RATIO_LOWER_BOUND, TUMOR_RATIO_UPPER_BOUND, total_slices_dict["train"], total_slices_dict["val"], total_slices_dict["test"], datetime.now().strftime("%b-%d_%H-%M-%S")]
    ]
    append_to_csv(processed_data_lists_csv, processed_data_lists_data, processed_data_lists_header)

else:
    print(f'dir processed_data existed at {processed_data_dir_root}.')

# set the data info to params
TRAIN_PKL = f'{processed_data_dir_root}/processed_train_data.pkl'
VAL_PKL = f'{processed_data_dir_root}/processed_val_data.pkl'
TEST_PKL = f'{processed_data_dir_root}/processed_test_data.pkl'
TRAIN_PKL_CSV = f'{processed_data_dir_root}/train_data_info.csv'
VAL_PKL_CSV = f'{processed_data_dir_root}/val_data_info.csv'
TEST_PKL_CSV = f'{processed_data_dir_root}/test_data_info.csv'
total_slices_dict.update({
    "train": count_rows_in_csv(TRAIN_PKL_CSV),
    "val": count_rows_in_csv(VAL_PKL_CSV),
    "test": count_rows_in_csv(TEST_PKL_CSV)
})

print(f'train: {total_slices_dict["train"]} slices')
print(f'val: {total_slices_dict["val"]} slices')
print(f'test: {total_slices_dict["test"]} slices')
# Out:
# tumor ratio: 0.15 ~ 0.2
# dir processed_data existed at ./data/dimension_256/processed_data_0.15_0.2.
# train: 7678 slices
# val: 2139 slices
# test: 1382 slices

# %% [markdown]
# ### Step 3 - Set up training compoenents

# %% [markdown]
# **When generating `DataGenerator`**:
# - We use a data generator to be able to process and send our data to our neural network (since all our images cannot be stored in memory at once).
# - For each epoch (single pass of the entire training dataset through a neural network), the model will receive 250 samples (those contained in our training dataset).
# - For each sample, the model will have to analyze 150 slices (since there are two modalities, and 75(VOLUME_SLICES) selected slices for both of them), received in a (128, 128) shape, as an X array of a (128, 128, 75, 2) shape. This array will be provided with the ground truth segmentation of the patient, which will be One-Hot encoded and will then have a (75, 128, 128, 4) shape.

# %% [markdown]
# #### 3 - 1: DataGenerator

# %% [markdown]
# ##### 3-1-1 DataGenerator_UnetV1

# %%
from tensorflow.keras import layers, models

# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net

class DataGenerator_UnetV1(keras.utils.all_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = N_CHANNELS, shuffle=True):
        print('------ usging Data Generator V1 ------')
        'Initialization'
        self.dim = dim # Resized image dimensions (128 x 128)
        self.batch_size = batch_size #  Number of images to load each time
        self.list_IDs = list_IDs # Patients IDs
        self.n_channels = n_channels # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle # Indicates if data is shuffled for each epoch
        self.on_epoch_end() # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):
            
            # Get path of each RMI modality and the segmentation
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            #t1_path = sample_path + '_t1.nii.gz'
            #t2_path = sample_path + '_t2.nii.gz'
            
            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()
        
            for j in range(VOLUME_SLICES_PLUS):
                 X[j +VOLUME_SLICES_PLUS*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                 X[j +VOLUME_SLICES_PLUS*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES_PLUS*c] = seg[:,:,j+VOLUME_START_AT]
                    
        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %% [markdown]
# ##### 3-1-2 DataGenerator_UnetV2

# %%
from tensorflow.keras import layers, models

# DataGenerator from Rastislav's notebook, https://www.kaggle.com/code/rastislav/3d-mri-brain-tumor-segmentation-u-net

class DataGenerator_UnetV2(keras.utils.all_utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = N_CHANNELS, shuffle=True):
        print('------ usging Data Generator V2 ------')
        'Initialization'
        self.dim = dim # Resized image dimensions (128 x 128)
        self.batch_size = batch_size #  Number of images to load each time
        self.list_IDs = list_IDs # Patients IDs
        self.n_channels = n_channels # Number of channels (T1CE + FLAIR)
        self.shuffle = shuffle # Indicates if data is shuffled for each epoch
        self.on_epoch_end() # Updates indexes after each epoch

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Load & Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES_PLUS, 240, 240))

        # Generate data
        for c, i in enumerate(Batch_ids):
            
            # Get path of each RMI modality and the segmentation
            data_path = os.path.join(data_path_GLI_train_dir, i, i)
            t1ce_path = data_path + '-t1c.nii.gz'
            flair_path = data_path + '-t2f.nii.gz'
            seg_path = data_path + '-seg.nii.gz'
            #t1_path = sample_path + '_t1.nii.gz'
            #t2_path = sample_path + '_t2.nii.gz'
            
            # Extract the data from these paths
            t1ce = nib.load(t1ce_path).get_fdata()
            flair = nib.load(flair_path).get_fdata()
            seg = nib.load(seg_path).get_fdata()
            #t1 = nib.load(t1_paths).get_fdata()
            #t2 = nib.load(t2_path).get_fdata()
        
            for j in range(VOLUME_SLICES_PLUS):
                 X[j +VOLUME_SLICES_PLUS*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                 y[j +VOLUME_SLICES_PLUS*c] = seg[:,:,j+VOLUME_START_AT]
                    
        # Masks / Segmentations
        y[y==4] = 3
        mask = tensorflow.one_hot(y, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Scale data between 0 and 1 (since the minimum value in the data is 0)
        return X/np.max(X), Y

# %% [markdown]
# ##### 3-1-3 DataGenerator_UnetV3_count_image_ratio

# %%
from tensorflow.keras import layers, models

class DataGenerator_UnetV3_count_image_ratio(keras.utils.all_utils.Sequence):
    def __init__(self, data_path, batch_size=1, shuffle=True):
        print('------ usging Data Generator V3: use crop NIIs ------')
        with open(data_path, 'rb') as f:
            self.data = pickle.load(f)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.data['X']))
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.data['X']) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        X_batch = [self.data['X'][k] for k in indexes]
        y_batch = [self.data['y'][k] for k in indexes]

        y_batch = np.array(y_batch)
        y_batch[y_batch == 4] = 3
        mask = tensorflow.one_hot(y_batch, 4)
        Y = tensorflow.image.resize(mask, (IMG_SIZE, IMG_SIZE))

        return np.array(X_batch) / np.max(X_batch), Y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# #### 3 -2: U-Net model

# %% [markdown]
# ##### 3-2-1 U-Net v1

# %%
# U-Net implementation for BraTS 2019 by Naomi Fridman, https://naomi-fridman.medium.com/multi-class-image-segmentation-a5cc671e647a
def unet_v1(inputs, ker_init, dropout, kernel_size=3):
    print('****** using U-Net V1 ******')
    conv1 = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)
    
    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    
    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = 2)(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    conv10 = Conv2D(4, 1, activation = 'softmax')(conv)
    
    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# ##### 3-2-2: U-Net V2

# %%
def unet_v2(inputs, ker_init, dropout=0.5, kernel_size=3):
    print('****** using U-Net V2 ******')
    conv1 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool3)
    conv4 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv4)
    drop4 = Dropout(dropout)(conv4)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
    conv5 = Conv2D(1024, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(1024, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge6)
    conv6 = Conv2D(512, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    conv9 = Conv2D(2, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    conv10 = Conv2D(4, 1, activation = 'sigmoid')(conv9)

    return Model(inputs = inputs, outputs = conv10)

# %% [markdown]
# #### 3 - 3: Loss Functions

# %%
def categorical_dice_loss(y_true, y_pred, smooth=1e-6):
    intersection = K.sum(y_true * y_pred, axis=[0,1,2])
    union = K.sum(y_true, axis=[0,1,2]) + K.sum(y_pred, axis=[0,1,2])
    dice_loss = 1 - K.mean((2. * intersection + smooth) / (union + smooth))
    return dice_loss

def focal_loss(alpha=0.25, gamma=2.0):
    def loss(y_true, y_pred):
        ce = tf.keras.losses.CategoricalCrossentropy()(y_true, y_pred)
        pt = tf.exp(-ce)  # 計算 p_t
        focal_loss = alpha * (1 - pt) ** gamma * ce
        return focal_loss
    return loss

def focal_dice_loss(y_true, y_pred):
    return focal_loss()(y_true, y_pred) + categorical_dice_loss(y_true, y_pred)

# %% [markdown]
# #### 3 - 4: Metrics

# %%
# Compute metric between the predicted segmentation and the ground truth
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

########################### my customized metrics ###########################

def sensibility(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Calculate the sensibility
    sensibility = 1 - (false_positives / (true_positives + possible_positives + K.epsilon()))
    # Check for NaN or Inf values and return NaN if True
    sensibility = tf.where(tf.math.is_nan(sensibility) | tf.math.is_inf(sensibility),
                           tf.constant(float('NaN')),
                           sensibility)
    return sensibility


def jaccard(y_true, y_pred):
    # True positives, false positives, false negatives
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)))
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)))
    # Calculate Jaccard index
    denominator = true_positives + false_positives + false_negatives + K.epsilon()  # Add epsilon to avoid division by zero
    result = true_positives / denominator
    # Handle NaN or Inf cases
    result = K.switch(K.is_inf(result) | K.is_nan(result), K.constant(float('NaN')), result)
    return result


# Hausdorff distance (approximation for use in Keras)
def hausdorff(y_true, y_pred):
    # Flatten the coordinates of the true and predicted segmentation masks
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    # Compute the Euclidean distance between every pair of points
    dist_matrix = K.square(y_true_flat - y_pred_flat)
    # Get the maximum distance in both directions (directed Hausdorff)
    directed_hausdorff_1 = K.max(dist_matrix, axis=1)  # From y_true to y_pred
    directed_hausdorff_2 = K.max(dist_matrix, axis=0)  # From y_pred to y_true
    # Take the maximum of both directed Hausdorff distances
    hausdorff_dist = K.maximum(directed_hausdorff_1, directed_hausdorff_2)
    # Handle NaN or Inf values by replacing them with NaN (if needed)
    hausdorff_dist = K.switch(K.is_inf(hausdorff_dist) | K.is_nan(hausdorff_dist), K.constant(float('NaN')), hausdorff_dist)
    return hausdorff_dist

# %% [markdown]
# #### 3 - 5: Define training params

# %%
from keras import Input

MODEL_VERSION = 1
DATA_GENERATOR_VERSION = 3

EPOCHS = 200
STEPS_PER_EPOCH = len(datas_train)

INPUT_LAYER = Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
KER_INIT = 'he_normal'
DROPOUT = 0.2
KERNEL_SIZE = 5
LEARNING_RATE = 1e-4
# LOSS_FUNCTION = "categorical_crossentropy"
LOSS_FUNCTION = focal_dice_loss

# %% [markdown]
# #### 3 - 6: Build the model

# %%
# Build and compile the model
model_builders = {
    1: unet_v1,
    2: unet_v2
}
model = model_builders.get(MODEL_VERSION, unet_v1)(inputs=INPUT_LAYER, ker_init=KER_INIT, dropout=DROPOUT, kernel_size=KERNEL_SIZE)

model.compile(loss=LOSS_FUNCTION, optimizer=tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity ] )
# Out:
# ****** using U-Net V1 ******

# %% [markdown]
# #### 3 - 7: Set up DataGenerator

# %%
data_generators = {
    1: DataGenerator_UnetV1,
    2: DataGenerator_UnetV2,
    3: DataGenerator_UnetV3_count_image_ratio
}

training_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(TRAIN_PKL if DATA_GENERATOR_VERSION == 3 else datas_train)
valid_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(VAL_PKL if DATA_GENERATOR_VERSION == 3 else datas_val)
# Out:
# ------ usging Data Generator V3: use crop NIIs ------
# ------ usging Data Generator V3: use crop NIIs ------

# %% [markdown]
# #### 3 - 8: Do the GC and check the GPU and memory status

# %%
import tensorflow as tf
import gc

gc.collect()

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for i, gpu in enumerate(gpus):
        device_name = f"GPU:{i}"  # Properly format the device name
        details = tf.config.experimental.get_memory_info(device_name)
        print(f"GPU: {device_name}")
        print(f"Current Memory Usage: {details['current']} bytes")
        print(f"Peak Memory Usage: {details['peak']} bytes")
else:
    print("No GPU devices found.")

for gpu in gpus:
    print(f"Memory growth for {gpu}: {tf.config.experimental.get_memory_growth(gpu)}")
# Out:
# GPU: GPU:0
# Current Memory Usage: 175609600 bytes
# Peak Memory Usage: 1295544576 bytes
# Memory growth for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'): None

# %%
# Mixed Precision Training
# from tensorflow.keras.mixed_precision import experimental as mixed_precision

# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_policy(policy)

# %% [markdown]
# #### 3 - 9: Set up callbacks
#
# Callbacks are functions that can be executed during the training process.
#
# We will use three callbacks:
#
# - **ReduceLROnPlateau**: This callback reduces the learning rate when a metric has stopped improving (validation loss here). The learning rate is reduced by a factor of 0.2, the patience is set to 2 epochs, and the minimum learning rate is set to 0.000001.
#
# - **ModelCheckpoint**: Saves the best model weights (model that has obtained the lowest validation loss during the different epochs). Saving a model allows us to reuse it later or to share it, without having to retrain it from scratch. This will save us time and resources!
#
# - **CSVLogger**: Add metrics to a CSV file, which is named *training.log* (parameter `append` is set to `False` so the file is overwritten if it already exists).

# %%
from datetime import datetime
import os

# Generate timestamp for filenames
start_train_timestamp = datetime.now().strftime("%b-%d_%H-%M-%S")

# model_dir = f'./model/model_v{MODEL_VERSION}_{start_train_timestamp}'
model_dir = f'/home/cbel/Desktop/YIHAN/unet/model/model_v{MODEL_VERSION}_{start_train_timestamp}'


if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    print(f"Model dir {model_dir} created.")
else:
    print(f"Model dir {model_dir} existed.")

# Define file paths with timestamps
training_log_filename = f"{model_dir}/training-{start_train_timestamp}.log"
model_checkpoint_path = f"{model_dir}/model_epoch{{epoch:02d}}-val_loss{{val_loss:.6f}}_{start_train_timestamp}.m5"

callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.000001, verbose=1),
    
    keras.callbacks.ModelCheckpoint(filepath=model_checkpoint_path, verbose=1, save_best_only=True, save_weights_only=True),

    CSVLogger(training_log_filename, separator=',', append=False)  # Save logs with timestamp
]
# Out:
# Model dir /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22 created.

# %% [markdown]
# ### Step 4 - Train & Save the model

# %% [markdown]
# #### 4 - 1: log all cell outputs during training

# %%
import sys

print(f'----------')
print(f'model name: {model_builders[MODEL_VERSION].__name__}')
print(f'epochs: {EPOCHS}')
print(f'steps_per_epoch: {STEPS_PER_EPOCH}')
print(f'dimension: {IMG_SIZE}')
print(f'n_channels: {N_CHANNELS}')
print(f'input layer: {INPUT_LAYER}')
print(f'kernel init: {KER_INIT}')
print(f'kernel size: {KERNEL_SIZE}')
print(f'dropout: {DROPOUT}')
print(f'learning rate: {LEARNING_RATE}')
print(f'loss function: {LOSS_FUNCTION}')
    
print(f"train cases: {len(datas_train)}")
print(f'train slices: {total_slices_dict["train"]}')
print(f"validation cases: {len(datas_val)}")
print(f'val slices: {total_slices_dict["val"]}')
print(f'slice index: {VOLUME_START_AT} ~ {VOLUME_START_AT + VOLUME_SLICES_PLUS}')
print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')
print(f"test cases: {len(datas_test)}")

print(f'start training at: {start_train_timestamp}')
print(f'----------')

original_stdout = sys.stdout
with open(f'{model_dir}/info.log', 'w') as predict_log_file:
    sys.stdout = predict_log_file
    print(f'----------')
    print(f'model name: {model_builders[MODEL_VERSION].__name__}')
    print(f'epochs: {EPOCHS}')
    print(f'steps_per_epoch: {STEPS_PER_EPOCH}')
    print(f'dimension: {IMG_SIZE}')
    print(f'n_channels: {N_CHANNELS}')
    print(f'input layer: {INPUT_LAYER}')
    print(f'kernel init: {KER_INIT}')
    print(f'kernel size: {KERNEL_SIZE}')
    print(f'dropout: {DROPOUT}')
    print(f'learning rate: {LEARNING_RATE}')
    print(f'loss function: {LOSS_FUNCTION}')

    print(f"train cases: {len(datas_train)}")
    print(f'train slices: {total_slices_dict["train"]}')
    print(f"validation cases: {len(datas_val)}")
    print(f'val slices: {total_slices_dict["val"]}')
    print(f'slice index: {VOLUME_START_AT} ~ {VOLUME_START_AT + VOLUME_SLICES_PLUS}')
    print(f'tumor ratio: {TUMOR_RATIO_LOWER_BOUND} ~ {TUMOR_RATIO_UPPER_BOUND}')
    print(f"test cases: {len(datas_test)}")

    print(f'start training at: {start_train_timestamp}')
    print(f'----------')

sys.stdout = original_stdout
# Out:
# ----------
# model name: unet_v1
# epochs: 200
# steps_per_epoch: 850
# dimension: 256
# n_channels: 2
# input layer: KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 2), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# kernel init: he_normal
# kernel size: 5
# dropout: 0.2
# learning rate: 0.0001
# loss function: <function focal_dice_loss at 0x7efd9cf544c0>
# train cases: 850
# train slices: 7678
# validation cases: 251
# val slices: 2139
# slice index: 40 ~ 116
# tumor ratio: 0.15 ~ 0.2
# test cases: 150
# start training at: Apr-21_22-49-22
# ----------

# %% [markdown]
# #### 4 - 2: train

# %%
model.fit(training_generator,
          epochs=EPOCHS,
          steps_per_epoch=STEPS_PER_EPOCH,
          callbacks=callbacks,
          validation_data=valid_generator)
# Out:
# Epoch 1/200
# 850/850 [==============================] - ETA: 0s - loss: 0.5917 - accuracy: 0.9404 - mean_io_u_1: 0.7276 - dice_coef: 0.4215 - precision: 0.9550 - sensitivity: 0.9260 - specificity: 0.9859
# Epoch 00001: val_loss improved from inf to 0.41848, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch01-val_loss0.418483_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 41ms/step - loss: 0.5917 - accuracy: 0.9404 - mean_io_u_1: 0.7276 - dice_coef: 0.4215 - precision: 0.9550 - sensitivity: 0.9260 - specificity: 0.9859 - val_loss: 0.4185 - val_accuracy: 0.9579 - val_mean_io_u_1: 0.7986 - val_dice_coef: 0.5848 - val_precision: 0.9596 - val_sensitivity: 0.9555 - val_specificity: 0.9866 - lr: 1.0000e-04
# Epoch 2/200
# 850/850 [==============================] - ETA: 0s - loss: 0.3849 - accuracy: 0.9655 - mean_io_u_1: 0.8092 - dice_coef: 0.6238 - precision: 0.9660 - sensitivity: 0.9643 - specificity: 0.9887
# Epoch 00002: val_loss improved from 0.41848 to 0.35335, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch02-val_loss0.353349_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.3849 - accuracy: 0.9655 - mean_io_u_1: 0.8092 - dice_coef: 0.6238 - precision: 0.9660 - sensitivity: 0.9643 - specificity: 0.9887 - val_loss: 0.3533 - val_accuracy: 0.9727 - val_mean_io_u_1: 0.8688 - val_dice_coef: 0.6541 - val_precision: 0.9727 - val_sensitivity: 0.9720 - val_specificity: 0.9909 - lr: 1.0000e-04
# Epoch 3/200
# 850/850 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.9717 - mean_io_u_1: 0.8220 - dice_coef: 0.6784 - precision: 0.9715 - sensitivity: 0.9710 - specificity: 0.9905
# Epoch 00003: val_loss improved from 0.35335 to 0.31201, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch03-val_loss0.312010_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.3300 - accuracy: 0.9717 - mean_io_u_1: 0.8220 - dice_coef: 0.6784 - precision: 0.9715 - sensitivity: 0.9710 - specificity: 0.9905 - val_loss: 0.3120 - val_accuracy: 0.9651 - val_mean_io_u_1: 0.7772 - val_dice_coef: 0.6944 - val_precision: 0.9649 - val_sensitivity: 0.9645 - val_specificity: 0.9883 - lr: 1.0000e-04
# Epoch 4/200
# 850/850 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.9752 - mean_io_u_1: 0.8132 - dice_coef: 0.6981 - precision: 0.9750 - sensitivity: 0.9747 - specificity: 0.9917
# Epoch 00004: val_loss improved from 0.31201 to 0.28677, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch04-val_loss0.286772_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.3111 - accuracy: 0.9752 - mean_io_u_1: 0.8132 - dice_coef: 0.6981 - precision: 0.9750 - sensitivity: 0.9747 - specificity: 0.9917 - val_loss: 0.2868 - val_accuracy: 0.9774 - val_mean_io_u_1: 0.8201 - val_dice_coef: 0.7203 - val_precision: 0.9771 - val_sensitivity: 0.9768 - val_specificity: 0.9924 - lr: 1.0000e-04
# Epoch 5/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2818 - accuracy: 0.9790 - mean_io_u_1: 0.8380 - dice_coef: 0.7303 - precision: 0.9787 - sensitivity: 0.9784 - specificity: 0.9929
# Epoch 00005: val_loss improved from 0.28677 to 0.27938, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch05-val_loss0.279376_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2818 - accuracy: 0.9790 - mean_io_u_1: 0.8380 - dice_coef: 0.7303 - precision: 0.9787 - sensitivity: 0.9784 - specificity: 0.9929 - val_loss: 0.2794 - val_accuracy: 0.9809 - val_mean_io_u_1: 0.8778 - val_dice_coef: 0.7378 - val_precision: 0.9805 - val_sensitivity: 0.9804 - val_specificity: 0.9935 - lr: 1.0000e-04
# Epoch 6/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.9781 - mean_io_u_1: 0.8250 - dice_coef: 0.7231 - precision: 0.9778 - sensitivity: 0.9775 - specificity: 0.9926
# Epoch 00006: val_loss improved from 0.27938 to 0.26618, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch06-val_loss0.266182_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.2901 - accuracy: 0.9781 - mean_io_u_1: 0.8250 - dice_coef: 0.7231 - precision: 0.9778 - sensitivity: 0.9775 - specificity: 0.9926 - val_loss: 0.2662 - val_accuracy: 0.9818 - val_mean_io_u_1: 0.8870 - val_dice_coef: 0.7415 - val_precision: 0.9815 - val_sensitivity: 0.9813 - val_specificity: 0.9938 - lr: 1.0000e-04
# Epoch 7/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2834 - accuracy: 0.9810 - mean_io_u_1: 0.8950 - dice_coef: 0.7374 - precision: 0.9808 - sensitivity: 0.9806 - specificity: 0.9936
# Epoch 00007: val_loss did not improve from 0.26618
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2834 - accuracy: 0.9810 - mean_io_u_1: 0.8950 - dice_coef: 0.7374 - precision: 0.9808 - sensitivity: 0.9806 - specificity: 0.9936 - val_loss: 0.2765 - val_accuracy: 0.9764 - val_mean_io_u_1: 0.8717 - val_dice_coef: 0.7514 - val_precision: 0.9761 - val_sensitivity: 0.9760 - val_specificity: 0.9920 - lr: 1.0000e-04
# Epoch 8/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9844 - mean_io_u_1: 0.9027 - dice_coef: 0.7600 - precision: 0.9841 - sensitivity: 0.9840 - specificity: 0.9947
# Epoch 00008: val_loss improved from 0.26618 to 0.25003, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch08-val_loss0.250025_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2577 - accuracy: 0.9844 - mean_io_u_1: 0.9027 - dice_coef: 0.7600 - precision: 0.9841 - sensitivity: 0.9840 - specificity: 0.9947 - val_loss: 0.2500 - val_accuracy: 0.9832 - val_mean_io_u_1: 0.8608 - val_dice_coef: 0.7610 - val_precision: 0.9829 - val_sensitivity: 0.9828 - val_specificity: 0.9943 - lr: 1.0000e-04
# Epoch 9/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9841 - mean_io_u_1: 0.8965 - dice_coef: 0.7570 - precision: 0.9838 - sensitivity: 0.9836 - specificity: 0.9946
# Epoch 00009: val_loss improved from 0.25003 to 0.24185, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch09-val_loss0.241846_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2580 - accuracy: 0.9841 - mean_io_u_1: 0.8965 - dice_coef: 0.7570 - precision: 0.9838 - sensitivity: 0.9836 - specificity: 0.9946 - val_loss: 0.2418 - val_accuracy: 0.9860 - val_mean_io_u_1: 0.9318 - val_dice_coef: 0.7789 - val_precision: 0.9857 - val_sensitivity: 0.9857 - val_specificity: 0.9952 - lr: 1.0000e-04
# Epoch 10/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2431 - accuracy: 0.9857 - mean_io_u_1: 0.9104 - dice_coef: 0.7762 - precision: 0.9854 - sensitivity: 0.9853 - specificity: 0.9951
# Epoch 00010: val_loss did not improve from 0.24185
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2431 - accuracy: 0.9857 - mean_io_u_1: 0.9104 - dice_coef: 0.7762 - precision: 0.9854 - sensitivity: 0.9853 - specificity: 0.9951 - val_loss: 0.2481 - val_accuracy: 0.9856 - val_mean_io_u_1: 0.8883 - val_dice_coef: 0.7795 - val_precision: 0.9853 - val_sensitivity: 0.9852 - val_specificity: 0.9951 - lr: 1.0000e-04
# Epoch 11/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9846 - mean_io_u_1: 0.9113 - dice_coef: 0.7724 - precision: 0.9843 - sensitivity: 0.9842 - specificity: 0.9948
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00011: val_loss did not improve from 0.24185
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2482 - accuracy: 0.9846 - mean_io_u_1: 0.9113 - dice_coef: 0.7724 - precision: 0.9843 - sensitivity: 0.9842 - specificity: 0.9948 - val_loss: 0.2820 - val_accuracy: 0.9815 - val_mean_io_u_1: 0.8332 - val_dice_coef: 0.7336 - val_precision: 0.9813 - val_sensitivity: 0.9811 - val_specificity: 0.9938 - lr: 1.0000e-04
# Epoch 12/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9869 - mean_io_u_1: 0.8962 - dice_coef: 0.7888 - precision: 0.9866 - sensitivity: 0.9865 - specificity: 0.9955
# Epoch 00012: val_loss improved from 0.24185 to 0.23348, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch12-val_loss0.233476_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2362 - accuracy: 0.9869 - mean_io_u_1: 0.8962 - dice_coef: 0.7888 - precision: 0.9866 - sensitivity: 0.9865 - specificity: 0.9955 - val_loss: 0.2335 - val_accuracy: 0.9868 - val_mean_io_u_1: 0.9047 - val_dice_coef: 0.7927 - val_precision: 0.9865 - val_sensitivity: 0.9865 - val_specificity: 0.9955 - lr: 2.0000e-05
# Epoch 13/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9878 - mean_io_u_1: 0.9097 - dice_coef: 0.7895 - precision: 0.9875 - sensitivity: 0.9874 - specificity: 0.9958
# Epoch 00013: val_loss improved from 0.23348 to 0.22883, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch13-val_loss0.228833_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2268 - accuracy: 0.9878 - mean_io_u_1: 0.9097 - dice_coef: 0.7895 - precision: 0.9875 - sensitivity: 0.9874 - specificity: 0.9958 - val_loss: 0.2288 - val_accuracy: 0.9878 - val_mean_io_u_1: 0.9178 - val_dice_coef: 0.7956 - val_precision: 0.9875 - val_sensitivity: 0.9875 - val_specificity: 0.9958 - lr: 2.0000e-05
# Epoch 14/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9889 - mean_io_u_1: 0.9160 - dice_coef: 0.8058 - precision: 0.9885 - sensitivity: 0.9885 - specificity: 0.9962
# Epoch 00014: val_loss did not improve from 0.22883
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2184 - accuracy: 0.9889 - mean_io_u_1: 0.9160 - dice_coef: 0.8058 - precision: 0.9885 - sensitivity: 0.9885 - specificity: 0.9962 - val_loss: 0.2304 - val_accuracy: 0.9865 - val_mean_io_u_1: 0.9219 - val_dice_coef: 0.7902 - val_precision: 0.9862 - val_sensitivity: 0.9862 - val_specificity: 0.9954 - lr: 2.0000e-05
# Epoch 15/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9889 - mean_io_u_1: 0.9182 - dice_coef: 0.8121 - precision: 0.9886 - sensitivity: 0.9885 - specificity: 0.9962
# Epoch 00015: val_loss improved from 0.22883 to 0.22745, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch15-val_loss0.227454_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2082 - accuracy: 0.9889 - mean_io_u_1: 0.9182 - dice_coef: 0.8121 - precision: 0.9886 - sensitivity: 0.9885 - specificity: 0.9962 - val_loss: 0.2275 - val_accuracy: 0.9879 - val_mean_io_u_1: 0.9214 - val_dice_coef: 0.7964 - val_precision: 0.9876 - val_sensitivity: 0.9876 - val_specificity: 0.9959 - lr: 2.0000e-05
# Epoch 16/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9897 - mean_io_u_1: 0.9280 - dice_coef: 0.8194 - precision: 0.9893 - sensitivity: 0.9893 - specificity: 0.9964
# Epoch 00016: val_loss did not improve from 0.22745
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2033 - accuracy: 0.9897 - mean_io_u_1: 0.9280 - dice_coef: 0.8194 - precision: 0.9893 - sensitivity: 0.9893 - specificity: 0.9964 - val_loss: 0.2318 - val_accuracy: 0.9880 - val_mean_io_u_1: 0.9248 - val_dice_coef: 0.7992 - val_precision: 0.9877 - val_sensitivity: 0.9877 - val_specificity: 0.9959 - lr: 2.0000e-05
# Epoch 17/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.9896 - mean_io_u_1: 0.9286 - dice_coef: 0.8181 - precision: 0.9892 - sensitivity: 0.9892 - specificity: 0.9964
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 00017: val_loss did not improve from 0.22745
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2100 - accuracy: 0.9896 - mean_io_u_1: 0.9286 - dice_coef: 0.8181 - precision: 0.9892 - sensitivity: 0.9892 - specificity: 0.9964 - val_loss: 0.2289 - val_accuracy: 0.9884 - val_mean_io_u_1: 0.9377 - val_dice_coef: 0.8070 - val_precision: 0.9881 - val_sensitivity: 0.9881 - val_specificity: 0.9960 - lr: 2.0000e-05
# Epoch 18/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9896 - mean_io_u_1: 0.9266 - dice_coef: 0.8226 - precision: 0.9893 - sensitivity: 0.9892 - specificity: 0.9964
# Epoch 00018: val_loss improved from 0.22745 to 0.22405, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch18-val_loss0.224052_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2084 - accuracy: 0.9896 - mean_io_u_1: 0.9266 - dice_coef: 0.8226 - precision: 0.9893 - sensitivity: 0.9892 - specificity: 0.9964 - val_loss: 0.2241 - val_accuracy: 0.9884 - val_mean_io_u_1: 0.9344 - val_dice_coef: 0.8042 - val_precision: 0.9880 - val_sensitivity: 0.9880 - val_specificity: 0.9960 - lr: 4.0000e-06
# Epoch 19/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9901 - mean_io_u_1: 0.9324 - dice_coef: 0.8293 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00019: val_loss improved from 0.22405 to 0.22368, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch19-val_loss0.223676_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.1958 - accuracy: 0.9901 - mean_io_u_1: 0.9324 - dice_coef: 0.8293 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.2237 - val_accuracy: 0.9886 - val_mean_io_u_1: 0.9338 - val_dice_coef: 0.8039 - val_precision: 0.9883 - val_sensitivity: 0.9883 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 20/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2035 - accuracy: 0.9899 - mean_io_u_1: 0.9270 - dice_coef: 0.8266 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965
# Epoch 00020: val_loss improved from 0.22368 to 0.22280, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch20-val_loss0.222797_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2035 - accuracy: 0.9899 - mean_io_u_1: 0.9270 - dice_coef: 0.8266 - precision: 0.9895 - sensitivity: 0.9895 - specificity: 0.9965 - val_loss: 0.2228 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9276 - val_dice_coef: 0.8057 - val_precision: 0.9883 - val_sensitivity: 0.9883 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 21/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9899 - mean_io_u_1: 0.9257 - dice_coef: 0.8292 - precision: 0.9896 - sensitivity: 0.9895 - specificity: 0.9965
# Epoch 00021: val_loss did not improve from 0.22280
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2025 - accuracy: 0.9899 - mean_io_u_1: 0.9257 - dice_coef: 0.8292 - precision: 0.9896 - sensitivity: 0.9895 - specificity: 0.9965 - val_loss: 0.2232 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9315 - val_dice_coef: 0.8076 - val_precision: 0.9884 - val_sensitivity: 0.9884 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 22/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9902 - mean_io_u_1: 0.9249 - dice_coef: 0.8257 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966
# Epoch 00022: val_loss improved from 0.22280 to 0.22264, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch22-val_loss0.222642_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2055 - accuracy: 0.9902 - mean_io_u_1: 0.9249 - dice_coef: 0.8257 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966 - val_loss: 0.2226 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9312 - val_dice_coef: 0.8067 - val_precision: 0.9883 - val_sensitivity: 0.9883 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 23/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9905 - mean_io_u_1: 0.9291 - dice_coef: 0.8289 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00023: val_loss did not improve from 0.22264
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2022 - accuracy: 0.9905 - mean_io_u_1: 0.9291 - dice_coef: 0.8289 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.2230 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9360 - val_dice_coef: 0.8102 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 24/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2062 - accuracy: 0.9902 - mean_io_u_1: 0.9300 - dice_coef: 0.8216 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00024: val_loss improved from 0.22264 to 0.22198, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch24-val_loss0.221975_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2062 - accuracy: 0.9902 - mean_io_u_1: 0.9300 - dice_coef: 0.8216 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.2220 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9377 - val_dice_coef: 0.8086 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 25/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2004 - accuracy: 0.9909 - mean_io_u_1: 0.9342 - dice_coef: 0.8351 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00025: val_loss did not improve from 0.22198
# 850/850 [==============================] - 35s 41ms/step - loss: 0.2004 - accuracy: 0.9909 - mean_io_u_1: 0.9342 - dice_coef: 0.8351 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.2223 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9406 - val_dice_coef: 0.8111 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 26/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9910 - mean_io_u_1: 0.9387 - dice_coef: 0.8398 - precision: 0.9907 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00026: val_loss improved from 0.22198 to 0.22159, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch26-val_loss0.221589_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1957 - accuracy: 0.9910 - mean_io_u_1: 0.9387 - dice_coef: 0.8398 - precision: 0.9907 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.2216 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9427 - val_dice_coef: 0.8115 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 27/200
# 850/850 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9902 - mean_io_u_1: 0.9344 - dice_coef: 0.8274 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966
# Epoch 00027: val_loss improved from 0.22159 to 0.22083, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch27-val_loss0.220825_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.2055 - accuracy: 0.9902 - mean_io_u_1: 0.9344 - dice_coef: 0.8274 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966 - val_loss: 0.2208 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9395 - val_dice_coef: 0.8097 - val_precision: 0.9884 - val_sensitivity: 0.9884 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 28/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9906 - mean_io_u_1: 0.9511 - dice_coef: 0.8432 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00028: val_loss improved from 0.22083 to 0.21424, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch28-val_loss0.214237_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1897 - accuracy: 0.9906 - mean_io_u_1: 0.9511 - dice_coef: 0.8432 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.2142 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9700 - val_dice_coef: 0.8197 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 29/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9902 - mean_io_u_1: 0.9717 - dice_coef: 0.8374 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00029: val_loss improved from 0.21424 to 0.20296, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch29-val_loss0.202962_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1937 - accuracy: 0.9902 - mean_io_u_1: 0.9717 - dice_coef: 0.8374 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.2030 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9784 - val_dice_coef: 0.8255 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 30/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9899 - mean_io_u_1: 0.9790 - dice_coef: 0.8385 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966
# Epoch 00030: val_loss improved from 0.20296 to 0.19564, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch30-val_loss0.195638_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1881 - accuracy: 0.9899 - mean_io_u_1: 0.9790 - dice_coef: 0.8385 - precision: 0.9897 - sensitivity: 0.9897 - specificity: 0.9966 - val_loss: 0.1956 - val_accuracy: 0.9886 - val_mean_io_u_1: 0.9788 - val_dice_coef: 0.8265 - val_precision: 0.9883 - val_sensitivity: 0.9884 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 31/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9908 - mean_io_u_1: 0.9793 - dice_coef: 0.8557 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00031: val_loss did not improve from 0.19564
# 850/850 [==============================] - 35s 41ms/step - loss: 0.1637 - accuracy: 0.9908 - mean_io_u_1: 0.9793 - dice_coef: 0.8557 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.1996 - val_accuracy: 0.9883 - val_mean_io_u_1: 0.9782 - val_dice_coef: 0.8263 - val_precision: 0.9881 - val_sensitivity: 0.9881 - val_specificity: 0.9960 - lr: 4.0000e-06
# Epoch 32/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9901 - mean_io_u_1: 0.9762 - dice_coef: 0.8421 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966
# Epoch 00032: val_loss improved from 0.19564 to 0.19408, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch32-val_loss0.194079_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1795 - accuracy: 0.9901 - mean_io_u_1: 0.9762 - dice_coef: 0.8421 - precision: 0.9898 - sensitivity: 0.9898 - specificity: 0.9966 - val_loss: 0.1941 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9784 - val_dice_coef: 0.8278 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 33/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9902 - mean_io_u_1: 0.9764 - dice_coef: 0.8424 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966
# Epoch 00033: val_loss improved from 0.19408 to 0.19118, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch33-val_loss0.191183_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1756 - accuracy: 0.9902 - mean_io_u_1: 0.9764 - dice_coef: 0.8424 - precision: 0.9899 - sensitivity: 0.9899 - specificity: 0.9966 - val_loss: 0.1912 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9744 - val_dice_coef: 0.8286 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 34/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9905 - mean_io_u_1: 0.9754 - dice_coef: 0.8459 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00034: val_loss improved from 0.19118 to 0.19093, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch34-val_loss0.190931_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1707 - accuracy: 0.9905 - mean_io_u_1: 0.9754 - dice_coef: 0.8459 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1909 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9742 - val_dice_coef: 0.8268 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 4.0000e-06
# Epoch 35/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9906 - mean_io_u_1: 0.9762 - dice_coef: 0.8468 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00035: val_loss did not improve from 0.19093
# 850/850 [==============================] - 35s 41ms/step - loss: 0.1692 - accuracy: 0.9906 - mean_io_u_1: 0.9762 - dice_coef: 0.8468 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1911 - val_accuracy: 0.9886 - val_mean_io_u_1: 0.9749 - val_dice_coef: 0.8285 - val_precision: 0.9883 - val_sensitivity: 0.9884 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 36/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9905 - mean_io_u_1: 0.9750 - dice_coef: 0.8473 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00036: val_loss did not improve from 0.19093
# 850/850 [==============================] - 35s 41ms/step - loss: 0.1679 - accuracy: 0.9905 - mean_io_u_1: 0.9750 - dice_coef: 0.8473 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1914 - val_accuracy: 0.9887 - val_mean_io_u_1: 0.9726 - val_dice_coef: 0.8278 - val_precision: 0.9884 - val_sensitivity: 0.9885 - val_specificity: 0.9961 - lr: 4.0000e-06
# Epoch 37/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9906 - mean_io_u_1: 0.9740 - dice_coef: 0.8459 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00037: val_loss improved from 0.19093 to 0.19058, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch37-val_loss0.190584_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1694 - accuracy: 0.9906 - mean_io_u_1: 0.9740 - dice_coef: 0.8459 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1906 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9737 - val_dice_coef: 0.8282 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 38/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9906 - mean_io_u_1: 0.9746 - dice_coef: 0.8492 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00038: val_loss improved from 0.19058 to 0.19031, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch38-val_loss0.190306_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1645 - accuracy: 0.9906 - mean_io_u_1: 0.9746 - dice_coef: 0.8492 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1903 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9745 - val_dice_coef: 0.8287 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 39/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9906 - mean_io_u_1: 0.9732 - dice_coef: 0.8484 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00039: val_loss improved from 0.19031 to 0.19028, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch39-val_loss0.190276_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1679 - accuracy: 0.9906 - mean_io_u_1: 0.9732 - dice_coef: 0.8484 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1903 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9741 - val_dice_coef: 0.8283 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 40/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9904 - mean_io_u_1: 0.9729 - dice_coef: 0.8461 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967
# Epoch 00040: val_loss improved from 0.19028 to 0.18929, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch40-val_loss0.189294_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1705 - accuracy: 0.9904 - mean_io_u_1: 0.9729 - dice_coef: 0.8461 - precision: 0.9901 - sensitivity: 0.9901 - specificity: 0.9967 - val_loss: 0.1893 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9744 - val_dice_coef: 0.8286 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 41/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9907 - mean_io_u_1: 0.9735 - dice_coef: 0.8548 - precision: 0.9904 - sensitivity: 0.9904 - specificity: 0.9968
# Epoch 00041: val_loss did not improve from 0.18929
# 850/850 [==============================] - 35s 41ms/step - loss: 0.1606 - accuracy: 0.9907 - mean_io_u_1: 0.9735 - dice_coef: 0.8548 - precision: 0.9904 - sensitivity: 0.9904 - specificity: 0.9968 - val_loss: 0.1894 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9737 - val_dice_coef: 0.8287 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 42/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9907 - mean_io_u_1: 0.9732 - dice_coef: 0.8527 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00042: val_loss improved from 0.18929 to 0.18906, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch42-val_loss0.189056_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1599 - accuracy: 0.9907 - mean_io_u_1: 0.9732 - dice_coef: 0.8527 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1891 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9733 - val_dice_coef: 0.8284 - val_precision: 0.9885 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 43/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9905 - mean_io_u_1: 0.9732 - dice_coef: 0.8457 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00043: val_loss improved from 0.18906 to 0.18898, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch43-val_loss0.188979_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1682 - accuracy: 0.9905 - mean_io_u_1: 0.9732 - dice_coef: 0.8457 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1890 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9751 - val_dice_coef: 0.8287 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 44/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1652 - accuracy: 0.9908 - mean_io_u_1: 0.9759 - dice_coef: 0.8500 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00044: val_loss improved from 0.18898 to 0.18873, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch44-val_loss0.188734_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1652 - accuracy: 0.9908 - mean_io_u_1: 0.9759 - dice_coef: 0.8500 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.1887 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9742 - val_dice_coef: 0.8286 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 45/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1652 - accuracy: 0.9906 - mean_io_u_1: 0.9735 - dice_coef: 0.8474 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00045: val_loss improved from 0.18873 to 0.18849, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch45-val_loss0.188494_Apr-21_22-49-22.m5
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1652 - accuracy: 0.9906 - mean_io_u_1: 0.9735 - dice_coef: 0.8474 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1885 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9738 - val_dice_coef: 0.8292 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 46/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9906 - mean_io_u_1: 0.9737 - dice_coef: 0.8473 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00046: val_loss improved from 0.18849 to 0.18848, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch46-val_loss0.188480_Apr-21_22-49-22.m5
# 850/850 [==============================] - 37s 43ms/step - loss: 0.1650 - accuracy: 0.9906 - mean_io_u_1: 0.9737 - dice_coef: 0.8473 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1885 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9733 - val_dice_coef: 0.8284 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 47/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9907 - mean_io_u_1: 0.9725 - dice_coef: 0.8500 - precision: 0.9904 - sensitivity: 0.9904 - specificity: 0.9968
# Epoch 00047: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1622 - accuracy: 0.9907 - mean_io_u_1: 0.9725 - dice_coef: 0.8500 - precision: 0.9904 - sensitivity: 0.9904 - specificity: 0.9968 - val_loss: 0.1886 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9726 - val_dice_coef: 0.8280 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 48/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9909 - mean_io_u_1: 0.9731 - dice_coef: 0.8538 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00048: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1596 - accuracy: 0.9909 - mean_io_u_1: 0.9731 - dice_coef: 0.8538 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.1889 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9727 - val_dice_coef: 0.8278 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 49/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9909 - mean_io_u_1: 0.9728 - dice_coef: 0.8471 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00049: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1658 - accuracy: 0.9909 - mean_io_u_1: 0.9728 - dice_coef: 0.8471 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1892 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9734 - val_dice_coef: 0.8281 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 50/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9908 - mean_io_u_1: 0.9732 - dice_coef: 0.8547 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00050: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1561 - accuracy: 0.9908 - mean_io_u_1: 0.9732 - dice_coef: 0.8547 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.1893 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9743 - val_dice_coef: 0.8288 - val_precision: 0.9885 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 51/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9910 - mean_io_u_1: 0.9742 - dice_coef: 0.8526 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00051: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1598 - accuracy: 0.9910 - mean_io_u_1: 0.9742 - dice_coef: 0.8526 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1895 - val_accuracy: 0.9888 - val_mean_io_u_1: 0.9746 - val_dice_coef: 0.8285 - val_precision: 0.9885 - val_sensitivity: 0.9885 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 52/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9909 - mean_io_u_1: 0.9751 - dice_coef: 0.8503 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00052: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1639 - accuracy: 0.9909 - mean_io_u_1: 0.9751 - dice_coef: 0.8503 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1895 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9743 - val_dice_coef: 0.8280 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 53/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9910 - mean_io_u_1: 0.9745 - dice_coef: 0.8566 - precision: 0.9907 - sensitivity: 0.9907 - specificity: 0.9969
# Epoch 00053: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1560 - accuracy: 0.9910 - mean_io_u_1: 0.9745 - dice_coef: 0.8566 - precision: 0.9907 - sensitivity: 0.9907 - specificity: 0.9969 - val_loss: 0.1896 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9739 - val_dice_coef: 0.8280 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 54/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9905 - mean_io_u_1: 0.9737 - dice_coef: 0.8494 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00054: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1632 - accuracy: 0.9905 - mean_io_u_1: 0.9737 - dice_coef: 0.8494 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1894 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9729 - val_dice_coef: 0.8279 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 55/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9908 - mean_io_u_1: 0.9734 - dice_coef: 0.8520 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00055: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1584 - accuracy: 0.9908 - mean_io_u_1: 0.9734 - dice_coef: 0.8520 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.1889 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9734 - val_dice_coef: 0.8281 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 56/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9909 - mean_io_u_1: 0.9751 - dice_coef: 0.8599 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00056: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1507 - accuracy: 0.9909 - mean_io_u_1: 0.9751 - dice_coef: 0.8599 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1891 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9745 - val_dice_coef: 0.8283 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 57/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9907 - mean_io_u_1: 0.9743 - dice_coef: 0.8541 - precision: 0.9904 - sensitivity: 0.9904 - specificity: 0.9968
# Epoch 00057: val_loss did not improve from 0.18848
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1567 - accuracy: 0.9907 - mean_io_u_1: 0.9743 - dice_coef: 0.8541 - precision: 0.9904 - sensitivity: 0.9904 - specificity: 0.9968 - val_loss: 0.1892 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9746 - val_dice_coef: 0.8284 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 58/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9906 - mean_io_u_1: 0.9735 - dice_coef: 0.8455 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967
# Epoch 00058: val_loss improved from 0.18848 to 0.18828, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch58-val_loss0.188275_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1689 - accuracy: 0.9906 - mean_io_u_1: 0.9735 - dice_coef: 0.8455 - precision: 0.9902 - sensitivity: 0.9902 - specificity: 0.9967 - val_loss: 0.1883 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9738 - val_dice_coef: 0.8289 - val_precision: 0.9886 - val_sensitivity: 0.9886 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 59/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9911 - mean_io_u_1: 0.9745 - dice_coef: 0.8537 - precision: 0.9907 - sensitivity: 0.9907 - specificity: 0.9969
# Epoch 00059: val_loss improved from 0.18828 to 0.18810, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch59-val_loss0.188101_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1573 - accuracy: 0.9911 - mean_io_u_1: 0.9745 - dice_coef: 0.8537 - precision: 0.9907 - sensitivity: 0.9907 - specificity: 0.9969 - val_loss: 0.1881 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9733 - val_dice_coef: 0.8283 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 60/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9911 - mean_io_u_1: 0.9731 - dice_coef: 0.8583 - precision: 0.9908 - sensitivity: 0.9908 - specificity: 0.9969
# Epoch 00060: val_loss did not improve from 0.18810
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1521 - accuracy: 0.9911 - mean_io_u_1: 0.9731 - dice_coef: 0.8583 - precision: 0.9908 - sensitivity: 0.9908 - specificity: 0.9969 - val_loss: 0.1889 - val_accuracy: 0.9889 - val_mean_io_u_1: 0.9721 - val_dice_coef: 0.8282 - val_precision: 0.9886 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 61/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9911 - mean_io_u_1: 0.9722 - dice_coef: 0.8551 - precision: 0.9908 - sensitivity: 0.9908 - specificity: 0.9969
# Epoch 00061: val_loss did not improve from 0.18810
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1553 - accuracy: 0.9911 - mean_io_u_1: 0.9722 - dice_coef: 0.8551 - precision: 0.9908 - sensitivity: 0.9908 - specificity: 0.9969 - val_loss: 0.1885 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9733 - val_dice_coef: 0.8281 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 62/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9909 - mean_io_u_1: 0.9749 - dice_coef: 0.8535 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00062: val_loss did not improve from 0.18810
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1588 - accuracy: 0.9909 - mean_io_u_1: 0.9749 - dice_coef: 0.8535 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1883 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9747 - val_dice_coef: 0.8286 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 63/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9909 - mean_io_u_1: 0.9735 - dice_coef: 0.8535 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00063: val_loss improved from 0.18810 to 0.18778, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch63-val_loss0.187782_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1571 - accuracy: 0.9909 - mean_io_u_1: 0.9735 - dice_coef: 0.8535 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1878 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9729 - val_dice_coef: 0.8288 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 64/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9908 - mean_io_u_1: 0.9724 - dice_coef: 0.8512 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968
# Epoch 00064: val_loss did not improve from 0.18778
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1581 - accuracy: 0.9908 - mean_io_u_1: 0.9724 - dice_coef: 0.8512 - precision: 0.9905 - sensitivity: 0.9905 - specificity: 0.9968 - val_loss: 0.1880 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9728 - val_dice_coef: 0.8286 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 65/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9907 - mean_io_u_1: 0.9722 - dice_coef: 0.8491 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968
# Epoch 00065: val_loss did not improve from 0.18778
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1609 - accuracy: 0.9907 - mean_io_u_1: 0.9722 - dice_coef: 0.8491 - precision: 0.9903 - sensitivity: 0.9903 - specificity: 0.9968 - val_loss: 0.1880 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9731 - val_dice_coef: 0.8283 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 66/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9909 - mean_io_u_1: 0.9737 - dice_coef: 0.8510 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969
# Epoch 00066: val_loss improved from 0.18778 to 0.18766, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch66-val_loss0.187660_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1591 - accuracy: 0.9909 - mean_io_u_1: 0.9737 - dice_coef: 0.8510 - precision: 0.9906 - sensitivity: 0.9906 - specificity: 0.9969 - val_loss: 0.1877 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9746 - val_dice_coef: 0.8298 - val_precision: 0.9887 - val_sensitivity: 0.9887 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 67/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9910 - mean_io_u_1: 0.9750 - dice_coef: 0.8547 - precision: 0.9907 - sensitivity: 0.9907 - specificity: 0.9969
# Epoch 00067: val_loss did not improve from 0.18766
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1559 - accuracy: 0.9910 - mean_io_u_1: 0.9750 - dice_coef: 0.8547 - precision: 0.9907 - sensitivity: 0.9907 - specificity: 0.9969 - val_loss: 0.1878 - val_accuracy: 0.9890 - val_mean_io_u_1: 0.9745 - val_dice_coef: 0.8297 - val_precision: 0.9887 - val_sensitivity: 0.9888 - val_specificity: 0.9962 - lr: 1.0000e-06
# Epoch 68/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.9906 - mean_io_u_1: 0.9736 - dice_coef: 0.8476 - precision: 0.9902 - sensitivity: 0.9903 - specificity: 0.9968
# ...
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1425 - accuracy: 0.9917 - mean_io_u_1: 0.9737 - dice_coef: 0.8658 - precision: 0.9913 - sensitivity: 0.9913 - specificity: 0.9971 - val_loss: 0.1847 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9733 - val_dice_coef: 0.8284 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 177/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9915 - mean_io_u_1: 0.9731 - dice_coef: 0.8606 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971
# Epoch 00177: val_loss did not improve from 0.18467
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1468 - accuracy: 0.9915 - mean_io_u_1: 0.9731 - dice_coef: 0.8606 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971 - val_loss: 0.1850 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9732 - val_dice_coef: 0.8282 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 178/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9917 - mean_io_u_1: 0.9738 - dice_coef: 0.8655 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00178: val_loss improved from 0.18467 to 0.18459, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch178-val_loss0.184593_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1407 - accuracy: 0.9917 - mean_io_u_1: 0.9738 - dice_coef: 0.8655 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1846 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9736 - val_dice_coef: 0.8297 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 179/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9919 - mean_io_u_1: 0.9741 - dice_coef: 0.8642 - precision: 0.9915 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00179: val_loss improved from 0.18459 to 0.18341, saving model to /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/model_epoch179-val_loss0.183414_Apr-21_22-49-22.m5
# 850/850 [==============================] - 36s 42ms/step - loss: 0.1432 - accuracy: 0.9919 - mean_io_u_1: 0.9741 - dice_coef: 0.8642 - precision: 0.9915 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1834 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9729 - val_dice_coef: 0.8302 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 180/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9918 - mean_io_u_1: 0.9728 - dice_coef: 0.8655 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972
# Epoch 00180: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1407 - accuracy: 0.9918 - mean_io_u_1: 0.9728 - dice_coef: 0.8655 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972 - val_loss: 0.1840 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9720 - val_dice_coef: 0.8292 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 181/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9918 - mean_io_u_1: 0.9729 - dice_coef: 0.8647 - precision: 0.9914 - sensitivity: 0.9915 - specificity: 0.9971
# Epoch 00181: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1414 - accuracy: 0.9918 - mean_io_u_1: 0.9729 - dice_coef: 0.8647 - precision: 0.9914 - sensitivity: 0.9915 - specificity: 0.9971 - val_loss: 0.1843 - val_accuracy: 0.9892 - val_mean_io_u_1: 0.9710 - val_dice_coef: 0.8284 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 182/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9919 - mean_io_u_1: 0.9728 - dice_coef: 0.8727 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00182: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1332 - accuracy: 0.9919 - mean_io_u_1: 0.9728 - dice_coef: 0.8727 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1841 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9735 - val_dice_coef: 0.8289 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 183/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9918 - mean_io_u_1: 0.9735 - dice_coef: 0.8680 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00183: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1395 - accuracy: 0.9918 - mean_io_u_1: 0.9735 - dice_coef: 0.8680 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1846 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9725 - val_dice_coef: 0.8288 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 184/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9915 - mean_io_u_1: 0.9739 - dice_coef: 0.8600 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971
# Epoch 00184: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1464 - accuracy: 0.9915 - mean_io_u_1: 0.9739 - dice_coef: 0.8600 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971 - val_loss: 0.1840 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9732 - val_dice_coef: 0.8302 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 185/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9916 - mean_io_u_1: 0.9734 - dice_coef: 0.8658 - precision: 0.9913 - sensitivity: 0.9913 - specificity: 0.9971
# Epoch 00185: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1398 - accuracy: 0.9916 - mean_io_u_1: 0.9734 - dice_coef: 0.8658 - precision: 0.9913 - sensitivity: 0.9913 - specificity: 0.9971 - val_loss: 0.1856 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9737 - val_dice_coef: 0.8284 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 186/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9916 - mean_io_u_1: 0.9736 - dice_coef: 0.8637 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971
# Epoch 00186: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1429 - accuracy: 0.9916 - mean_io_u_1: 0.9736 - dice_coef: 0.8637 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971 - val_loss: 0.1848 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9734 - val_dice_coef: 0.8300 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 187/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9916 - mean_io_u_1: 0.9731 - dice_coef: 0.8582 - precision: 0.9912 - sensitivity: 0.9913 - specificity: 0.9971
# Epoch 00187: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1496 - accuracy: 0.9916 - mean_io_u_1: 0.9731 - dice_coef: 0.8582 - precision: 0.9912 - sensitivity: 0.9913 - specificity: 0.9971 - val_loss: 0.1847 - val_accuracy: 0.9892 - val_mean_io_u_1: 0.9720 - val_dice_coef: 0.8290 - val_precision: 0.9889 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 188/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9919 - mean_io_u_1: 0.9731 - dice_coef: 0.8668 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972
# Epoch 00188: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1384 - accuracy: 0.9919 - mean_io_u_1: 0.9731 - dice_coef: 0.8668 - precision: 0.9915 - sensitivity: 0.9915 - specificity: 0.9972 - val_loss: 0.1847 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9728 - val_dice_coef: 0.8288 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 189/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9920 - mean_io_u_1: 0.9735 - dice_coef: 0.8685 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00189: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1375 - accuracy: 0.9920 - mean_io_u_1: 0.9735 - dice_coef: 0.8685 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1846 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9735 - val_dice_coef: 0.8297 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 190/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9919 - mean_io_u_1: 0.9742 - dice_coef: 0.8691 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00190: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1373 - accuracy: 0.9919 - mean_io_u_1: 0.9742 - dice_coef: 0.8691 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1839 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9732 - val_dice_coef: 0.8299 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 191/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9917 - mean_io_u_1: 0.9731 - dice_coef: 0.8677 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00191: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1379 - accuracy: 0.9917 - mean_io_u_1: 0.9731 - dice_coef: 0.8677 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1840 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9721 - val_dice_coef: 0.8294 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 192/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9916 - mean_io_u_1: 0.9724 - dice_coef: 0.8647 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971
# Epoch 00192: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1411 - accuracy: 0.9916 - mean_io_u_1: 0.9724 - dice_coef: 0.8647 - precision: 0.9912 - sensitivity: 0.9912 - specificity: 0.9971 - val_loss: 0.1841 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9733 - val_dice_coef: 0.8296 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 193/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9917 - mean_io_u_1: 0.9734 - dice_coef: 0.8668 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00193: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1396 - accuracy: 0.9917 - mean_io_u_1: 0.9734 - dice_coef: 0.8668 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1845 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9730 - val_dice_coef: 0.8291 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 194/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9919 - mean_io_u_1: 0.9734 - dice_coef: 0.8647 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00194: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1406 - accuracy: 0.9919 - mean_io_u_1: 0.9734 - dice_coef: 0.8647 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1843 - val_accuracy: 0.9892 - val_mean_io_u_1: 0.9723 - val_dice_coef: 0.8294 - val_precision: 0.9889 - val_sensitivity: 0.9889 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 195/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9917 - mean_io_u_1: 0.9731 - dice_coef: 0.8639 - precision: 0.9913 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00195: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1422 - accuracy: 0.9917 - mean_io_u_1: 0.9731 - dice_coef: 0.8639 - precision: 0.9913 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1841 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9734 - val_dice_coef: 0.8303 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 196/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9918 - mean_io_u_1: 0.9746 - dice_coef: 0.8633 - precision: 0.9914 - sensitivity: 0.9915 - specificity: 0.9971
# Epoch 00196: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1439 - accuracy: 0.9918 - mean_io_u_1: 0.9746 - dice_coef: 0.8633 - precision: 0.9914 - sensitivity: 0.9915 - specificity: 0.9971 - val_loss: 0.1841 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9752 - val_dice_coef: 0.8305 - val_precision: 0.9890 - val_sensitivity: 0.9891 - val_specificity: 0.9964 - lr: 1.0000e-06
# Epoch 197/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9918 - mean_io_u_1: 0.9747 - dice_coef: 0.8678 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971
# Epoch 00197: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1380 - accuracy: 0.9918 - mean_io_u_1: 0.9747 - dice_coef: 0.8678 - precision: 0.9914 - sensitivity: 0.9914 - specificity: 0.9971 - val_loss: 0.1848 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9746 - val_dice_coef: 0.8296 - val_precision: 0.9890 - val_sensitivity: 0.9891 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 198/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9919 - mean_io_u_1: 0.9748 - dice_coef: 0.8688 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00198: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1370 - accuracy: 0.9919 - mean_io_u_1: 0.9748 - dice_coef: 0.8688 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1840 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9742 - val_dice_coef: 0.8306 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 199/200
# 850/850 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9919 - mean_io_u_1: 0.9742 - dice_coef: 0.8681 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00199: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1377 - accuracy: 0.9919 - mean_io_u_1: 0.9742 - dice_coef: 0.8681 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1843 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9737 - val_dice_coef: 0.8294 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06
# Epoch 200/200
# 849/850 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9920 - mean_io_u_1: 0.9745 - dice_coef: 0.8706 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972
# Epoch 00200: val_loss did not improve from 0.18341
# 850/850 [==============================] - 35s 42ms/step - loss: 0.1344 - accuracy: 0.9920 - mean_io_u_1: 0.9745 - dice_coef: 0.8706 - precision: 0.9916 - sensitivity: 0.9916 - specificity: 0.9972 - val_loss: 0.1845 - val_accuracy: 0.9893 - val_mean_io_u_1: 0.9739 - val_dice_coef: 0.8296 - val_precision: 0.9890 - val_sensitivity: 0.9890 - val_specificity: 0.9963 - lr: 1.0000e-06

# %% [markdown]
# #### 4 - 3: Plot the training process

# %%
import glob

training_log_filename = glob.glob(os.path.join(model_dir, 'training-*.log'))[0]
plt_filename = os.path.splitext(os.path.basename(training_log_filename))[0]
print(f'plt image will be saved in: {training_log_filename}\nwith name: {plt_filename}')
# Out:
# plt image will be saved in: /home/cbel/Desktop/YIHAN/unet/model/model_v1_Apr-21_22-49-22/training-Apr-21_22-49-22.log
# with name: training-Apr-21_22-49-22

# %%
# Read the CSVlogger file that contains all our metrics (accuracy, loss, dice_coef, ...) of our training
history = pd.read_csv(training_log_filename, sep=',', engine='python')

# Plot training and validation metrics
fig, axs = plt.subplots(1, 3, figsize=(16, 8))
# fig, axs = plt.subplots(1, 4, figsize=(16, 8))

axs[0].plot(history['epoch'], history['accuracy'], 'b', label='Training Accuracy')
axs[0].plot(history['epoch'], history['val_accuracy'], 'r', label='Validation Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

axs[1].plot(history['epoch'], history['loss'], 'b', label='Training Loss')
axs[1].plot(history['epoch'], history['val_loss'], 'r', label='Validation Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()

axs[2].plot(history['epoch'], history['dice_coef'], 'b', label='Training dice coef')
axs[2].plot(history['epoch'], history['val_dice_coef'], 'r', label='Validation dice coef')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Dice Coefficient')
axs[2].legend()

# axs[3].plot(history['epoch'], history['mean_io_u'], 'b', label='Training mean IOU')
# axs[3].plot(history['epoch'], history['val_mean_io_u'], 'r', label='Validation mean IOU')
# axs[3].set_xlabel('Epoch')
# axs[3].set_ylabel('Mean IOU')
# axs[3].legend()

# Add space between subplots
plt.subplots_adjust(wspace=0.4)
plt.savefig(f'/home/cbel/Desktop/YIHAN/unet/plt/train/{plt_filename}.png', dpi=300)

plt.show()

# %% [markdown]
# ### Step 5 - Predict

# %%
PREDICT_PLT_DIR = f'/home/cbel/Desktop/YIHAN/unet/plt/predict/{model_dir.split("/home/cbel/Desktop/YIHAN/unet/model/")[1]}'
if not os.path.exists(PREDICT_PLT_DIR):
    os.makedirs(PREDICT_PLT_DIR)
    print(f"Dir {PREDICT_PLT_DIR} created.")
else:
    print(f"Dir {PREDICT_PLT_DIR} existed.")
# Out:
# Dir /home/cbel/Desktop/YIHAN/unet/plt/predict/model_v1_Apr-21_22-49-22 created.

# %%
import glob
import os

def find_latest_file(directory, pattern):
    search_pattern = os.path.join(directory, pattern)
    files = glob.glob(search_pattern)

    if not files:
        return None

    latest_file = max(files, key=os.path.getmtime)

    return latest_file

PATTERN = 'model_epoch*-val_loss*_*.m5.index'

latest_model_file = find_latest_file(f'{model_dir}', PATTERN)

latest_trained_model = os.path.splitext(os.path.splitext(os.path.basename(latest_model_file))[0])[0]

print(f'latest model file: {latest_trained_model}')
# Out:
# latest model file: model_epoch179-val_loss0.183414_Apr-21_22-49-22

# %%
# Compile a model and load our saved weights
from tensorflow.keras import Input

INPUT_LAYER = Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
KER_INIT = KER_INIT
DROPOUT = DROPOUT
LEARNING_RATE = LEARNING_RATE

best_saved_model = model_builders.get(MODEL_VERSION, unet_v1)(inputs=INPUT_LAYER, ker_init=KER_INIT, dropout=DROPOUT, kernel_size=KERNEL_SIZE)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tensorflow.keras.optimizers.Adam(learning_rate=LEARNING_RATE), metrics = ['accuracy',tensorflow.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity] )


best_saved_model.load_weights(f'{model_dir}/{latest_trained_model}.m5')
# Out:
# ****** using U-Net V1 ******

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '-t1c.nii.gz'
    flair_path = sample_path + '-t2f.nii.gz'
    #t1_path = sample_path + '_t1.nii'
    #t2_path = sample_path + '_t2.nii'
            
    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()
    
    # Create an empty array
    X = np.empty((VOLUME_SLICES_PLUS, IMG_SIZE, IMG_SIZE, 2))
    
    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES_PLUS):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
    # Send our images to the CNN model and return predicted segmentation 
    return best_saved_model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)
    print(f'random_sample: {random_sample}')
    
    # Get path of this patient
    random_sample_path = os.path.join(data_path_GLI_train_dir, random_sample, random_sample)
    print(f'random_sample_path: {random_sample_path}')
    
    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)
   
    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '-seg.nii.gz'
    seg = nib.load(seg_path).get_fdata()
    
    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    
    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    convert_all = all.astype(np.float32) if all.dtype == np.float16 else all
    convert_zero = zero.astype(np.float32) if zero.dtype == np.float16 else zero
    convert_first = first.astype(np.float32) if first.dtype == np.float16 else first
    convert_second = second.astype(np.float32) if second.dtype == np.float16 else second
    convert_third = third.astype(np.float32) if third.dtype == np.float16 else third

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')
    
    # Layers 1, 2, 3
    axstest[1].imshow(convert_all)
    axstest[1].set_title('Predicted Segmentation - all layers')
    
    # Layer 0
    axstest[2].imshow(convert_zero)
    axstest[2].set_title('Predicted Segmentation - layer 0')
    
    # Layer 1
    axstest[3].imshow(convert_first)
    axstest[3].set_title('Predicted Segmentation - layer 1')
    
    # Layer 2
    axstest[4].imshow(convert_second)
    axstest[4].set_title('Predicted Segmentation - layer 2')
    
    # Layer 3
    axstest[5].imshow(convert_third)
    axstest[5].set_title('Predicted Segmentation - layer 3')
    
    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.savefig(f'{PREDICT_PLT_DIR}/{random_sample}.png', dpi=300)

    plt.show()

cmap = mpl.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = mpl.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# %%
show_predicted_segmentations(datas_test, 60, cmap, norm)
# Out:
# random_sample: BraTS-GLI-01314-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-01314-000/BraTS-GLI-01314-000
# 3/3 [==============================] - 4s 738ms/step
# Patient number:  BraTS-GLI-01314-000

# %%
show_predicted_segmentations(datas_test, 50, cmap, norm)
# Out:
# random_sample: BraTS-GLI-01661-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-01661-000/BraTS-GLI-01661-000
# 3/3 [==============================] - 0s 62ms/step
# Patient number:  BraTS-GLI-01661-000

# %%
show_predicted_segmentations(datas_test, 70, cmap, norm)
# Out:
# random_sample: BraTS-GLI-01179-000
# random_sample_path: /home/cbel/Desktop/YIHAN/brain_tumor_seg/data/raw_data/GLI_train/BraTS-GLI-01179-000/BraTS-GLI-01179-000
# 3/3 [==============================] - 0s 63ms/step
# Patient number:  BraTS-GLI-01179-000

# %%
def show_post_processed_segmentations(sample, slice_to_plot, cmap, norm):
    
    # Get path of this patient
    sample_path = os.path.join(data_path_GLI_train_dir, sample, sample)
    
    # Predict patient's segmentation
    predicted_seg = predict_segmentation(sample_path)
   
    # Load patient's original segmentation (Ground truth)
    seg_path = sample_path + '-seg.nii.gz'
    seg = nib.load(seg_path).get_fdata()
    
    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    
    # Fix 4 to 3 to have the same values as in the predicted segmentation, and then same colors
    seg[seg==4] = 3
    
    # Remove background layer (0) from original segmentation
    seg[seg==0] = np.nan
    
    # Post-processing
    # Get indexes for each class of the highest probability pixels. Array will then contain only [0 1 2 3] instead of probabilities
    my_pred = np.argmax(predicted_seg, axis=3)
    my_pred = my_pred[slice_to_plot, :, :]

    # Remove background layer (0) from post-processed predicted segmentation
    # To fix 0 to np.nan, we need to convert array as a float
    my_pred = my_pred.astype(float)
    my_pred[my_pred == 0] = np.nan

    # Remove background layer (0) from classical predicted segmentation
    all = predicted_seg[slice_to_plot,:,:,1:4] 

    convert_all = all.astype(np.float32) if all.dtype == np.float16 else all
    
    # Plot Original segmentation & predicted segmentation without processing & predicted segmentation
    print("Patient number: ", sample)
    fig, axstest = plt.subplots(1, 3, figsize=(15, 10))

    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')
    
    axstest[1].imshow(convert_all)
    axstest[1].set_title('Prediction (w/o post processing (layer 1,2,3)')
    
    axstest[2].imshow(my_pred, cmap, norm)
    axstest[2].set_title('Prediction (w/ post processing (layer 1,2,3)')
    
    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)
    plt.savefig(f'{PREDICT_PLT_DIR}/{sample}.png', dpi=300)
    
    plt.show()

# %%
show_post_processed_segmentations(sample = "BraTS-GLI-00777-000", slice_to_plot=60, cmap=cmap, norm=norm)
# Out:
# 3/3 [==============================] - 0s 63ms/step
# Patient number:  BraTS-GLI-00777-000

# %%
show_post_processed_segmentations(sample = "BraTS-GLI-00675-000", slice_to_plot=50, cmap=cmap, norm=norm)
# Out:
# 3/3 [==============================] - 0s 62ms/step
# Patient number:  BraTS-GLI-00675-000

# %% [markdown]
# ### Step 6 - Evaluate the model

# %%
import sys
# Evaluate the model on the test data
test_generator = data_generators.get(DATA_GENERATOR_VERSION, DataGenerator_UnetV1)(TEST_PKL if DATA_GENERATOR_VERSION == 3 else datas_test)
results = best_saved_model.evaluate(test_generator, batch_size=200, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

print("\nModel evaluation on the test set:")

original_stdout = sys.stdout
with open(f'{model_dir}/predict_result.log', 'w') as predict_log_file:
    sys.stdout = predict_log_file

    # Display each metric with its description
    print("==================================")
    for i, (metric, description) in enumerate(results_list):
        print(f"{description} : {round(metric, 4)}")
    print("==================================")

sys.stdout = original_stdout
# Out:
# ------ usging Data Generator V3: use crop NIIs ------
# 1382/1382 [==============================] - 12s 8ms/step - loss: 0.1803 - accuracy: 0.9890 - mean_io_u_2: 0.9696 - dice_coef: 0.8197 - precision: 0.9887 - sensitivity: 0.9887 - specificity: 0.9962
#
# Model evaluation on the test set:
